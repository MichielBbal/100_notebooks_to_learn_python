# %% [markdown]
# # Graphs advanced
#
# ## Contents
# 0. Install packages
# 1. Seaborn
# 2. Plotly - interactive graphs
# 3. Plotnine
# 4. IPywidgets - interactive graphs

# %% [markdown]
# ## 0. Install packages

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: scipy>=1.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotnine
# Out:
# Collecting plotnine
#   Downloading plotnine-0.10.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from plotnine) (1.21.5)
# Requirement already satisfied: matplotlib>=3.5.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from plotnine) (3.5.1)
# Requirement already satisfied: patsy>=0.5.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: pandas>=1.3.5 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from plotnine) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from plotnine) (1.7.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from plotnine) (0.13.2)
# Collecting mizani>=0.8.1
#   Downloading mizani-0.8.1-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 5.2 MB/s  eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine) (0.11.0)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 7.4 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3.5->plotnine) (2021.3)
# Requirement already satisfied: six in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: palettable, mizani, plotnine
# Successfully installed mizani-0.8.1 palettable-3.3.0 plotnine-0.10.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Seaborn

# %%
#Intro to Python p.415

c = lambda f:5/9 * (f-32)
temps = [(f, c(f)) for f in range(0,101,10)]

import pandas as pd
temps_df = pd.DataFrame(temps, columns=['Fahrenheit', 'Celsius'])

#axes = temps_df.plot(x='Fahrenheit', y = 'Celsius', style = ".-")
#y_label = axes.set_ylabel('Celsius')

nyc = pd.read_csv('USH00305801-tavg-1-1-1895-2020.csv')
nyc.columns = ['Date', 'Temperature', 'Anomaly']
nyc.head()

import seaborn as sns
sns.set_style('whitegrid')
axes = sns.regplot(x=nyc.Date, y=nyc.Temperature)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 12>()
#       7 temps_df = pd.DataFrame(temps, columns=['Fahrenheit', 'Celsius'])
#       9 #axes = temps_df.plot(x='Fahrenheit', y = 'Celsius', style = ".-")
#      10 #y_label = axes.set_ylabel('Celsius')
# ---> 12 nyc = pd.read_csv('USH00305801-tavg-1-1-1895-2020.csv')
#      13 nyc.columns = ['Date', 'Temperature', 'Anomaly']
#      14 nyc.head()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'USH00305801-tavg-1-1-1895-2020.csv'

# %% [markdown]
# ## 2. Plotly
#
# Plotly is a library for making interactive graphs. It can be used to make more advanced graphs.
#
# Plotly has two modes: an offline mode and an online mode. With the offline mode you can make nice graphs but can't make interactive graphs. With the more advance online mode, users can make interactive graphs eg. setting the scale.
#
# For simple usage, there is an offline mode which you can use in Jupyter notebook. We will do this in this notebook.
#
# If you want to present your data in a website using interactive charts and maps, Plotly is your tool.
# Plotly is a service and needs an account. You are sending a request to the plotly server and you get a html=page back.
#
# Plotly documentation can be found here:

# %%
# %pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# Processing c:\users\31653\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56\retrying-1.3.3-py3-none-any.whl
# Requirement already satisfied: six in c:\users\31653\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.14.3 retrying-1.3.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2a. My first Plotly (offline mode)

# %%
# source https://www.youtube.com/watch?v=XUNaGFa9xCM

import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
from scipy import special 

py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x= np.linspace(0,np.pi, 1000)

layout=go.Layout(
    title='SIMPLE EXAMPLE',
    yaxis=dict(
        title='volts'),
    xaxis=dict(
        title='nanosecs'
    )
)

trace1= go.Scatter(
    x=x,
    y=np.sin(x),
    mode='lines',
    name='sin(x)',
    line =dict(
        shape='spline'
    )
)

fig=go.Figure(data=[trace1], layout=layout)

py.offline.iplot(fig)
# Out:
# <div>                            <div id="3ab811f8-3cab-4bee-855d-29b70331fe5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ab811f8-3cab-4bee-855d-29b70331fe5f")) {                    Plotly.newPlot(                        "3ab811f8-3cab-4bee-855d-29b70331fe5f",                        [{"line":{"shape":"spline"},"mode":"lines","name":"sin(x)","x":[0.0,0.0031447373909807737,0.006289474781961547,0.009434212172942321,0.012578949563923095,0.01572368695490387,0.018868424345884642,0.022013161736865416,0.02515789912784619,0.028302636518826963,0.03144737390980774,0.034592111300788514,0.037736848691769284,0.040881586082750054,0.04402632347373083,0.04717106086471161,0.05031579825569238,0.05346053564667315,0.056605273037653926,0.0597500104286347,0.06289474781961547,0.06603948521059624,0.06918422260157703,0.0723289599925578,0.07547369738353857,0.07861843477451934,0.08176317216550011,0.08490790955648089,0.08805264694746166,0.09119738433844243,0.09434212172942322,0.09748685912040399,0.10063159651138476,0.10377633390236553,0.1069210712933463,0.11006580868432708,0.11321054607530785,0.11635528346628862,0.1195000208572694,0.12264475824825018,0.12578949563923095,0.12893423303021173,0.1320789704211925,0.13522370781217327,0.13836844520315406,0.1415131825941348,0.1446579199851156,0.14780265737609635,0.15094739476707714,0.15409213215805792,0.15723686954903868,0.16038160694001946,0.16352634433100022,0.166671081721981,0.16981581911296179,0.17296055650394254,0.17610529389492333,0.1792500312859041,0.18239476867688487,0.18553950606786565,0.18868424345884643,0.1918289808498272,0.19497371824080797,0.19811845563178873,0.20126319302276952,0.2044079304137503,0.20755266780473106,0.21069740519571184,0.2138421425866926,0.21698687997767338,0.22013161736865416,0.22327635475963492,0.2264210921506157,0.2295658295415965,0.23271056693257725,0.23585530432355803,0.2390000417145388,0.24214477910551957,0.24528951649650035,0.2484342538874811,0.2515789912784619,0.25472372866944265,0.25786846606042346,0.2610132034514042,0.264157940842385,0.2673026782333658,0.27044741562434654,0.2735921530153273,0.2767368904063081,0.27988162779728887,0.2830263651882696,0.2861711025792504,0.2893158399702312,0.29246057736121195,0.2956053147521927,0.2987500521431735,0.3018947895341543,0.30503952692513503,0.30818426431611584,0.3113290017070966,0.31447373909807735,0.31761847648905817,0.3207632138800389,0.3239079512710197,0.32705268866200043,0.33019742605298125,0.333342163443962,0.33648690083494276,0.33963163822592357,0.3427763756169043,0.3459211130078851,0.3490658503988659,0.35221058778984665,0.3553553251808274,0.3585000625718082,0.361644799962789,0.36478953735376973,0.36793427474475054,0.3710790121357313,0.37422374952671206,0.37736848691769287,0.3805132243086736,0.3836579616996544,0.38680269909063514,0.38994743648161595,0.3930921738725967,0.39623691126357746,0.3993816486545583,0.40252638604553903,0.4056711234365198,0.4088158608275006,0.41196059821848136,0.4151053356094621,0.4182500730004429,0.4213948103914237,0.42453954778240444,0.4276842851733852,0.430829022564366,0.43397375995534676,0.4371184973463275,0.44026323473730833,0.4434079721282891,0.44655270951926984,0.44969744691025065,0.4528421843012314,0.45598692169221217,0.459131659083193,0.46227639647417373,0.4654211338651545,0.4685658712561353,0.47171060864711606,0.4748553460380968,0.4780000834290776,0.4811448208200584,0.48428955821103914,0.4874342956020199,0.4905790329930007,0.49372377038398146,0.4968685077749622,0.500013245165943,0.5031579825569238,0.5063027199479045,0.5094474573388853,0.5125921947298661,0.5157369321208469,0.5188816695118277,0.5220264069028084,0.5251711442937892,0.52831588168477,0.5314606190757507,0.5346053564667316,0.5377500938577123,0.5408948312486931,0.5440395686396738,0.54718430603065 ...

# %% [markdown]
# ## 3. Plotnine with pandas
#
# source: https://smithsonianworkshops.github.io/2018-06-12-nmnh/17-visualization-ggplot-python/index.html
# Python has powerful built-in plotting capabilities such as matplotlib, but for this episode, we will be using the plotnine package, which facilitates the creation of highly-informative plots of structured data based on the R implementation of ggplot2 and The Grammar of Graphics by Leland Wilkinson. The plotnine package is built on top of Matplotlib and interacts well with Pandas.
#
# Just as with the other packages, plotnine need to be imported. It is good practice to not just load an entire package such as from plotnine import *, but to use an abbreviation as we used pd for Pandas:

# %%
import plotnine as p9

# %%
import pandas as pd
gh_url = 'https://raw.githubusercontent.com/datacarpentry/R-genomics/gh-pages/data/Ecoli_metadata.csv'
ecoli = pd.read_csv(gh_url)
ecoli.head()
# Out:
#      sample  generation    clade  strain      cit        run  genome_size
# 0    REL606           0      NaN  REL606  unknown        NaN         4.62
# 1  REL1166A        2000  unknown  REL606  unknown  SRR098028         4.63
# 2    ZDB409        5000  unknown  REL606  unknown  SRR098281         4.60
# 3    ZDB429       10000       UC  REL606  unknown  SRR098282         4.59
# 4    ZDB446       15000       UC  REL606  unknown  SRR098283         4.66

# %%
(p9.ggplot(data=ecoli,
           mapping=p9.aes(x='genome_size'))
    + p9.geom_histogram(bins=15)
)
# Out:
# <ggplot: (8781899253685)>

# %%
(p9.ggplot(data=ecoli,
           mapping=p9.aes(x = 'sample', y= 'genome_size'))
 + p9.geom_point()
)
# Out:
# <ggplot: (8781899493617)>

# %% [markdown]
# ## 4. IPywidgets
#
# - Readthedocs: https://ipywidgets.readthedocs.io/en/stable/user_install.html
# - Pypi:

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\michiel\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (8.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (6.9.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\michiel\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\michiel\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: stack-data in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (61.2.0)
# Requirement already satisfied: decorator in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: colorama in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: backcall in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\michiel\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\michiel\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\michiel\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\michiel\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\michiel\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\michiel\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (302)
# Requirement already satisfied: fastjsonschema in c:\users\michiel\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\michiel\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\michiel\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\michiel\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\michiel\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\michiel\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\michiel\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\michiel\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\michiel\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\michiel\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\michiel\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\michiel\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\michiel\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.4.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\michiel\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\michiel\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\michiel\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\michiel\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\michiel\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: defusedxml in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: bleach in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: testpath in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\michiel\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\michiel\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.3.1)
# Requirement already satisfied: packaging in c:\users\michiel\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: webencodings in c:\users\michiel\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\michiel\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.4)
# Requirement already satisfied: executing in c:\users\michiel\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\michiel\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\michiel\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)

# %%
import ipywidgets as widgets

# %%
from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
#dropdown: https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html#Dropdown
widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)
# Out:
# Dropdown(description='Number:', index=1, options=('1', '2', '3'), value='2')

# %%
#radio buttons
widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-content'}, # If the items' names are long
    description='Pizza topping:',
    disabled=False
)
# Out:
# RadioButtons(description='Pizza topping:', options=('pepperoni', 'pineapple', 'anchovies'), value='pepperoni')
