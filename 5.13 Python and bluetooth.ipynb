# %% [markdown]
# # Python and bluetooth
#
# In this notebook we will connect a device to a
#
# Pybluez =
#
# ### Contents
# 0. Install packages
# 1. Connecting
# 2.
#
#
# ### Sources
# -

# %% [markdown]
# ## Devices and packages
#
#
# | Package | Windows | Linux | MacOS | Link
# | --- | --- | --- | --- | --- |
# | pybluez | Yes | Yes | Yes | https://pybluez.github.io/ |
# | pybluez2 | Yes | Yes | No |
# | blueutil | No | No | Yes | brew install blueutil https://github.com/toy/blueutil

# %%
pip install pybluez2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# simple inquiry example
import bluetooth

nearby_devices = bluetooth.discover_devices(lookup_names=True)
print("Found {} devices.".format(len(nearby_devices)))

for addr, name in nearby_devices:
    print("  {} - {}".format(addr, name))
# Out:
# /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/bluetooth/macos/discovery.py:51: ObjCSuperWarning: Objective-C subclass uses super(), but super is not objc.super
#   class DeviceInquiryDelegate(NSObject):
# /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/bluetooth/macos/btsocket/delegate.py:26: ObjCSuperWarning: Objective-C subclass uses super(), but super is not objc.super
#   class BluezBluetoothChannelDelegate(NSObject):
# /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/bluetooth/macos/btsocket/btsocket.py:655: ObjCSuperWarning: Objective-C subclass uses super(), but super is not objc.super
#   class ChannelEventListener(Foundation.NSObject):
# /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/bluetooth/macos/btsocket/btsocket.py:728: ObjCSuperWarning: Objective-C subclass uses super(), but super is not objc.super
#   class ChannelServerEventListener(Foundation.NSObject):
# ...

# %%
pip install PyBluez-updated
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [9 lines of output]
#       xcode-select: error: tool 'xcodebuild' requires Xcode, but active developer directory '/Library/Developer/CommandLineTools' is a command line tools instance
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-u5m6jo8j/pybluez-updated_99c46fb90d9a4747867c555c9f29b36b/setup.py", line 59, in <module>
#           subprocess.check_call([
#         File "/Users/michielbontenbal/anaconda3/lib/python3.10/subprocess.py", line 369, in check_call
#           raise CalledProcessError(retcode, cmd)
# ...

# %%
# simple inquiry example
import bluetooth

nearby_devices = bluetooth.discover_devices(lookup_names=True)
print("Found {} devices.".format(len(nearby_devices)))

for addr, name in nearby_devices:
    print("  {} - {}".format(addr, name))
# Out:
# /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages/pygments/regexopt.py:77: UninitializedDeallocWarning: leaking an uninitialized object of type DeviceInquiryDelegate
#   '|'.join(regex_opt_inner(list(group[1]), '')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 # simple inquiry example
#       2 import bluetooth
# ----> 4 nearby_devices = bluetooth.discover_devices(lookup_names=True)
#       5 print("Found {} devices.".format(len(nearby_devices)))
#       7 for addr, name in nearby_devices:
#
# File ~/anaconda3/lib/python3.10/site-packages/bluetooth/macos/__init__.py:10, in discover_devices(duration, flush_cache, lookup_names, lookup_class, device_id)
#       7 def discover_devices(duration=8, flush_cache=True, lookup_names=False,
#       8         lookup_class=False, device_id=-1):
# ...

# %%
# !bluetoothctl
# Out:
# zsh:1: command not found: bluetoothctl

# %% [markdown]
# ## Connecting to bluetooth using sockets
#
# source: https://www.youtube.com/watch?v=8pMaR-WUc6U

# %%
# a script to chat over bluetooth SERVER SIDE
import socket
server = socket.socket(socket.AF_BLUETOOTH, socket.SOCK_STREAM, socket.BTPROTO_RFCOMM)
server.bind(("YOUR MAC ADDRESS", 4))
server.listen(1)

client, addr = server.accept()

try:
    while True: 
        data = client.recv()
        
        if not data:
            break
        print(f"Message {data.decode('utf-8')}")
        message = input("Enter message")
        cliet.send(message.encode("utf-8"))
except OSError as e:
    pass

client.close()
server.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 # a script to chat over bluetooth SERVER SIDE
#       2 import socket
# ----> 3 server = socket.socket(socket.AF_BLUETOOTH, socket.SOCK_STREAM, socket.BTPROTO_RFCOMM)
#       4 server.bind(("YOUR MAC ADDRESS", 4))
#       5 server.listen(1)
#
# AttributeError: module 'socket' has no attribute 'AF_BLUETOOTH'

# %%
dir(socket)
# Out:
# ['AF_APPLETALK',
#  'AF_DECnet',
#  'AF_INET',
#  'AF_INET6',
#  'AF_IPX',
#  'AF_LINK',
#  'AF_ROUTE',
#  'AF_SNA',
#  'AF_SYSTEM',
#  'AF_UNIX',
#  'AF_UNSPEC',
#  'AI_ADDRCONFIG',
#  'AI_ALL',
#  'AI_CANONNAME',
#  'AI_DEFAULT',
#  'AI_MASK',
#  'AI_NUMERICHOST',
#  'AI_NUMERICSERV',
#  'AI_PASSIVE',
#  'AI_V4MAPPED',
#  'AI_V4MAPPED_CFG',
#  'AddressFamily',
#  'AddressInfo',
#  'CAPI',
#  'CMSG_LEN',
#  'CMSG_SPACE',
#  'EAGAIN',
#  'EAI_ADDRFAMILY',
#  'EAI_AGAIN',
#  'EAI_BADFLAGS',
#  'EAI_BADHINTS',
#  'EAI_FAIL',
#  'EAI_FAMILY',
#  'EAI_MAX',
#  'EAI_MEMORY',
#  'EAI_NODATA',
#  'EAI_NONAME',
#  'EAI_OVERFLOW',
#  'EAI_PROTOCOL',
#  'EAI_SERVICE',
#  'EAI_SOCKTYPE',
#  'EAI_SYSTEM',
#  'EBADF',
#  'EWOULDBLOCK',
#  'INADDR_ALLHOSTS_GROUP',
#  'INADDR_ANY',
#  'INADDR_BROADCAST',
#  'INADDR_LOOPBACK',
#  'INADDR_MAX_LOCAL_GROUP',
#  'INADDR_NONE',
#  'INADDR_UNSPEC_GROUP',
#  'IPPORT_RESERVED',
#  'IPPORT_USERRESERVED',
#  'IPPROTO_AH',
#  'IPPROTO_DSTOPTS',
# ...
