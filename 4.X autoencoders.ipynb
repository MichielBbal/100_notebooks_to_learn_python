# %% [markdown]
# # Autoencoder

# %% [markdown]
# In dit notebook maken en trainen we een autoencoder voor de `mnist` dataset.
# We gebruiken deze vervolgens om nieuw afbeeldingen van handgeschreven letters te genereren.

# %% [markdown]
# De code in dit voorbeeld is gebaseerd op de code uit hoofdstuk 3 van *Generative Deep Learning* van David Forester, O'Reilly Media, 2019 en op hoofdstuk 8 van *Deep Learning with Python* door François Chollet, Manning, 2018.

# %%
import numpy as np

from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam

# %% [markdown]
# ### verover de data

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_train = x_train.reshape(x_train.shape + (1,))
    
x_test = x_test.astype('float32') / 255.
x_test = x_test.reshape(x_test.shape + (1,))

# %% [markdown]
# Afbeeldingen zijn 28x28 pixels in zwart/wit (1 kanaal).
#
# We projecteren iedere afbeelding naar 2 getallen.

# %%
input_dim = (28, 28, 1)
z_dim = 2

# %% [markdown]
# ### Encoder

# %% [markdown]
# We maken eerst een `encoder`. We maken hiervoor gebruik van de functionele notatie van Keras. De `encoder` is in essentie een CNN dat een afbeelding terugbrengt tot twee getallen.

# %%
encoder_input = Input(input_dim, name = 'encoder_input')

x = Conv2D(filters = 32,
           kernel_size = 3,
           padding = 'same',
           name = 'encoder_conv_1')(encoder_input)
x = LeakyReLU()(x)

x = Conv2D(filters = 64,
           kernel_size = 3,
           strides = (2,2),
           padding = 'same',
           name = 'encoder_conv_2')(x)
x = LeakyReLU()(x)

x = Conv2D(filters = 64,
           kernel_size = 3,
           strides = (2,2),
           padding = 'same',
           name = 'encoder_conv_3')(x)
x = LeakyReLU()(x)

x = Conv2D(filters = 64,
           kernel_size = 3,
           padding = 'same',
           name = 'encoder_conv_4')(x)
x = LeakyReLU()(x)

shape_before_flattening = K.int_shape(x)[1:]

x = Flatten()(x)

encoder_output = Dense(z_dim, name = 'encoder_output')(x)

encoder = Model(encoder_input, encoder_output)

# %% [markdown]
# Bestudeer bovenstaande code en maak vervolgens een `summary` van het model. Komt deze samenvatting overeen met jouw verwachtingen?

# %%
encoder.summary()
# Out:
# Model: "model_66"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 28, 28, 1)]       0
#
#  encoder_conv_1 (Conv2D)     (None, 28, 28, 32)        320
#
#  leaky_re_lu_167 (LeakyReLU)  (None, 28, 28, 32)       0
#
#  encoder_conv_2 (Conv2D)     (None, 14, 14, 64)        18496
#
#  leaky_re_lu_168 (LeakyReLU)  (None, 14, 14, 64)       0
#
#  encoder_conv_3 (Conv2D)     (None, 7, 7, 64)          36928
#
#  leaky_re_lu_169 (LeakyReLU)  (None, 7, 7, 64)         0
#
#  encoder_conv_4 (Conv2D)     (None, 7, 7, 64)          36928
#
#  leaky_re_lu_170 (LeakyReLU)  (None, 7, 7, 64)         0
#
#  flatten_22 (Flatten)        (None, 3136)              0
#
#  encoder_output (Dense)      (None, 2)                 6274
#
# =================================================================
# Total params: 98,946
# Trainable params: 98,946
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Decoder

# %% [markdown]
# Nu maken we een `decoder`. Deze vertaalt een representatie bestaande uit twee getallen naar een afbeelding.
# Hiervoor gebruiken we `Conv2DTranspose` lagen.

# %%
decoder_input = Input((z_dim,), name = 'decoder_input')

x = Dense(np.prod(shape_before_flattening))(decoder_input)
x = Reshape(shape_before_flattening)(x) # van een dense vector naar de vorm van een afbeelding

x = Conv2DTranspose(filters = 64,
                kernel_size = 3,
                padding = 'same',
                name = 'decoder_conv_t_1')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters = 64,
                kernel_size = 3,
                strides = (2,2),
                padding = 'same',
                name = 'decoder_conv_t_2')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters = 32,
                kernel_size = 3,
                strides = (2,2),
                padding = 'same',
                name = 'decoder_conv_t_3')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters = 1,
                kernel_size = 3,
                padding = 'same',
                name = 'decoder_conv_t_4')(x)
x = LeakyReLU()(x)

decoder_output = Activation('sigmoid')(x)

decoder = Model(decoder_input, decoder_output)

# %% [markdown]
# Bestudeer bovenstaande code en maak vervolgens een `summary`. Merk op dat de output van de laatste laag de afmetingen heeft van een afbeelding uit de `mnist` dataset. De `decoder` is een gespiegelde versie van de `encoder`, dit is echter niet noodzakelijk, de enige eis is dat het netwerk op basis van twee getallen een afbeelding kan genereren.

# %%
decoder.summary()
# Out:
# Model: "model_67"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense_21 (Dense)            (None, 3136)              9408
#
#  reshape_22 (Reshape)        (None, 7, 7, 64)          0
#
#  decoder_conv_t_1 (Conv2DTra  (None, 7, 7, 64)         36928
#  nspose)
#
#  leaky_re_lu_171 (LeakyReLU)  (None, 7, 7, 64)         0
#
#  decoder_conv_t_2 (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  leaky_re_lu_172 (LeakyReLU)  (None, 14, 14, 64)       0
#
#  decoder_conv_t_3 (Conv2DTra  (None, 28, 28, 32)       18464
#  nspose)
#
#  leaky_re_lu_173 (LeakyReLU)  (None, 28, 28, 32)       0
#
#  decoder_conv_t_4 (Conv2DTra  (None, 28, 28, 1)        289
#  nspose)
#
#  leaky_re_lu_174 (LeakyReLU)  (None, 28, 28, 1)        0
#
#  activation_16 (Activation)  (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### De volledige autoencoder

# %% [markdown]
# De autoencoder koppelt de `encoder` en de `decoder`. Door deze samen te trainen en als loss functie de *mean squared error* tussen de originele afbeelding (input van de encoder) en de output van de decoder te nemen, optimaliseert de autoencoder de gewichten van beide onderdelen voor het reconstrueren van afbeeldingen.

# %%
autoencoder = Model(encoder_input, decoder(encoder_output))

# %% [markdown]
# Compileer en train de `autoencoder`.

# %%
learning_rate = 0.0005

optimizer = Adam(learning_rate = learning_rate)

def r_loss(y_true, y_pred):
    return K.mean(K.square(y_true - y_pred), axis = [1,2,3])

autoencoder.compile(optimizer = optimizer, loss = r_loss)

# %% [markdown]
# Merk op dat in onderstaande code de labels gelijk zijn aan de inputs.

# %%
subset = 3000

autoencoder.fit(x = x_train[:subset], y = x_train[:subset], batch_size = 32, epochs = 20, shuffle = True)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 3s 30ms/step - loss: 0.1371
# Epoch 2/20
# 94/94 [==============================] - 3s 31ms/step - loss: 0.0659
# Epoch 3/20
# 94/94 [==============================] - 3s 33ms/step - loss: 0.0579
# Epoch 4/20
# 94/94 [==============================] - 3s 33ms/step - loss: 0.0561
# Epoch 5/20
# 94/94 [==============================] - 3s 36ms/step - loss: 0.0552
# Epoch 6/20
# 94/94 [==============================] - 3s 29ms/step - loss: 0.0544
# Epoch 7/20
# 94/94 [==============================] - 3s 28ms/step - loss: 0.0537
# Epoch 8/20
# 94/94 [==============================] - 3s 33ms/step - loss: 0.0530
# Epoch 9/20
# 94/94 [==============================] - 3s 34ms/step - loss: 0.0524
# Epoch 10/20
# 94/94 [==============================] - 3s 28ms/step - loss: 0.0518
# Epoch 11/20
# 94/94 [==============================] - 3s 28ms/step - loss: 0.0511
# Epoch 12/20
# 94/94 [==============================] - 3s 28ms/step - loss: 0.0505
# Epoch 13/20
# 94/94 [==============================] - 3s 31ms/step - loss: 0.0499
# Epoch 14/20
# 94/94 [==============================] - 3s 29ms/step - loss: 0.0494
# Epoch 15/20
# 94/94 [==============================] - 3s 33ms/step - loss: 0.0489
# Epoch 16/20
# 94/94 [==============================] - 3s 30ms/step - loss: 0.0486
# Epoch 17/20
# 94/94 [==============================] - 3s 30ms/step - loss: 0.0481
# Epoch 18/20
# 94/94 [==============================] - 3s 30ms/step - loss: 0.0479
# Epoch 19/20
# 94/94 [==============================] - 2s 26ms/step - loss: 0.0475
# Epoch 20/20
# 94/94 [==============================] - 2s 26ms/step - loss: 0.0471

# %% [markdown]
# ### Reconstructie van originele afbeeldingen
#
# Laten we nu eens kijken wat voor resultaten de `autoencoder` oplevert. Om te beginnen kijken we hoe goed de `decoder` in staat is om afbeeldingen te reconstrueren.
#
# We selecteren willekeurige afbeeldingen uit de testset, coderen deze met de `encoder` en decoderen deze met de `decoder`.

# %%
import matplotlib.pyplot as plt

n = 10

# selecteer willekeurige afbeeldingen uit x_test
idx = np.random.choice(range(len(x_test)), n)
test_images = x_test[idx]

# vertaal met de encoder naar getallen
z_points = encoder.predict(test_images)

# vertaal de getallen met de decoder terug naar afbeeldingen
reconstr_images = decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n):
    img = test_images[i].reshape((28,28))
    ax = fig.add_subplot(2, n, i + 1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)   
    ax.imshow(img, cmap='gray_r')
    
for i in range(n):
    img = reconstr_images[i].reshape((28,28))
    ax = fig.add_subplot(2, n, i + n + 1)
    ax.axis('off')
    ax.imshow(img, cmap='gray_r')
# Out:
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 88ms/step

# %% [markdown]
# Bovenstaande plot laat op de bovenste rij de originele afbeeldingen zien en daaronder telkens de door de decoder gereconstrueerde afbeelding.
#
# Wat valt je op aan de reconstructies?

# %% [markdown]
# - Gereconstrueerde =  de afbeeldingen die door de decoder worden gegenereerd uit de gecomprimeerde representatie, met als doel om deze zo nauwkeurig mogelijk te laten lijken op de oorspronkelijke invoerafbeelding.
#
#
#     Wat opvalt aan de reconstructies is dat de gereconstrueerde afbeeldingen iets waziger zijn en minder scherp dan de originele afbeeldingen. Bepaalde cijfers kloppen ook niet, bijv. 2, 7 & 9
#
# ---

# %% [markdown]
# Om een beter beeld te krijgen van het gedrag van de autoencoder, plotten we de outputs van de encoder (de 'z-waarden') voor een deel van de testset. De kleur van een punt geeft het correcte label weer.
#
# Daarnaast selecteren we alvast een aantal willekeurige punten (dus een combinatie van twee willekeurige getallen) die we dadelijk gaan gebruiken om volledig nieuwe afbeeldingen te genereren. Deze punten worden in het rood weergegeven.

# %%
n = 5000
grid_size = 10
grid_depth = 3
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n)
test_images = x_test[example_idx]
test_labels = y_test[example_idx]

z_points = encoder.predict(test_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize = (figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap = 'rainbow' , c = test_labels, alpha = 0.5, s = 2)
plt.colorbar()

# willekeurige punten
x = np.random.uniform(min_x,max_x, size = grid_size * grid_depth)
y = np.random.uniform(min_y,max_y, size = grid_size * grid_depth)
z_grid = np.array(list(zip(x, y)))

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()
# Out:
# 157/157 [==============================] - 1s 5ms/step

# %% [markdown]
# Wat valt je op aan bovenstaande plot met betrekking tot de verdeling van de labels?
#
# - Ik zie verschillende kleuren labels in hetzelfde gebied van de grafiek (punten (0,0) tot (5,5)). Overlap of verband tussen de z-waarden van afbeeldingen met verschillende       labels. Het kan betekenen dat de afbeeldingen met verschillende labels bepaalde eigenschappen gemeen hebben zoals de vorm van de geschreven cijfers.
#
# Wat valt je op aan bovenstaande plot met betrekking tot de willekeurig geselecteerde punten?
#
# - Ik zie een paar rode punten niet dichtbij de gekleurde punten, hierdoor denk ik dat het model moeite heeft om accurate afbeeldingen te genereren op basis van deze punten.

# %% [markdown]
# We gebruiken nu de `decoder` om op basis van de willekeurig gegenereerde punten volledig nieuwe afbeeldingen te genereren en plotten deze afbeeldingen.

# %%
reconst = decoder.predict(z_grid)

figsize = 15
fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# Wat valt je op aan deze afbeeldingen?

# %% [markdown]
# - Ik zie dat bepaalde afbeeldingen niet erg duidelijke zijn en dat sommige vormen veel voorkomen.

# %% [markdown]
# Varieer nu eens met het aantal lagen en filters in de `encoder` en `decoder`. Kun je de `decoder` een volledig andere vorm geven dan de `encoder`? Hoe beïnvloed dit het resultaat?

# %% [markdown]
# ## Encoder

# %% [markdown]
# - De tweede convolutielaag heeft 64 filters met een strides van (2,2), terwijl in de originele voorbeeld de tweede convolutielaag 64 filters heeft zonder strides.
# - De derde convolutionele laag heeft 128 filters met een strides van (2,2), terwijl in de originele voorbeeld de derde convolutielaag 64 filters heeft met een strides van (2,2).
# - De vierde convolutielaag heeft 256 filters zonder strides, terwijl in de originele voorbeeld de vierde convolutielaag 64 filters zonder strides heeft.

# %%
encoder_input = Input(input_dim, name='encoder_input')

x = Conv2D(filters=32, 
           kernel_size=3, 
           padding='same', 
           name='encoder_conv_1')(encoder_input)
x = LeakyReLU()(x)

x = Conv2D(filters=64, 
           kernel_size=3, 
           strides=(2,2), 
           padding='same', 
           name='encoder_conv_2')(x)
x = LeakyReLU()(x)

x = Conv2D(filters=128, 
           kernel_size=3, 
           strides=(2,2), 
           padding='same',
             name='encoder_conv_3')(x)
x = LeakyReLU()(x)

x = Conv2D(filters=256, 
           kernel_size=3, 
           padding='same',
             name='encoder_conv_4')(x)
x = LeakyReLU()(x)

shape_before_flattening = K.int_shape(x)[1:]

x = Flatten()(x)

encoder_output = Dense(z_dim, name='encoder_output')(x)

encoder = Model(encoder_input, encoder_output)

# %%
encoder.summary()
# Out:
# Model: "model_69"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 28, 28, 1)]       0
#
#  encoder_conv_1 (Conv2D)     (None, 28, 28, 32)        320
#
#  leaky_re_lu_175 (LeakyReLU)  (None, 28, 28, 32)       0
#
#  encoder_conv_2 (Conv2D)     (None, 14, 14, 64)        18496
#
#  leaky_re_lu_176 (LeakyReLU)  (None, 14, 14, 64)       0
#
#  encoder_conv_3 (Conv2D)     (None, 7, 7, 128)         73856
#
#  leaky_re_lu_177 (LeakyReLU)  (None, 7, 7, 128)        0
#
#  encoder_conv_4 (Conv2D)     (None, 7, 7, 256)         295168
#
#  leaky_re_lu_178 (LeakyReLU)  (None, 7, 7, 256)        0
#
#  flatten_23 (Flatten)        (None, 12544)             0
#
#  encoder_output (Dense)      (None, 2)                 25090
#
# =================================================================
# Total params: 412,930
# Trainable params: 412,930
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Decoder

# %% [markdown]
# - De eerste getransponeerde convolutielaag 128 filters met een strides van (2,2), terwijl in de originele voorbeeld de eerste getransponeerde convolutielaag 64 filters heeft met een strides van (2,2).
# - De tweede getransponeerde convolutionele laag heeft 64 filters zonder strides, terwijl in de originele voorbeeld  de tweede getransponeerde convolutionele laag 64 filters heeft met een strides van (2,2).

# %%
decoder_input = Input((z_dim,), name='decoder_input')

x = Dense(np.prod(shape_before_flattening))(decoder_input)
x = Reshape(shape_before_flattening)(x) # van een dense vector naar de vorm van een afbeelding

x = Conv2DTranspose(filters=128, 
                    kernel_size=3, 
                    strides=(2,2), 
                    padding='same', 
                    name='decoder_conv_t_1')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters=64, 
                    kernel_size=3, 
                    padding='same', 
                    name='decoder_conv_t_2')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(filters=32, 
                    kernel_size=3, 
                    strides=(2,2), 
                    padding='same', 
                    name='decoder_conv_t_3')(x)
x = LeakyReLU()(x)

decoder_output = Conv2DTranspose(filters=1, 
                                  kernel_size=3, 
                                  padding='same', 
                                  activation='sigmoid', 
                                  name='decoder_output')(x)

decoder = Model(decoder_input, decoder_output)

# %%
decoder.summary()
# Out:
# Model: "model_70"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense_22 (Dense)            (None, 12544)             37632
#
#  reshape_23 (Reshape)        (None, 7, 7, 256)         0
#
#  decoder_conv_t_1 (Conv2DTra  (None, 14, 14, 128)      295040
#  nspose)
#
#  leaky_re_lu_179 (LeakyReLU)  (None, 14, 14, 128)      0
#
#  decoder_conv_t_2 (Conv2DTra  (None, 14, 14, 64)       73792
#  nspose)
#
#  leaky_re_lu_180 (LeakyReLU)  (None, 14, 14, 64)       0
#
#  decoder_conv_t_3 (Conv2DTra  (None, 28, 28, 32)       18464
#  nspose)
#
#  leaky_re_lu_181 (LeakyReLU)  (None, 28, 28, 32)       0
#
#  decoder_output (Conv2DTrans  (None, 28, 28, 1)        289
#  pose)
#
# =================================================================
# Total params: 425,217
# Trainable params: 425,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Autoencoder

# %%
autoencoder = Model(encoder_input, decoder(encoder_output))

# %%
learning_rate = 0.0005

optimizer = Adam(learning_rate = learning_rate)

def r_loss(y_true, y_pred):
    return K.mean(K.square(y_true - y_pred), axis = [1,2,3])

autoencoder.compile(optimizer = optimizer, loss = r_loss)

# %%
subset = 3000

autoencoder.fit(x = x_train[:subset], y = x_train[:subset], batch_size = 32, epochs = 20, shuffle = True)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 5s 46ms/step - loss: 0.0962
# Epoch 2/20
# 94/94 [==============================] - 5s 51ms/step - loss: 0.0569
# Epoch 3/20
# 94/94 [==============================] - 4s 47ms/step - loss: 0.0549
# Epoch 4/20
# 94/94 [==============================] - 4s 47ms/step - loss: 0.0538
# Epoch 5/20
# 94/94 [==============================] - 4s 47ms/step - loss: 0.0526
# Epoch 6/20
# 94/94 [==============================] - 5s 50ms/step - loss: 0.0516
# Epoch 7/20
# 94/94 [==============================] - 4s 45ms/step - loss: 0.0506
# Epoch 8/20
# 94/94 [==============================] - 5s 48ms/step - loss: 0.0497
# Epoch 9/20
# 94/94 [==============================] - 5s 48ms/step - loss: 0.0488
# Epoch 10/20
# 94/94 [==============================] - 5s 51ms/step - loss: 0.0483
# Epoch 11/20
# 94/94 [==============================] - 5s 55ms/step - loss: 0.0477
# Epoch 12/20
# 94/94 [==============================] - 4s 46ms/step - loss: 0.0470
# Epoch 13/20
# 94/94 [==============================] - 4s 45ms/step - loss: 0.0466
# Epoch 14/20
# 94/94 [==============================] - 4s 46ms/step - loss: 0.0463
# Epoch 15/20
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0461
# Epoch 16/20
# 94/94 [==============================] - 5s 55ms/step - loss: 0.0458
# Epoch 17/20
# 94/94 [==============================] - 5s 53ms/step - loss: 0.0453
# Epoch 18/20
# 94/94 [==============================] - 5s 52ms/step - loss: 0.0450
# Epoch 19/20
# 94/94 [==============================] - 5s 53ms/step - loss: 0.0449
# Epoch 20/20
# 94/94 [==============================] - 5s 53ms/step - loss: 0.0445

# %%
import matplotlib.pyplot as plt

n = 10

# selecteer willekeurige afbeeldingen uit x_test
idx = np.random.choice(range(len(x_test)), n)
test_images = x_test[idx]

# vertaal met de encoder naar getallen
z_points = encoder.predict(test_images)

# vertaal de getallen met de decoder terug naar afbeeldingen
reconstr_images = decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n):
    img = test_images[i].reshape((28,28))
    ax = fig.add_subplot(2, n, i + 1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)   
    ax.imshow(img, cmap='gray_r')
    
for i in range(n):
    img = reconstr_images[i].reshape((28,28))
    ax = fig.add_subplot(2, n, i + n + 1)
    ax.axis('off')
    ax.imshow(img, cmap='gray_r')
# Out:
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 81ms/step

# %%
n = 5000
grid_size = 10
grid_depth = 3
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n)
test_images = x_test[example_idx]
test_labels = y_test[example_idx]

z_points = encoder.predict(test_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize = (figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap = 'rainbow' , c = test_labels, alpha = 0.5, s = 2)
plt.colorbar()

# willekeurige punten
x = np.random.uniform(min_x,max_x, size = grid_size * grid_depth)
y = np.random.uniform(min_y,max_y, size = grid_size * grid_depth)
z_grid = np.array(list(zip(x, y)))

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()
# Out:
# 157/157 [==============================] - 2s 10ms/step

# %%
reconst = decoder.predict(z_grid)

figsize = 15
fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
# Out:
# 1/1 [==============================] - 0s 31ms/step
