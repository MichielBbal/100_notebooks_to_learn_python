# %% [markdown]
# # Misc & other stuff

# %% [markdown]
# ## x. Pyfiglet
#
# Pyfiglet is an implementation of figlet, that can be used to creat ASCII art.
#
# source: https://github.com/pwaller/pyfiglet

# %%
pip install pyfiglet
# Out:
# Requirement already satisfied: pyfiglet in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (0.8.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyfiglet import Figlet

# %%
f = Figlet(font='slant')

# %%
f = Figlet(font='slant')
print(f.renderText('Silly walks'))
# Out:
#    _____ _ ____                        ____
#   / ___/(_) / /_  __   _      ______ _/ / /_______
#   \__ \/ / / / / / /  | | /| / / __ `/ / //_/ ___/
#  ___/ / / / / /_/ /   | |/ |/ / /_/ / / ,< (__  )
# /____/_/_/_/\__, /    |__/|__/\__,_/_/_/|_/____/
#            /____/

# %% [markdown]
# ## x. Flightradar
#
#
# source: https://github.com/mkorkmaz/flightradar24

# %%
pip install flightradar24
# Out:
# Collecting flightradar24
#   Using cached flightradar24-0.3.1-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: requests in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from flightradar24) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->flightradar24) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->flightradar24) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->flightradar24) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->flightradar24) (2021.10.8)
# Installing collected packages: flightradar24
# Successfully installed flightradar24-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import flightradar24
fr = flightradar24.Api()
airports = fr.get_airports()
airports['rows']
# Out:
# [{'name': 'A Coruna Airport',
#   'iata': 'LCG',
#   'icao': 'LECO',
#   'lat': 43.302059,
#   'lon': -8.37725,
#   'country': 'Spain',
#   'alt': 326},
#  {'name': 'Aachen Merzbruck Airport',
#   'iata': 'AAH',
#   'icao': 'EDKA',
#   'lat': 50.823051,
#   'lon': 6.186111,
#   'country': 'Germany',
#   'alt': 623},
#  {'name': 'Aalborg Airport',
#   'iata': 'AAL',
#   'icao': 'EKYT',
#   'lat': 57.092781,
#   'lon': 9.849164,
#   'country': 'Denmark',
#   'alt': 10},
#  {'name': 'Aarhus Airport',
#   'iata': 'AAR',
#   'icao': 'EKAH',
#   'lat': 56.300011,
#   'lon': 10.619,
#   'country': 'Denmark',
#   'alt': 82},
#  {'name': 'Aarhus Sea Airport',
#   'iata': 'QEA',
#   'icao': 'EKAC',
#   'lat': 56.151993,
#   'lon': 10.247725,
#   'country': 'Denmark',
#   'alt': 1},
#  {'name': 'Aasiaat Airport',
#   'iata': 'JEG',
#   'icao': 'BGAA',
#   'lat': 68.72184,
#   'lon': -52.784698,
#   'country': 'Greenland',
#   'alt': 74},
#  {'name': 'Abadan Airport',
#   'iata': 'ABD',
#   'icao': 'OIAA',
#   'lat': 30.371111,
#   'lon': 48.228329,
#   'country': 'Iran',
#   'alt': 19},
#  {'name': 'Abakan International Airport',
#   'iata': 'ABA',
#   'icao': 'UNAA',
#   'lat': 53.740002,
#   'lon': 91.385002,
#   'country': 'Russia',
#   'alt': 831},
#  {'name': 'Abbotsford International Airport',
#   'iata': 'YXX',
#   'icao': 'CYXX',
#   'lat': 49.025269,
#   'lon': -122.360001,
#   'country': 'Canada',
#   'alt': 195},
#  {'name': 'Aberdeen International Airport',
#   'iata': 'ABZ',
#   'icao': 'EGPD',
#   'lat': 57.201939,
#   'lon': -2.19777,
#   'country': 'United Kingdom',
#   'alt': 215},
#  {'name': 'Aberdeen Regional Airport',
#   'iata': 'ABR',
#   'icao': 'KABR',
#   'lat': 45.439999,
#   'lon': -98.419998,
#   'country': 'United States',
#   'alt': 1302},
#  {'name': 'Abha Regional Airport',
#   'iata': 'AHB',
#   'icao': 'OEAB',
#   'lat': 18.24036,
#   'lon': 42.65662,
#   'country': 'Saudi Arabia',
#   'alt': 6858},
#  {'name': 'Abidjan Port Bouet Airport',
#   'iata': 'ABJ',
#   'icao': 'DIAP',
#   'lat': 5.261386,
#   'lon': -3.92629,
#   'country': "Cote D'ivoire (Ivory Coast)",
#   'alt': 21},
#  {'name': 'Abilene Regional Airport',
#   'iata': 'ABI',
#   'icao': 'KABI',
#   'lat': 32.411301,
#   'lon': -99.681801,
#   'country': 'United States',
#   'alt': 1790},
#  {'name': 'Abingdon Virginia Highlands Airport',
#   'iata': 'VJI',
#   'icao': 'KVJI',
#   'lat': 36.686111,
#   'lon': -82.033333,
#   'country': 'United States',
#   'alt': 2088},
#  {'name': 'Abu Dhabi Al Bateen Executive Airport',
#   'iata': 'AZI',
#   'icao': 'OMAD',
#   'lat': 24.428329,
#   'lon': 54.45808,
#   'country': 'United Arab Emirates',
#   'alt': 16},
#  {'name': 'Abu Dhabi Al Dhafra Air Base',
#   'iata': 'DHF',
#   'icao': 'OMAM',
#   'lat': 24.248199,
#   'lon': 54.547699,
#   'country': 'United Arab Emirates',
#   'alt': 77},
#  {'name': 'Abu Dhabi International Airport',
#   'iata': 'AUH',
#   'icao': 'OMAA',
#   'lat': 24.43297,
#   'lon': 54.651131,
#   'country': 'United Arab Emirates',
#   'alt': 88},
#  {'name': 'Abu Musa Island Airport',
#   'iata': 'AEU',
#   'icao': 'OIBA',
#   'lat': 25.8757,
#   'lon': 55.033001,
#   'country': 'Iran',
#   'alt': 23},
#  {'name': 'Abu Simbel Airport',
#   'iata': 'ABS',
#   'icao': 'HEBL',
#   'lat': 22.37595,
#   'lon': 31.611719,
#   'country': 'Egypt',
#   'alt': 616},
#  {'name': 'Abuja Nnamdi Azikiwe International Airport',
#   'iata': 'ABV',
#   'icao': 'DNAA',
#   'lat': 9.006792,
#   'lon': 7.263172,
#   'country': 'Nigeria',
#   'alt': 1123},
#  {'name': 'Acapulco International Airport',
#   'iata': 'ACA',
#   'icao': 'MMAA',
#   'lat': 16.757059,
#   'lon': -99.753899,
#   'country': 'Mexico',
#   'alt': 16},
#  {'name': 'Accra Kotoka International Airport',
#   'iata': 'ACC',
#   'icao': 'DGAA',
#   'lat': 5.605186,
#   'lon': -0.16678,
#   'country': 'Ghana',
#   'alt': 205},
#  {'name': 'Ada Municipal Airport',
#   'iata': 'ADT',
#   'icao': 'KADH',
#   'lat': 34.804298,
#   'lon': -96.671303,
#   'country': 'United States',
#   'alt': 1016},
#  {'name': 'Adak Airport',
#   'iata': 'ADK',
#   'icao': 'PADK',
#   'lat': 51.87796,
#   'lon': -176.645996,
#   'country': 'United States',
#   'alt': 18},
#  {'name': 'Adampur Airport',
#   'iata': 'AIP',
#   'icao': 'VIAX',
#   'lat': 31.433056,
#   'lon': 75.760559,
#   'country': 'India',
#   'alt': 776},
#  {'name': 'Adana Sakirpasa Airport',
#   'iata': 'ADA',
#   'icao': 'LTAF',
#   'lat': 36.982159,
#   'lon': 35.28038,
#   'country': 'Turkey',
#   'alt': 65},
#  {'name': 'Addis Ababa Bole Airport',
#   'iata': 'ADD',
#   'icao': 'HAAB',
#   'lat': 8.977889,
#   'lon': 38.799309,
#   'country': 'Ethiopia',
#   'alt': 7656},
#  {'name': 'Adelaide Airport',
#   'iata': 'ADL',
#   'icao': 'YPAD',
#   'lat': -34.945,
#   'lon': 138.530502,
#   'country': 'Australia',
#   'alt': 20},
#  {'name': 'Aden International Airport',
#   'iata': 'ADE',
#   'icao': 'OYAA',
#   'lat': 12.82954,
#   'lon': 45.02879,
#   'country': 'Yemen',
#   'alt': 7},
#  {'name': 'Adiyaman Airport',
#   'iata': 'ADF',
#   'icao': 'LTCP',
#   'lat': 37.731361,
#   'lon': 38.468929,
#   'country': 'Turkey',
#   'alt': 2216},
#  {'name': 'Adrar Airport',
#   'iata': 'AZR',
#   'icao': 'DAUA',
#   'lat': 27.83758,
#   'lon': -0.18641,
#   'country': 'Algeria',
#   'alt': 919},
#  {'name': 'Adrian Lenawee County Airport',
#   'iata': 'ADG',
#   'icao': 'KADG',
#   'lat': 41.86607,
#   'lon': -84.078293,
#   'country': 'United States',
#   'alt': 798},
#  {'name': 'Afton Municipal Airport',
#   'iata': 'AFO',
#   'icao': 'KAFO',
#   'lat': 42.711201,
#   'lon': -110.942001,
#   'country': 'United States',
#   'alt': 6221},
#  {'name': 'Agades Mano Dayak International Airport',
#   'iata': 'AJY',
#   'icao': 'DRZA',
#   'lat': 16.96599,
#   'lon': 8.000114,
#   'country': 'Niger',
#   'alt': 1657},
#  {'name': 'Agadir Al Massira Airport',
#   'iata': 'AGA',
#   'icao': 'GMAD',
#   'lat': 30.324989,
#   'lon': -9.41306,
#   'country': 'Morocco',
#   'alt': 250},
#  {'name': 'Agartala Airport',
#   'iata': 'IXA',
#   'icao': 'VEAT',
#   'lat': 23.886971,
#   'lon': 91.240448,
#   'country': 'India',
#   'alt': 46},
#  {'name': 'Agatti Airport',
#   'iata': 'AGX',
#   'icao': 'VOAT',
#   'lat': 10.82365,
#   'lon': 72.176041,
#   'country': 'India',
#   'alt': 14},
#  {'name': 'Agen La Garenne Airport',
#   'iata': 'AGF',
#   'icao': 'LFBA',
#   'lat': 44.174709,
#   'lon': 0.590619,
#   'country': 'France',
#   'alt': 204},
#  {'name': 'Aghajari Airport',
#   'iata': 'AKW',
#   'icao': 'OIAG',
#   'lat': 30.7444,
#   'lon': 49.6772,
#   'country': 'Iran',
#   'alt': 88},
#  {'name': 'Agra Airport',
#   'iata': 'AGR',
#   'icao': 'VIAG',
#   'lat': 27.15583,
#   'lon': 77.960892,
#   'country': 'India',
#   'alt': 551},
#  {'name': 'Agri Airport',
#   'iata': 'AJI',
#   'icao': 'LTCO',
#   'lat': 39.65456,
#   'lon': 43.027149,
#   'country': 'Turkey',
#   'alt': 5462},
#  {'name': 'Agua Boa Airport',
#   'iata': 'GGB',
#   'icao': 'SWHP',
#   'lat': -14.019444,
#   'lon': -52.152222,
#   'country': 'Brazil',
#   'alt': 1506},
#  {'name': 'Aguachica Hacaritama Airport',
#   'iata': 'HAY',
#   'icao': 'SKAG',
#   'lat': 8.246203,
#   'lon': -73.579628,
#   'country': 'Colombia',
#   'alt': 531},
#  {'name': 'Aguadilla Rafael Hernandez Airport',
#   'iata': 'BQN',
#   'icao': 'TJBQ',
#   'lat': 18.49486,
#   'lon': -67.129402,
#   'country': 'Puerto Rico',
#   'alt': 237},
#  {'name': 'Aguascalientes International Airport',
#   'iata': 'AGU',
#   'icao': 'MMAS',
#   'lat': 21.705549,
#   'lon': -102.317001,
#   'country': 'Mexico',
#   'alt': 6112},
#  {'name': 'Ahe Airport',
#   'iata': 'AHE',
#   'icao': 'NTHE',
#   'lat': -14.42759,
#   'lon': -146.255981,
#   'country': 'French Polynesia',
#   'alt': 11},
#  {'name': 'Ahmedabad International Airport',
#   'iata': 'AMD',
#   'icao': 'VAAH',
#   'lat': 23.07724,
#   'lon': 72.634651,
#   'country': 'India',
#   'alt': 189},
#  {'name': 'Ahwaz International Airport',
#   'iata': 'AWZ',
#   'icao': 'OIAW',
#   'lat': 31.337429,
#   'lon': 48.761951,
#   'country': 'Iran',
#   'alt': 66},
#  {'name': 'Aiken Municipal Airport',
#   'iata': 'AIK',
#   'icao': 'KAIK',
#   'lat': 33.649399,
#   'lon': -81.684998,
#   'country': 'United States',
#   'alt': 528},
#  {'name': 'Airai Roman Tmetuchl International Airport',
#   'iata': 'ROR',
#   'icao': 'PTRO',
#   'lat': 7.367303,
#   'lon': 134.544205,
#   'country': 'Palau',
#   'alt': 176},
#  {'name': 'Aitutaki Airport',
#   'iata': 'AIT',
#   'icao': 'NCAI',
#   'lat': -18.8309,
#   'lon': -159.764008,
#   'country': 'Cook Islands',
#   'alt': 14},
#  {'name': 'Aix-en-Provence Airport',
#   'iata': 'QXB',
#   'icao': 'LFMA',
#   'lat': 43.50528,
#   'lon': 5.367222,
#   'country': 'France',
#   'alt': 368},
#  {'name': 'Aizawl Lengpui Airport',
#   'iata': 'AJL',
#   'icao': 'VELP',
#   'lat': 23.838442,
#   'lon': 92.620361,
#   'country': 'India',
#   'alt': 1001},
#  {'name': 'Ajaccio Napoleon Bonaparte Airport',
#   'iata': 'AJA',
#   'icao': 'LFKJ',
#   'lat': 41.923882,
#   'lon': 8.8025,
#   'country': 'France',
#   'alt': 16},
#  {'name': 'Akiak Airport',
#   'iata': 'AKI',
#   'icao': 'PFAK',
#   'lat': 60.902901,
#   'lon': -161.231003,
#   'country': 'United States',
#   'alt': 30},
#  {'name': 'Akita Airport',
#   'iata': 'AXT',
#   'icao': 'RJSK',
#   'lat': 39.615551,
#   'lon': 140.218597,
#   'country': 'Japan',
#   'alt': 313},
#  {'name': 'Aklavik Airport',
#   'iata': 'LAK',
#   'icao': 'CYKD',
#   'lat': 68.223297,
#   'lon': -135.005997,
#   'country': 'Canada',
#   'alt': 23},
#  {'name': 'Akron Canton Airport',
#   'iata': 'CAK',
#   'icao': 'KCAK',
#   'lat': 40.91608,
#   'lon': -81.442101,
#   'country': 'United States',
#   'alt': 1225},
#  {'name': 'Akron Fulton International Airport',
#   'iata': 'AKC',
#   'icao': 'KAKR',
#   'lat': 41.037498,
#   'lon': -81.466904,
#   'country': 'United States',
#   'alt': 1067},
#  {'name': 'Aksu Airport',
#   'iata': 'AKU',
#   'icao': 'ZWAK',
#   'lat': 41.262501,
#   'lon': 80.291664,
#   'country': 'China',
#   'alt': 3816},
#  {'name': 'Aktau Airport',
#   'iata': 'SCO',
#   'icao': 'UATE',
#   'lat': 43.86005,
#   'lon': 51.091969,
#   'country': 'Kazakhstan',
#   'alt': 73},
#  {'name': 'Aktion National Airport',
#   'iata': 'PVK',
#   'icao': 'LGPZ',
#   'lat': 38.925461,
#   'lon': 20.76531,
#   'country': 'Greece',
#   'alt': 11},
#  {'name': 'Aktobe Airport',
#   'iata': 'AKX',
#   'icao': 'UATT',
#   'lat': 50.245831,
#   'lon': 57.206661,
#   'country': 'Kazakhstan',
#   'alt': 738},
#  {'name': 'Akulivik Airport',
#   'iata': 'AKV',
#   'icao': 'CYKO',
#   'lat': 60.818611,
#   'lon': -78.148613,
#   'country': 'Canada',
#   'alt': 75},
#  {'name': 'Akure Airport',
#   'iata': 'AKR',
#   'icao': 'DNAK',
#   'lat': 7.246739,
#   'lon': 5.301008,
#   'country': 'Nigeria',
#   'alt': 1100},
#  {'name': 'Akureyri Airport',
#   'iata': 'AEY',
#   'icao': 'BIAR',
#   'lat': 65.658607,
#   'lon': -18.072201,
#   'country': 'Iceland',
#   'alt': 6},
#  {'name': 'Al Ain International Airport',
#   'iata': 'AAN',
#   'icao': 'OMAL',
#   'lat': 24.26166,
#   'lon': 55.609161,
#   'country': 'United Arab Emirates',
#   'alt': 869},
#  {'name': 'Al Hoceima Cherif Al Idrissi Airport',
#   'iata': 'AHU',
#   'icao': 'GMTA',
#   'lat': 35.177101,
#   'lon': -3.83952,
#   'country': 'Morocco',
#   'alt': 95},
#  {'name': 'Al Najaf International Airport',
#   'iata': 'NJF',
#   'icao': 'ORNI',
#   'lat': 31.991667,
#   'lon': 44.404167,
#   'country': 'Iraq',
#   'alt': 108},
#  {'name': 'Al Udeid Air Base',
#   'iata': 'XJD',
#   'icao': 'OTBH',
#   'lat': 25.114941,
#   'lon': 51.316105,
#   'country': 'Qatar',
#   'alt': 130},
#  {'name': 'Al Ula  Airport',
#   'iata': 'ULH',
#   'icao': 'OEAO',
#   'lat': 26.480862,
#   'lon': 38.116653,
#   'country': 'Saudi Arabia',
#   'alt': 2017},
#  {'name': 'Al Wajh Airport',
#   'iata': 'EJH',
#   'icao': 'OEWJ',
#   'lat': 26.198334,
#   'lon': 36.476112,
#   'country': 'Saudi Arabia',
#   'alt': 66},
#  {'name': 'Al-Baha Domestic Airport',
#   'iata': 'ABT',
#   'icao': 'OEBA',
#   'lat': 20.296129,
#   'lon': 41.63427,
#   'country': 'Saudi Arabia',
#   'alt': 5486},
#  {'name': 'Al-Qamishli Airport',
#   'iata': 'KAC',
#   'icao': 'OSKL',
#   'lat': 37.031025,
#   'lon': 41.205559,
#   'country': 'Syria',
#   'alt': 1480},
#  {'name': 'Al-Qassim Regional Airport',
#   'iata': 'ELQ',
#   'icao': 'OEGS',
#   'lat': 26.30282,
#   'lon': 43.773911,
#   'country': 'Saudi Arabia',
#   'alt': 2126},
#  {'name': 'Alakanuk Airport',
#   'iata': 'AUK',
#   'icao': 'PAUK',
#   'lat': 62.683056,
#   'lon': -164.722198,
#   'country': 'United States',
#   'alt': 22},
#  {'name': 'Alamogordo White Sands Regional Airport',
#   'iata': 'ALM',
#   'icao': 'KALM',
#   'lat': 32.845833,
#   'lon': -105.985275,
#   'country': 'United States',
#   'alt': 4200},
#  {'name': 'Alamosa San Luis Valley Regional Airport',
#   'iata': 'ALS',
#   'icao': 'KALS',
#   'lat': 37.43491,
#   'lon': -105.865997,
#   'country': 'United States',
#   'alt': 7539},
#  {'name': 'Albacete Airport',
#   'iata': 'ABC',
#   'icao': 'LEAB',
#   'lat': 38.948502,
#   'lon': -1.86352,
#   'country': 'Spain',
#   'alt': 2302},
#  {'name': 'Albany Airport',
#   'iata': 'ALH',
#   'icao': 'YABA',
#   'lat': -34.939999,
#   'lon': 117.800003,
#   'country': 'Australia',
#   'alt': 233},
#  {'name': 'Albany International Airport',
#   'iata': 'ALB',
#   'icao': 'KALB',
#   'lat': 42.749111,
#   'lon': -73.801903,
#   'country': 'United States',
#   'alt': 285},
#  {'name': 'Albany Southwest Georgia Regional Airport',
#   'iata': 'ABY',
#   'icao': 'KABY',
#   'lat': 31.535509,
#   'lon': -84.194397,
#   'country': 'United States',
#   'alt': 196},
#  {'name': 'Albenga Clemente Panero International Airport',
#   'iata': 'ALL',
#   'icao': 'LIMG',
#   'lat': 44.050598,
#   'lon': 8.127428,
#   'country': 'Italy',
#   'alt': 148},
#  {'name': 'Albert Picardie Airport',
#   'iata': 'BYF',
#   'icao': 'LFAQ',
#   'lat': 49.9715,
#   'lon': 2.69766,
#   'country': 'France',
#   'alt': 364},
#  {'name': 'Albi Le Sequestre Airport',
#   'iata': 'LBI',
#   'icao': 'LFCI',
#   'lat': 43.913269,
#   'lon': 2.11675,
#   'country': 'France',
#   'alt': 564},
#  {'name': 'Albuquerque International Airport',
#   'iata': 'ABQ',
#   'icao': 'KABQ',
#   'lat': 35.040218,
#   'lon': -106.609001,
#   'country': 'United States',
#   'alt': 5355},
#  {'name': 'Albury Airport',
#   'iata': 'ABX',
#   'icao': 'YMAY',
#   'lat': -36.067699,
#   'lon': 146.957993,
#   'country': 'Australia',
#   'alt': 539},
#  {'name': 'Aldan Airport',
#   'iata': 'ADH',
#   'icao': 'UEEA',
#   'lat': 58.602772,
#   'lon': 125.408798,
#   'country': 'Russia',
#   'alt': 2241},
#  {'name': 'Alderney Airport',
#   'iata': 'ACI',
#   'icao': 'EGJA',
#   'lat': 49.706108,
#   'lon': -2.21472,
#   'country': 'United Kingdom',
#   'alt': 290},
#  {'name': 'Alegrete Novo Airport',
#   'iata': 'ALQ',
#   'icao': 'SSLT',
#   'lat': -29.8127,
#   'lon': -55.893398,
#   'country': 'Brazil',
#   'alt': 459},
#  {'name': 'Aleppo International Airport',
#   'iata': 'ALP',
#   'icao': 'OSAP',
#   'lat': 36.180672,
#   'lon': 37.22435,
#   'country': 'Syria',
#   'alt': 1276},
#  {'name': 'Alert Airport',
#   'iata': 'YLT',
#   'icao': 'CYLT',
#   'lat': 82.517776,
#   'lon': -62.280556,
#   'country': 'Canada',
#   'alt': 100},
#  {'name': 'Alesund Vigra Airport',
#   'iata': 'AES',
#   'icao': 'ENAL',
#   'lat': 62.560371,
#   'lon': 6.110164,
#   'country': 'Norway',
#   'alt': 69},
#  {'name': 'Alexander City Thomas C Russell Field',
#   'iata': 'ALX',
#   'icao': 'KALX',
#   'lat': 32.933334,
#   'lon': -85.949997,
#   'country': 'United States',
#   'alt': 686},
#  {'name': 'Alexandria Borg El Arab Airport',
#   'iata': 'HBE',
#   'icao': 'HEBA',
#   'lat': 30.91766,
#   'lon': 29.6964,
#   'country': 'Egypt',
#   'alt': 177},
#  {'name': 'Alexandria International Airport',
#   'iata': 'AEX',
#   'icao': 'KAEX',
#   'lat': 31.32737,
#   'lon': -92.5485,
#   'country': 'United States',
#   'alt': 89},
#  {'name': 'Alexandria Municipal Airport',
#   'iata': 'AXN',
#   'icao': 'KAXN',
#   'lat': 45.867222,
#   'lon': -95.394165,
#   'country': 'United States',
#   'alt': 1425},
#  {'name': 'Alexandroupolis International Airport',
#   'iata': 'AXD',
#   'icao': 'LGAL',
#   'lat': 40.855862,
#   'lon': 25.956261,
#   'country': 'Greece',
#   'alt': 24},
#  {'name': 'Algeciras Heliport',
#   'iata': 'QYH',
#   'icao': 'LEAG',
#   'lat': 36.128887,
#   'lon': -5.441111,
#   'country': 'Spain',
#   'alt': 98},
#  {'name': 'Alghero Fertilia Airport',
#   'iata': 'AHO',
#   'icao': 'LIEA',
#   'lat': 40.63213,
#   'lon': 8.290772,
#   'country': 'Italy',
#   'alt': 87},
#  {'name': 'Algiers Houari Boumediene Airport',
#   'iata': 'ALG',
#   'icao': 'DAAG',
#   'lat': 36.69101,
#   'lon': 3.215408,
#   'country': 'Algeria',
#   'alt': 82},
#  {'name': 'Alicante Airport',
#   'iata': 'ALC',
#   'icao': 'LEAL',
#   'lat': 38.282162,
#   'lon': -0.55815,
#   'country': 'Spain',
#   'alt': 142},
#  {'name': 'Alice International Airport',
#   'iata': 'ALI',
#   'icao': 'KALI',
#   'lat': 27.740879,
#   'lon': -98.026901,
#   'country': 'United States',
#   'alt': 178},
#  {'name': 'Alice Springs Airport',
#   'iata': 'ASP',
#   'icao': 'YBAS',
#   'lat': -23.806601,
#   'lon': 133.902206,
#   'country': 'Australia',
#   'alt': 1789},
#  {'name': 'Allahabad Airport',
#   'iata': 'IXD',
#   'icao': 'VEAB',
#   'lat': 25.439886,
#   'lon': 81.734406,
#   'country': 'India',
#   'alt': 319},
#  {'name': 'Allakaket Airport',
#   'iata': 'AET',
#   'icao': 'PFAL',
#   'lat': 66.551804,
#   'lon': -152.621994,
#   'country': 'United States',
#   'alt': 441},
#  {'name': 'Allendorf Airport',
#   'iata': 'QEQ',
#   'icao': 'EDFQ',
#   'lat': 51.035713,
#   'lon': 8.679523,
#   'country': 'Germany',
#   'alt': 1164},
#  {'name': 'Allentown Lehigh Valley International Airport',
#   'iata': 'ABE',
#   'icao': 'KABE',
#   'lat': 40.652302,
#   'lon': -75.440399,
#   'country': 'United States',
#   'alt': 393},
#  {'name': 'Alliance Municipal Airport',
#   'iata': 'AIA',
#   'icao': 'KAIA',
#   'lat': 42.053219,
#   'lon': -102.803001,
#   'country': 'United States',
#   'alt': 3931},
#  {'name': 'Alma Airport',
#   'iata': 'YTF',
#   'icao': 'CYTF',
#   'lat': 48.509655,
#   'lon': -71.642715,
#   'country': 'Canada',
#   'alt': 434},
#  {'name': 'Almaty International Airport',
#   'iata': 'ALA',
#   'icao': 'UAAA',
#   'lat': 43.35207,
#   'lon': 77.040497,
#   'country': 'Kazakhstan',
#   'alt': 2234},
#  {'name': 'Almeirim Airport',
#   'iata': 'GGF',
#   'icao': 'SNYA',
#   'lat': -1.479167,
#   'lon': -52.578056,
#   'country': 'Brazil',
#   'alt': 584},
#  {'name': 'Almeria Airport',
#   'iata': 'LEI',
#   'icao': 'LEAM',
#   'lat': 36.843929,
#   'lon': -2.37009,
#   'country': 'Spain',
#   'alt': 70},
#  {'name': 'Alor Island Airport',
#   'iata': 'ARD',
#   'icao': 'WATM',
#   'lat': -8.13234,
#   'lon': 124.597,
#   'country': 'Indonesia',
#   'alt': 10},
#  {'name': 'Alor Setar Sultan Abdul Halim Airport',
#   'iata': 'AOR',
#   'icao': 'WMKA',
#   'lat': 6.189667,
#   'lon': 100.398102,
#   'country': 'Malaysia',
#   'alt': 15},
#  {'name': 'Alpena County Regional Airport',
#   'iata': 'APN',
#   'icao': 'KAPN',
#   'lat': 45.081669,
#   'lon': -83.555832,
#   'country': 'United States',
#   'alt': 689},
#  {'name': 'Alta Airport',
#   'iata': 'ALF',
#   'icao': 'ENAT',
#   'lat': 69.976112,
#   'lon': 23.37166,
#   'country': 'Norway',
#   'alt': 9},
#  {'name': 'Alta Floresta Airport',
#   'iata': 'AFL',
#   'icao': 'SBAT',
#   'lat': -9.86609,
#   'lon': -56.106201,
#   'country': 'Brazil',
#   'alt': 947},
#  {'name': 'Altai Airport',
#   'iata': 'LTI',
#   'icao': 'ZMAT',
#   'lat': 46.650002,
#   'lon': 96.416664,
#   'country': 'Mongolia',
#   'alt': 7261},
#  {'name': 'Altamira Airport',
#   'iata': 'ATM',
#   'icao': 'SBHT',
#   'lat': -3.2539,
#   'lon': -52.253899,
#   'country': 'Brazil',
#   'alt': 368},
#  {'name': 'Altay Airport',
#   'iata': 'AAT',
#   'icao': 'ZWAT',
#   'lat': 47.750362,
#   'lon': 88.084442,
#   'country': 'China',
#   'alt': 1750},
#  {'name': 'Altenburg Nobitz Airport',
#   'iata': 'AOC',
#   'icao': 'EDAC',
#   'lat': 50.981812,
#   'lon': 12.50636,
#   'country': 'Germany',
#   'alt': 640},
#  {'name': 'Altenstadt Air Base',
#   'iata': 'QCA',
#   'icao': 'ETHA',
#   'lat': 47.835518,
#   'lon': 10.870574,
#   'country': 'Germany',
#   'alt': 2423},
#  {'name': 'Alton St. Louis Regional Airport',
#   'iata': 'ALN',
#   'icao': 'KALN',
#   'lat': 38.890301,
#   'lon': -90.045998,
#   'country': 'United States',
#   'alt': 544},
#  {'name': 'Altoona Blair County Airport',
#   'iata': 'AOO',
#   'icao': 'KAOO',
#   'lat': 40.296371,
#   'lon': -78.32,
#   'country': 'United States',
#   'alt': 1503},
#  {'name': 'Alzintan Airport',
#   'iata': 'ZIS',
#   'icao': 'HLZN',
#   'lat': 31.775,
#   'lon': 12.25,
#   'country': 'Libya',
#   'alt': 2080},
#  {'name': 'Amakusa Airport',
#   'iata': 'AXJ',
#   'icao': 'RJDA',
#   'lat': 32.483261,
#   'lon': 130.15564,
#   'country': 'Japan',
#   'alt': 328},
#  {'name': 'Amami Airport',
#   'iata': 'ASJ',
#   'icao': 'RJKA',
#   'lat': 28.43063,
#   'lon': 129.712494,
#   'country': 'Japan',
#   'alt': 27},
#  {'name': 'Amarillo Rick Husband  International Airport',
#   'iata': 'AMA',
#   'icao': 'KAMA',
#   'lat': 35.21936,
#   'lon': -101.705002,
#   'country': 'United States',
#   'alt': 3607},
#  {'name': 'Amarillo Tradewind Airport',
#   'iata': 'TDW',
#   'icao': 'KTDW',
#   'lat': 35.169899,
#   'lon': -101.825996,
#   'country': 'United States',
#   'alt': 3649},
#  {'name': 'Ambler Airport',
#   'iata': 'ABL',
#   'icao': 'PAFM',
#   'lat': 67.087502,
#   'lon': -157.84584,
#   'country': 'United States',
#   'alt': 289},
#  {'name': 'Ambon Pattimura Airport',
#   'iata': 'AMQ',
#   'icao': 'WAPP',
#   'lat': -3.71026,
#   'lon': 128.089096,
#   'country': 'Indonesia',
#   'alt': 33},
#  {'name': 'Amboseli Airport',
#   'iata': 'ASV',
#   'icao': 'HKAM',
#   'lat': -2.633,
#   'lon': 37.25,
#   'country': 'Kenya',
#   'alt': 3755},
#  {'name': 'Ames Municipal Airport',
#   'iata': 'AMW',
#   'icao': 'KAMW',
#   'lat': 41.992001,
#   'lon': -93.621803,
#   'country': 'United States',
#   'alt': 956},
#  {'name': 'Amman Civil Airport',
#   'iata': 'ADJ',
#   'icao': 'OJAM',
#   'lat': 31.9727,
#   'lon': 35.991562,
#   'country': 'Jordan',
#   'alt': 2555},
#  {'name': 'Amman Queen Alia International Airport',
#   'iata': 'AMM',
#   'icao': 'OJAI',
#   'lat': 31.722549,
#   'lon': 35.99321,
#   'country': 'Jordan',
#   'alt': 2395},
#  {'name': 'Amritsar International Airport',
#   'iata': 'ATQ',
#   'icao': 'VIAR',
#   'lat': 31.709591,
#   'lon': 74.797256,
#   'country': 'India',
#   'alt': 756},
#  {'name': 'Amsterdam Schiphol Airport',
#   'iata': 'AMS',
#   'icao': 'EHAM',
#   'lat': 52.308609,
#   'lon': 4.763889,
#   'country': 'Netherlands',
#   'alt': 11},
#  {'name': 'Anadyr Ugolny Airport',
#   'iata': 'DYR',
#   'icao': 'UHMA',
#   'lat': 64.730003,
#   'lon': 177.740005,
#   'country': 'Russia',
#   'alt': 194},
#  {'name': 'Anaktuvuk Pass Airport',
#   'iata': 'AKP',
#   'icao': 'PAKP',
#   'lat': 68.129997,
#   'lon': -151.740005,
#   'country': 'United States',
#   'alt': 2106},
#  {'name': 'Anapa Airport',
#   'iata': 'AAQ',
#   'icao': 'URKA',
#   'lat': 45.00209,
#   'lon': 37.347271,
#   'country': 'Russia',
#   'alt': 174},
#  {'name': 'Anapolis Airport',
#   'iata': 'APS',
#   'icao': 'SBAN',
#   'lat': -16.22714,
#   'lon': -48.963783,
#   'country': 'Brazil',
#   'alt': 3712},
#  {'name': 'Anchorage Elmendorf Air Force Base',
#   'iata': 'EDF',
#   'icao': 'PAED',
#   'lat': 61.251339,
#   'lon': -149.806,
#   'country': 'United States',
#   'alt': 213},
#  {'name': 'Anchorage Merrill Field Airport',
#   'iata': 'MRI',
#   'icao': 'PAMR',
#   'lat': 61.213539,
#   'lon': -149.843994,
#   'country': 'United States',
#   'alt': 137},
#  {'name': 'Anchorage Ted Stevens International Airport',
#   'iata': 'ANC',
#   'icao': 'PANC',
#   'lat': 61.174358,
#   'lon': -149.996002,
#   'country': 'United States',
#   'alt': 151},
#  {'name': 'Ancona Airport',
#   'iata': 'AOI',
#   'icao': 'LIPY',
#   'lat': 43.616341,
#   'lon': 13.36231,
#   'country': 'Italy',
#   'alt': 49},
#  {'name': 'Andenes Andoya Airport',
#   'iata': 'ANX',
#   'icao': 'ENAN',
#   'lat': 69.292503,
#   'lon': 16.144159,
#   'country': 'Norway',
#   'alt': 43},
#  {'name': 'Anderson Regional Airport',
#   'iata': 'AND',
#   'icao': 'KAND',
#   'lat': 34.494579,
#   'lon': -82.709297,
#   'country': 'United States',
#   'alt': 782},
#  {'name': 'Andizhan Airport',
#   'iata': 'AZN',
#   'icao': 'UTFA',
#   'lat': 40.72773,
#   'lon': 72.294006,
#   'country': 'Uzbekistan',
#   'alt': 1515},
#  {'name': 'Andorra La Seu de Urgel Airport',
#   'iata': 'LEU',
#   'icao': 'LESU',
#   'lat': 42.34058,
#   'lon': 1.410326,
#   'country': 'Spain',
#   'alt': 2625},
#  {'name': 'Andros Town International Airport',
#   'iata': 'ASD',
#   'icao': 'MYAF',
#   'lat': 24.69828,
#   'lon': -77.795601,
#   'country': 'Bahamas',
#   'alt': 5},
#  {'name': 'Anegada Auguste George Airport',
#   'iata': 'NGD',
#   'icao': 'TUPA',
#   'lat': 18.727394,
#   'lon': -64.330055,
#   'country': 'Virgin Islands, British',
#   'alt': 21},
#  {'name': 'Angeles City Clark International Airport',
#   'iata': 'CRK',
#   'icao': 'RPLC',
#   'lat': 15.18598,
#   'lon': 120.560303,
#   'country': 'Philippines',
#   'alt': 484},
#  {'name': 'Angelholm Helsingborg Airport',
#   'iata': 'AGH',
#   'icao': 'ESTA',
#   'lat': 56.29607,
#   'lon': 12.84713,
#   'country': 'Sweden',
#   'alt': 68},
#  {'name': 'Angers Loire Airport',
#   'iata': 'ANE',
#   'icao': 'LFJR',
#   'lat': 47.56028,
#   'lon': -0.312222,
#   'country': 'France',
#   'alt': 194},
#  {'name': 'Anglesey Airport',
#   'iata': 'VLY',
#   'icao': 'EGOV',
#   'lat': 53.240002,
#   'lon': -4.53,
#   'country': 'United Kingdom',
#   'alt': '-1'},
#  {'name': 'Angola Tri-State Steuben County Airport',
#   'iata': 'ANQ',
#   'icao': 'KANQ',
#   'lat': 41.639702,
#   'lon': -85.083504,
#   'country': 'United States',
#   'alt': 995},
#  {'name': 'Angouleme Cognac International Airport',
#   'iata': 'ANG',
#   'icao': 'LFBU',
#   'lat': 45.729469,
#   'lon': 0.219153,
#   'country': 'France',
#   'alt': 436},
#  {'name': 'Angra dos Reis Airport',
#   'iata': 'GDR',
#   'icao': 'SDAG',
#   'lat': -22.975279,
#   'lon': -44.30722,
#   'country': 'Brazil',
#   'alt': 10},
#  {'name': 'Aniak Airport',
#   'iata': 'ANI',
#   'icao': 'PANI',
#   'lat': 61.581669,
#   'lon': -159.54306,
#   'country': 'United States',
#   'alt': 89},
#  {'name': 'Anjouan Ouani Airport',
#   'iata': 'AJN',
#   'icao': 'FMCV',
#   'lat': -12.1316,
#   'lon': 44.430271,
#   'country': 'Comoros',
#   'alt': 62},
#  {'name': 'Ankang Fuqiang Airport',
#   'iata': 'AKA',
#   'icao': 'ZLAK',
#   'lat': 32.708099,
#   'lon': 108.931046,
#   'country': 'China',
#   'alt': 849},
#  {'name': 'Ankara Esenboga International Airport',
#   'iata': 'ESB',
#   'icao': 'LTAC',
#   'lat': 40.128078,
#   'lon': 32.995079,
#   'country': 'Turkey',
#   'alt': 3125},
#  {'name': 'Ankeny Regional Airport',
#   'iata': 'QQK',
#   'icao': 'KIKV',
#   'lat': 41.691113,
#   'lon': -93.566391,
#   'country': 'United States',
#   'alt': 910},
#  {'name': 'Ann Airport',
#   'iata': 'VBA',
#   'icao': 'VYAN',
#   'lat': 19.770643,
#   'lon': 94.026405,
#   'country': 'Myanmar (Burma)',
#   'alt': 43},
#  {'name': 'Ann Arbor Municipal Airport',
#   'iata': 'ARB',
#   'icao': 'KARB',
#   'lat': 42.223057,
#   'lon': -83.74556,
#   'country': 'United States',
#   'alt': 839},
#  {'name': 'Annaba Rabah Bitat Airport',
#   'iata': 'AAE',
#   'icao': 'DABB',
#   'lat': 36.82222,
#   'lon': 7.809167,
#   'country': 'Algeria',
#   'alt': 16},
#  {'name': 'Annapolis Lee Airport',
#   'iata': 'ANP',
#   'icao': 'KANP',
#   'lat': 38.942902,
#   'lon': -76.568398,
#   'country': 'United States',
#   'alt': 34},
#  {'name': 'Annecy Mont Blanc Airport',
#   'iata': 'NCY',
#   'icao': 'LFLP',
#   'lat': 45.930771,
#   'lon': 6.106289,
#   'country': 'France',
#   'alt': 1519},
#  {'name': 'Annemasse Airport',
#   'iata': 'QYA',
#   'icao': 'LFLI',
#   'lat': 46.19194,
#   'lon': 6.269444,
#   'country': 'France',
#   'alt': 1617},
#  {'name': 'Anniston Regional',
#   'iata': 'ANB',
#   'icao': 'KANB',
#   'lat': 33.588161,
#   'lon': -85.858101,
#   'country': 'United States',
#   'alt': 612},
#  {'name': 'Anqing Tianzhushan Airport',
#   'iata': 'AQG',
#   'icao': 'ZSAQ',
#   'lat': 30.582222,
#   'lon': 117.050278,
#   'country': 'China',
#   'alt': '-1'},
#  {'name': "Anshan Teng'ao Airport",
#   'iata': 'AOG',
#   'icao': 'ZYAS',
#   'lat': 41.103523,
#   'lon': 122.855835,
#   'country': 'China',
#   'alt': 53},
#  {'name': 'Anshun Huangguoshu Airport',
#   'iata': 'AVA',
#   'icao': 'ZUAS',
#   'lat': 26.260555,
#   'lon': 105.873337,
#   'country': 'China',
#   'alt': 4812},
#  {'name': 'Antakya Hatay Airport',
#   'iata': 'HTY',
#   'icao': 'LTDA',
#   'lat': 36.362778,
#   'lon': 36.282223,
#   'country': 'Turkey',
#   'alt': 25},
#  {'name': 'Antalya Airport',
#   'iata': 'AYT',
#   'icao': 'LTAI',
#   'lat': 36.898731,
#   'lon': 30.800461,
#   'country': 'Turkey',
#   'alt': 177},
#  {'name': 'Antananarivo Ivato International Airport',
#   'iata': 'TNR',
#   'icao': 'FMMI',
#   'lat': -18.7969,
#   'lon': 47.478802,
#   'country': 'Madagascar',
#   'alt': 4198},
#  {'name': 'Antigua V. C. Bird International Airport',
#   'iata': 'ANU',
#   'icao': 'TAPA',
#   'lat': 17.13674,
#   'lon': -61.792599,
#   'country': 'Antigua And Barbuda',
#   'alt': 62},
#  {'name': 'Antofagasta International Airport',
#   'iata': 'ANF',
#   'icao': 'SCFA',
#   'lat': -23.444401,
#   'lon': -70.445099,
#   'country': 'Chile',
#   'alt': 455},
#  {'name': 'Antsiranana Arrachart Airport',
#   'iata': 'DIE',
#   'icao': 'FMNA',
#   'lat': -12.3494,
#   'lon': 49.29174,
#   'country': 'Madagascar',
#   'alt': 374},
#  {'name': 'Antwerp International Airport',
#   'iata': 'ANR',
#   'icao': 'EBAW',
#   'lat': 51.189442,
#   'lon': 4.460278,
#   'country': 'Belgium',
#   'alt': 39},
#  {'name': 'Anvik Airport',
#   'iata': 'ANV',
#   'icao': 'PANV',
#   'lat': 62.647778,
#   'lon': -160.188889,
#   'country': 'United States',
#   'alt': 309},
#  {'name': 'Aomori Airport',
#   'iata': 'AOJ',
#   'icao': 'RJSA',
#   'lat': 40.734718,
#   'lon': 140.690796,
#   'country': 'Japan',
#   'alt': 664},
#  {'name': 'Aosta Airport',
#   'iata': 'AOT',
#   'icao': 'LIMW',
#   'lat': 45.738499,
#   'lon': 7.36872,
#   'country': 'Italy',
#   'alt': 1791},
#  {'name': 'Apalachicola Regional Airport',
#   'iata': 'AAF',
#   'icao': 'KAAF',
#   'lat': 29.733334,
#   'lon': -84.98333,
#   'country': 'United States',
#   'alt': 20},
#  {'name': 'Apartado Airport',
#   'iata': 'APO',
#   'icao': 'SKLC',
#   'lat': 7.817678,
#   'lon': -76.717659,
#   'country': 'Colombia',
#   'alt': 46},
#  {'name': 'Apatity Airport',
#   'iata': 'KVK',
#   'icao': 'ULMK',
#   'lat': 67.463303,
#   'lon': 33.588299,
#   'country': 'Russia',
#   'alt': 515},
#  {'name': 'Apia Faleolo International Airport',
#   'iata': 'APW',
#   'icao': 'NSFA',
#   'lat': -13.8296,
#   'lon': -171.996994,
#   'country': 'Samoa',
#   'alt': 58},
#  {'name': 'Apple Valley Airport',
#   'iata': 'APV',
#   'icao': 'KAPV',
#   'lat': 34.575298,
#   'lon': -117.185997,
#   'country': 'United States',
#   'alt': 3062},
#  {'name': 'Appleton International Airport',
#   'iata': 'ATW',
#   'icao': 'KATW',
#   'lat': 44.258091,
#   'lon': -88.518997,
#   'country': 'United States',
#   'alt': 918},
#  {'name': 'Apucarana Airport',
#   'iata': 'APU',
#   'icao': 'SSAP',
#   'lat': -23.609501,
#   'lon': -51.384499,
#   'country': 'Brazil',
#   'alt': 2641},
#  {'name': 'Apui Airport',
#   'iata': 'IUP',
#   'icao': 'SWYN',
#   'lat': -7.1727,
#   'lon': -59.839409,
#   'country': 'Brazil',
#   'alt': 614},
#  {'name': 'Aqaba King Hussein International Airport',
#   'iata': 'AQJ',
#   'icao': 'OJAQ',
#   'lat': 29.61161,
#   'lon': 35.018059,
#   'country': 'Jordan',
#   'alt': 175},
#  {'name': 'Aracaju Santa Maria Airport',
#   'iata': 'AJU',
#   'icao': 'SBAR',
#   'lat': -10.984,
#   'lon': -37.070301,
#   'country': 'Brazil',
#   'alt': 23},
#  {'name': 'Aracati Airport',
#   'iata': 'ARX',
#   'icao': 'SBAC',
#   'lat': -4.56861,
#   'lon': -37.804722,
#   'country': 'Brazil',
#   'alt': 128},
#  {'name': 'Aracatuba Airport',
#   'iata': 'ARU',
#   'icao': 'SBAU',
#   'lat': -21.1413,
#   'lon': -50.424702,
#   'country': 'Brazil',
#   'alt': 1361},
#  {'name': 'Arad International Airport',
#   'iata': 'ARW',
#   'icao': 'LRAR',
#   'lat': 46.176552,
#   'lon': 21.26202,
#   'country': 'Romania',
#   'alt': 352},
#  {'name': 'Araguaina Airport',
#   'iata': 'AUX',
#   'icao': 'SWGN',
#   'lat': -7.227867,
#   'lon': -48.240467,
#   'country': 'Brazil',
#   'alt': 771},
#  {'name': 'Arak Airport',
#   'iata': 'AJK',
#   'icao': 'OIHR',
#   'lat': 34.1381,
#   'lon': 49.847301,
#   'country': 'Iran',
#   'alt': 5440},
#  {'name': 'Arapongas Airport',
#   'iata': 'APX',
#   'icao': 'SSOG',
#   'lat': -23.3529,
#   'lon': -51.491699,
#   'country': 'Brazil',
#   'alt': 2599},
#  {'name': 'Arar Domestic Airport',
#   'iata': 'RAE',
#   'icao': 'OERR',
#   'lat': 30.90658,
#   'lon': 41.13821,
#   'country': 'Saudi Arabia',
#   'alt': 1813},
#  {'name': 'Araraquara Airport',
#   'iata': 'AQA',
#   'icao': 'SBAQ',
#   'lat': -21.812,
#   'lon': -48.132999,
#   'country': 'Brazil',
#   'alt': 2334},
#  {'name': 'Araripina Airport',
#   'iata': 'JAW',
#   'icao': 'SNAB',
#   'lat': -7.5864,
#   'lon': -40.5354,
#   'country': 'Brazil',
#   'alt': 2421},
#  {'name': 'Arauca Santiago Perez Quiroz Airport',
#   'iata': 'AUC',
#   'icao': 'SKUC',
#   'lat': 7.068889,
#   'lon': -70.7369,
#   'country': 'Colombia',
#   'alt': 420},
#  {'name': 'Araxa Airport',
#   'iata': 'AAX',
#   'icao': 'SBAX',
#   'lat': -19.562658,
#   'lon': -46.961014,
#   'country': 'Brazil',
#   'alt': 3247},
#  {'name': 'Arba Minch Airport',
#   'iata': 'AMH',
#   'icao': 'HAAM',
#   'lat': 6.039389,
#   'lon': 37.59045,
#   'country': 'Ethiopia',
#   'alt': 3895},
#  {'name': 'Arcachon La Teste-de-Buch Airport',
#   'iata': 'XAC',
#   'icao': 'LFCH',
#   'lat': 44.59861,
#   'lon': -1.11472,
#   'country': 'France',
#   'alt': 49},
#  {'name': 'Arcata Eureka Airport',
#   'iata': 'ACV',
#   'icao': 'KACV',
#   'lat': 40.978111,
#   'lon': -124.108002,
#   'country': 'United States',
#   'alt': 222},
#  {'name': 'Arctic Bay Airport',
#   'iata': 'YAB',
#   'icao': 'CYAB',
#   'lat': 73.006386,
#   'lon': -85.047218,
#   'country': 'Canada',
#   'alt': 72},
#  {'name': 'Arctic Village',
#   'iata': 'ARC',
#   'icao': 'PARC',
#   'lat': 68.110001,
#   'lon': -145.570007,
#   'country': 'United States',
#   'alt': 2092},
#  {'name': 'Ardabil Airport',
#   'iata': 'ADU',
#   'icao': 'OITL',
#   'lat': 38.323826,
#   'lon': 48.421249,
#   'country': 'Iran',
#   'alt': 4317},
#  {'name': 'Ardmore Airport',
#   'iata': 'AMZ',
#   'icao': 'NZAR',
#   'lat': -37.029701,
#   'lon': 174.973007,
#   'country': 'New Zealand',
#   'alt': 111},
#  {'name': 'Ardmore Municipal Airport',
#   'iata': 'ADM',
#   'icao': 'KADM',
#   'lat': 34.303009,
#   'lon': -97.0196,
#   'country': 'United States',
#   'alt': 776},
#  {'name': 'Arendal Gullknapp Airport',
#   'iata': 'QCG',
#   'icao': 'ENGK',
#   'lat': 58.518326,
#   'lon': 8.707467,
#   'country': 'Norway',
#   'alt': 405},
#  {'name': 'Arequipa Rodriguez Ballon International Airport',
#   'iata': 'AQP',
#   'icao': 'SPQU',
#   'lat': -16.341,
#   'lon': -71.583,
#   'country': 'Peru',
#   'alt': 8405},
#  {'name': 'Argyle Airport',
#   'iata': 'GYL',
#   'icao': 'YARG',
#   'lat': -16.629999,
#   'lon': 128.449997,
#   'country': 'Australia',
#   'alt': 522},
#  {'name': 'Arica Chacalluta International Airport',
#   'iata': 'ARI',
#   'icao': 'SCAR',
#   'lat': -18.348499,
#   'lon': -70.338699,
#   'country': 'Chile',
#   'alt': 167},
#  {'name': 'Aripuana Airport',
#   'iata': 'AIR',
#   'icao': 'SSOU',
#   'lat': -10.186673,
#   'lon': -59.457531,
#   'country': 'Brazil',
#   'alt': 738},
#  {'name': 'Ariquemes Airport',
#   'iata': 'AQM',
#   'icao': 'SJOG',
#   'lat': -9.880993,
#   'lon': -63.047237,
#   'country': 'Brazil',
#   'alt': 461},
#  {'name': 'Arkhangelsk Talagi Airport',
#   'iata': 'ARH',
#   'icao': 'ULAA',
#   'lat': 64.600281,
#   'lon': 40.71666,
#   'country': 'Russia',
#   'alt': 62},
#  {'name': 'Arlington Municipal Airport',
#   'iata': 'QQW',
#   'icao': 'KAWO',
#   'lat': 48.160831,
#   'lon': -122.15889,
#   'country': 'United States',
#   'alt': 142},
#  {'name': 'Arlington Municipal Airport',
#   'iata': 'QQG',
#   'icao': 'KGKY',
#   'lat': 32.66,
#   'lon': -97.089996,
#   'country': 'United States',
#   'alt': 628},
#  {'name': 'Armenia El Eden International Airport',
#   'iata': 'AXM',
#   'icao': 'SKAR',
#   'lat': 4.453333,
#   'lon': -75.7658,
#   'country': 'Colombia',
#   'alt': 3990},
#  {'name': 'Armidale Airport',
#   'iata': 'ARM',
#   'icao': 'YARM',
#   'lat': -30.528334,
#   'lon': 151.616669,
#   'country': 'Australia',
#   'alt': 3556},
#  {'name': 'Artesia Municipal Airport',
#   'iata': 'ATS',
#   'icao': 'KATS',
#   'lat': 32.852501,
#   'lon': -104.468002,
#   'country': 'United States',
#   'alt': 3541},
#  {'name': "Arthur's Town Airport",
#   'iata': 'ATC',
#   'icao': 'MYCA',
#   'lat': 24.628611,
#   'lon': -75.671387,
#   'country': 'Bahamas',
#   'alt': 18},
#  {'name': 'Arusha Airport',
#   'iata': 'ARK',
#   'icao': 'HTAR',
#   'lat': -3.36779,
#   'lon': 36.633331,
#   'country': 'Tanzania',
#   'alt': 4550},
#  {'name': 'Arutua Airport',
#   'iata': 'AXR',
#   'icao': 'NTGU',
#   'lat': -15.2463,
#   'lon': -146.619995,
#   'country': 'French Polynesia',
#   'alt': 9},
#  {'name': 'Arviat Airport',
#   'iata': 'YEK',
#   'icao': 'CYEK',
#   'lat': 61.094158,
#   'lon': -94.070801,
#   'country': 'Canada',
#   'alt': 32},
#  {'name': 'Arvidsjaur Airport',
#   'iata': 'AJR',
#   'icao': 'ESNX',
#   'lat': 65.590271,
#   'lon': 19.28194,
#   'country': 'Sweden',
#   'alt': 1245},
#  {'name': 'Arxan Yiershi Airport',
#   'iata': 'YIE',
#   'icao': 'ZBES',
#   'lat': 47.310555,
#   'lon': 119.911942,
#   'country': 'China',
#   'alt': 2918},
#  {'name': 'Asaba International Airport',
#   'iata': 'ABB',
#   'icao': 'DNAS',
#   'lat': 6.203055,
#   'lon': 6.667222,
#   'country': 'Nigeria',
#   'alt': 242},
#  {'name': 'Asahikawa Airport',
#   'iata': 'AKJ',
#   'icao': 'RJEC',
#   'lat': 43.67083,
#   'lon': 142.447495,
#   'country': 'Japan',
#   'alt': 721},
#  {'name': 'Ascension Island Airport',
#   'iata': 'ASI',
#   'icao': 'FHAW',
#   'lat': -7.9696,
#   'lon': -14.3937,
#   'country': 'Saint Helena',
#   'alt': 278},
#  {'name': 'Asheville Regional Airport',
#   'iata': 'AVL',
#   'icao': 'KAVL',
#   'lat': 35.436192,
#   'lon': -82.541801,
#   'country': 'United States',
#   'alt': 2164},
#  {'name': 'Ashgabat International Airport',
#   'iata': 'ASB',
#   'icao': 'UTAA',
#   'lat': 37.986809,
#   'lon': 58.360958,
#   'country': 'Turkmenistan',
#   'alt': 692},
#  {'name': 'Asmara International Airport',
#   'iata': 'ASM',
#   'icao': 'HHAS',
#   'lat': 15.29185,
#   'lon': 38.91066,
#   'country': 'Eritrea',
#   'alt': 7661},
#  {'name': 'Asosa Airport',
#   'iata': 'ASO',
#   'icao': 'HASO',
#   'lat': 10.01855,
#   'lon': 34.58625,
#   'country': 'Ethiopia',
#   'alt': 5120},
#  {'name': 'Aspen Pitkin County Airport',
#   'iata': 'ASE',
#   'icao': 'KASE',
#   'lat': 39.22316,
#   'lon': -106.867996,
#   'country': 'United States',
#   'alt': 7838},
#  {'name': 'Assaluyeh Persian Gulf Airport',
#   'iata': 'PGU',
#   'icao': 'OIBP',
#   'lat': 27.383959,
#   'lon': 52.735516,
#   'country': 'Iran',
#   'alt': 40},
#  {'name': 'Assiut Airport',
#   'iata': 'ATZ',
#   'icao': 'HEAT',
#   'lat': 27.046499,
#   'lon': 31.01198,
#   'country': 'Egypt',
#   'alt': 772},
#  {'name': 'Astana Nursultan Nazarbayev International Airport',
#   'iata': 'NQZ',
#   'icao': 'UACC',
#   'lat': 51.022221,
#   'lon': 71.466942,
#   'country': 'Kazakhstan',
#   'alt': 1165},
#  {'name': 'Astoria Regional Airport',
#   'iata': 'AST',
#   'icao': 'KAST',
#   'lat': 46.159721,
#   'lon': -123.879997,
#   'country': 'United States',
#   'alt': 15},
#  {'name': 'Astrakhan Narimanovo Airport',
#   'iata': 'ASF',
#   'icao': 'URWA',
#   'lat': 46.283329,
#   'lon': 48.006271,
#   'country': 'Russia',
#   'alt': 65},
#  {'name': 'Asturias Airport',
#   'iata': 'OVD',
#   'icao': 'LEAS',
#   'lat': 43.56356,
#   'lon': -6.03462,
#   'country': 'Spain',
#   'alt': 416},
#  {'name': 'Astypalaia Island National Airport',
#   'iata': 'JTY',
#   'icao': 'LGPL',
#   'lat': 36.579887,
#   'lon': 26.375822,
#   'country': 'Greece',
#   'alt': 165},
#  {'name': 'Asuncion Silvio Pettirossi International Airport',
#   'iata': 'ASU',
#   'icao': 'SGAS',
#   'lat': -25.239799,
#   'lon': -57.5191,
#   'country': 'Paraguay',
#   'alt': 292},
#  {'name': 'Aswan International Airport',
#   'iata': 'ASW',
#   'icao': 'HESN',
#   'lat': 23.96435,
#   'lon': 32.819969,
#   'country': 'Egypt',
#   'alt': 662},
#  {'name': 'Atambua Haliwen Airport',
#   'iata': 'ABU',
#   'icao': 'WATA',
#   'lat': -9.07444,
#   'lon': 124.904404,
#   'country': 'Indonesia',
#   'alt': 75},
#  {'name': 'Athens Ben Epps Airport',
#   'iata': 'AHN',
#   'icao': 'KAHN',
#   'lat': 33.95195,
#   'lon': -83.324722,
#   'country': 'United States',
#   'alt': 808},
#  {'name': 'Athens Eleftherios Venizelos',
#   'iata': 'ATH',
#   'icao': 'LGAV',
#   'lat': 37.936352,
#   'lon': 23.94446,
#   'country': 'Greece',
#   'alt': 308},
#  {'name': 'Athens Gordon K. Bush Airport',
#   'iata': 'ATO',
#   'icao': 'KUNI',
#   'lat': 39.210999,
#   'lon': -82.2314,
#   'country': 'United States',
#   'alt': 766},
#  {'name': 'Athens McMinn County Airport',
#   'iata': 'MMI',
#   'icao': 'KMMI',
#   'lat': 35.397221,
#   'lon': -84.5625,
#   'country': 'United States',
#   'alt': 858},
#  {'name': 'Atlanta Cobb County Airport',
#   'iata': 'QQR',
#   'icao': 'KRYY',
#   'lat': 34.013058,
#   'lon': -84.59861,
#   'country': 'United States',
#   'alt': 1040},
#  {'name': 'Atlanta DeKalb Peachtree Airport',
#   'iata': 'PDK',
#   'icao': 'KPDK',
#   'lat': 33.869999,
#   'lon': -84.300003,
#   'country': 'United States',
#   'alt': 1003},
#  {'name': 'Atlanta Fulton County Airport',
#   'iata': 'FTY',
#   'icao': 'KFTY',
#   'lat': 33.777195,
#   'lon': -84.521141,
#   'country': 'United States',
#   'alt': 821},
#  {'name': 'Atlanta Hartsfield-Jackson International Airport',
#   'iata': 'ATL',
#   'icao': 'KATL',
#   'lat': 33.636719,
#   'lon': -84.428001,
#   'country': 'United States',
#   'alt': 1026},
#  {'name': 'Atlanta Regional Airport',
#   'iata': 'QTF',
#   'icao': 'KFFC',
#   'lat': 33.357475,
#   'lon': -84.572121,
#   'country': 'United States',
#   'alt': 784},
#  {'name': 'Atlantic City International Airport',
#   'iata': 'ACY',
#   'icao': 'KACY',
#   'lat': 39.457581,
#   'lon': -74.577103,
#   'country': 'United States',
#   'alt': 74},
#  {'name': 'Atlantic City Monmouth Executive Airport',
#   'iata': 'BLM',
#   'icao': 'KBLM',
#   'lat': 40.186668,
#   'lon': -74.124443,
#   'country': 'United States',
#   'alt': 153},
#  {'name': 'Atqasuk Airport',
#   'iata': 'ATK',
#   'icao': 'PATQ',
#   'lat': 70.5,
#   'lon': -157.333328,
#   'country': 'United States',
#   'alt': 96},
#  {'name': 'Attawapiskat Airport',
#   'iata': 'YAT',
#   'icao': 'CYAT',
#   'lat': 52.919998,
#   'lon': -82.43,
#   'country': 'Canada',
#   'alt': 31},
#  {'name': 'Atuona Airport',
#   'iata': 'AUQ',
#   'icao': 'NTMN',
#   'lat': -9.76879,
#   'lon': -139.011002,
#   'country': 'French Polynesia',
#   'alt': 1481},
#  {'name': 'Atwater Castle Airport',
#   'iata': 'MER',
#   'icao': 'KMER',
#   'lat': 37.380482,
#   'lon': -120.568001,
#   'country': 'United States',
#   'alt': 191},
#  {'name': 'Atyrau Airport',
#   'iata': 'GUW',
#   'icao': 'UATG',
#   'lat': 47.121941,
#   'lon': 51.821381,
#   'country': 'Kazakhstan',
#   'alt': 72},
#  {'name': 'Auburn Airport',
#   'iata': 'LEW',
#   'icao': 'KLEW',
#   'lat': 44.048611,
#   'lon': -70.283607,
#   'country': 'United States',
#   'alt': 288},
#  {'name': 'Auburn Municipal Airport',
#   'iata': 'AUN',
#   'icao': 'KAUN',
#   'lat': 38.9548,
#   'lon': -121.082001,
#   'country': 'United States',
#   'alt': 1539},
#  {'name': 'Auburn University Regional Airport',
#   'iata': 'AUO',
#   'icao': 'KAUO',
#   'lat': 32.615101,
#   'lon': -85.433998,
#   'country': 'United States',
#   'alt': 777},
#  {'name': 'Auckland Airport',
#   'iata': 'AKL',
#   'icao': 'NZAA',
#   'lat': -37.007999,
#   'lon': 174.791595,
#   'country': 'New Zealand',
#   'alt': 23},
#  {'name': 'Augsburg Airport',
#   'iata': 'AGB',
#   'icao': 'EDMA',
#   'lat': 48.425152,
#   'lon': 10.93176,
#   'country': 'Germany',
#   'alt': 1515},
#  {'name': 'Augusta Daniel Field Airport',
#   'iata': 'DNL',
#   'icao': 'KDNL',
#   'lat': 33.468098,
#   'lon': -82.0392,
#   'country': 'United States',
#   'alt': 414},
#  {'name': 'Augusta Regional Airport',
#   'iata': 'AGS',
#   'icao': 'KAGS',
#   'lat': 33.369942,
#   'lon': -81.9645,
#   'country': 'United States',
#   'alt': 144},
#  {'name': 'Augusta State Airport',
#   'iata': 'AUG',
#   'icao': 'KAUG',
#   'lat': 44.320648,
#   'lon': -69.797302,
#   'country': 'United States',
#   'alt': 352},
#  {'name': 'Aupaluk Airport',
#   'iata': 'YPJ',
#   'icao': 'CYLA',
#   'lat': 59.296665,
#   'lon': -69.599724,
#   'country': 'Canada',
#   'alt': 117},
#  {'name': 'Aurangabad Airport',
#   'iata': 'IXU',
#   'icao': 'VAAU',
#   'lat': 19.86272,
#   'lon': 75.398109,
#   'country': 'India',
#   'alt': 1911},
#  {'name': 'Aurillac Tronquieres Airport',
#   'iata': 'AUR',
#   'icao': 'LFLW',
#   'lat': 44.897579,
#   'lon': 2.416719,
#   'country': 'France',
#   'alt': 2096},
#  {'name': 'Aurukun Airport',
#   'iata': 'AUU',
#   'icao': 'YAUR',
#   'lat': -13.353889,
#   'lon': 141.72084,
#   'country': 'Australia',
#   'alt': 29},
#  {'name': 'Austin Bergstrom International Airport',
#   'iata': 'AUS',
#   'icao': 'KAUS',
#   'lat': 30.194521,
#   'lon': -97.6698,
#   'country': 'United States',
#   'alt': 542},
#  {'name': 'Austin Executive Airport',
#   'iata': 'EDC',
#   'icao': 'KEDC',
#   'lat': 30.389999,
#   'lon': -97.559998,
#   'country': 'United States',
#   'alt': 620},
#  {'name': 'Auxerre Branches Airport',
#   'iata': 'AUF',
#   'icao': 'LFLA',
#   'lat': 47.846321,
#   'lon': 3.496578,
#   'country': 'France',
#   'alt': 523},
#  {'name': 'Avalon Catalina Airport',
#   'iata': 'AVX',
#   'icao': 'KAVX',
#   'lat': 33.404999,
#   'lon': -118.415833,
#   'country': 'United States',
#   'alt': 1602},
#  {'name': 'Avarua Rarotonga International Airport',
#   'iata': 'RAR',
#   'icao': 'NCRG',
#   'lat': -21.2027,
#   'lon': -159.804993,
#   'country': 'Cook Islands',
#   'alt': 19},
#  {'name': 'Aviano Air Base',
#   'iata': 'AVB',
#   'icao': 'LIPA',
#   'lat': 46.031879,
#   'lon': 12.59647,
#   'country': 'Italy',
#   'alt': 410},
#  {'name': 'Avignon Caumont Airport',
#   'iata': 'AVN',
#   'icao': 'LFMV',
#   'lat': 43.906582,
#   'lon': 4.902028,
#   'country': 'France',
#   'alt': 124},
#  {'name': 'Avoca Wilkes-Barre/Scranton International Airport',
#   'iata': 'AVP',
#   'icao': 'KAVP',
#   'lat': 41.33847,
#   'lon': -75.723297,
#   'country': 'United States',
#   'alt': 962},
#  {'name': 'Awali Sakhir Air Base',
#   'iata': 'KHB',
#   'icao': 'OBKH',
#   'lat': 26.034721,
#   'lon': 50.524445,
#   'country': 'Bahrain',
#   'alt': 49},
#  {'name': 'Awasa Airport',
#   'iata': 'AWA',
#   'icao': 'HALA',
#   'lat': 7.095,
#   'lon': 38.398335,
#   'country': 'Ethiopia',
#   'alt': 5604},
#  {'name': 'Axum Airport',
#   'iata': 'AXU',
#   'icao': 'HAAX',
#   'lat': 14.14675,
#   'lon': 38.772831,
#   'country': 'Ethiopia',
#   'alt': 6915},
#  {'name': 'Ayacucho Airport',
#   'iata': 'AYP',
#   'icao': 'SPHO',
#   'lat': -13.1548,
#   'lon': -74.204399,
#   'country': 'Peru',
#   'alt': 8917},
#  {'name': 'Ayers Rock Airport',
#   'iata': 'AYQ',
#   'icao': 'YAYE',
#   'lat': -25.1861,
#   'lon': 130.975494,
#   'country': 'Australia',
#   'alt': 1626},
#  {'name': 'Babo Airport',
#   'iata': 'BXB',
#   'icao': 'WASO',
#   'lat': -2.53224,
#   'lon': 133.438797,
#   'country': 'Indonesia',
#   'alt': 10},
#  {'name': 'Bacau International Airport',
#   'iata': 'BCM',
#   'icao': 'LRBC',
#   'lat': 46.521938,
#   'lon': 26.910271,
#   'country': 'Romania',
#   'alt': 607},
#  {'name': 'Bacolod City Silay International Airport',
#   'iata': 'BCD',
#   'icao': 'RPVB',
#   'lat': 10.776905,
#   'lon': 123.018394,
#   'country': 'Philippines',
#   'alt': 25},
#  {'name': 'Badajoz Airport',
#   'iata': 'BJZ',
#   'icao': 'LEBZ',
#   'lat': 38.891251,
#   'lon': -6.82133,
#   'country': 'Spain',
#   'alt': 609},
#  {'name': 'Badin Talhar Airport',
#   'iata': 'BDN',
#   'icao': 'OPTH',
#   'lat': 24.841511,
#   'lon': 68.838402,
#   'country': 'Pakistan',
#   'alt': 28},
#  {'name': 'Badu Island Airport',
#   'iata': 'BDD',
#   'icao': 'YBAU',
#   'lat': -10.15,
#   'lon': 142.173401,
#   'country': 'Australia',
#   'alt': 14},
#  {'name': 'Bafoussam Airport',
#   'iata': 'BFX',
#   'icao': 'FKKU',
#   'lat': 5.536919,
#   'lon': 10.35458,
#   'country': 'Cameroon',
#   'alt': 4347},
#  {'name': 'Bage Comandante Gustavo Kraemer Airport',
#   'iata': 'BGX',
#   'icao': 'SBBG',
#   'lat': -31.390499,
#   'lon': -54.112202,
#   'country': 'Brazil',
#   'alt': 600},
#  {'name': 'Baghdad International Airport',
#   'iata': 'BGW',
#   'icao': 'ORBI',
#   'lat': 33.262501,
#   'lon': 44.234444,
#   'country': 'Iraq',
#   'alt': 114},
#  {'name': 'Baglung Airport',
#   'iata': 'BGL',
#   'icao': 'VNBL',
#   'lat': 28.212799,
#   'lon': 83.666298,
#   'country': 'Nepal',
#   'alt': 3320},
#  {'name': 'Bahawalpur Airport',
#   'iata': 'BHV',
#   'icao': 'OPBW',
#   'lat': 29.348057,
#   'lon': 71.717781,
#   'country': 'Pakistan',
#   'alt': 392},
#  {'name': 'Bahia Blanca Comandante Espora Airport',
#   'iata': 'BHI',
#   'icao': 'SAZB',
#   'lat': -38.724899,
#   'lon': -62.1693,
#   'country': 'Argentina',
#   'alt': 246},
#  {'name': 'Bahia Solano Jose Celestino Mutis Airport',
#   'iata': 'BSC',
#   'icao': 'SKBS',
#   'lat': 6.202936,
#   'lon': -77.394798,
#   'country': 'Colombia',
#   'alt': 80},
#  {'name': 'Bahir Dar Airport',
#   'iata': 'BJR',
#   'icao': 'HABD',
#   'lat': 11.60807,
#   'lon': 37.32164,
#   'country': 'Ethiopia',
#   'alt': 5976},
#  {'name': 'Bahrain International Airport',
#   'iata': 'BAH',
#   'icao': 'OBBI',
#   'lat': 26.27083,
#   'lon': 50.63361,
#   'country': 'Bahrain',
#   'alt': 6},
#  {'name': 'Baia Mare Airport',
#   'iata': 'BAY',
#   'icao': 'LRBM',
#   'lat': 47.658379,
#   'lon': 23.47002,
#   'country': 'Romania',
#   'alt': 605},
#  {'name': "Baicheng Chang'an Airport",
#   'iata': 'DBC',
#   'icao': 'ZLGL',
#   'lat': 45.50528,
#   'lon': 123.019722,
#   'country': 'China',
#   'alt': 463},
#  {'name': 'Baie Comeau Airport',
#   'iata': 'YBC',
#   'icao': 'CYBC',
#   'lat': 49.1325,
#   'lon': -68.204399,
#   'country': 'Canada',
#   'alt': 71},
#  {'name': 'Bainbridge Decatur County Airport',
#   'iata': 'BGE',
#   'icao': 'KBGE',
#   'lat': 30.972855,
#   'lon': -84.635307,
#   'country': 'United States',
#   'alt': 134},
#  {'name': 'Bairnsdale Airport',
#   'iata': 'BSJ',
#   'icao': 'YBNS',
#   'lat': -37.887501,
#   'lon': 147.567993,
#   'country': 'Australia',
#   'alt': 165},
#  {'name': 'Baise Bama Airport',
#   'iata': 'AEB',
#   'icao': 'ZGBS',
#   'lat': 23.719469,
#   'lon': 106.967773,
#   'country': 'China',
#   'alt': 480},
#  {'name': 'Baishan Changbaishan Airport',
#   'iata': 'NBS',
#   'icao': 'ZYBS',
#   'lat': 42.088055,
#   'lon': 127.548889,
#   'country': 'China',
#   'alt': 2883},
# ...
#   'iata': 'CGF',
#   'icao': 'KCGF',
#   'lat': 41.565182,
#   'lon': -81.488052,
#   'country': 'United States',
#   'alt': 862},
#  {'name': 'Cleveland Hopkins International Airport',
#   'iata': 'CLE',
#   'icao': 'KCLE',
#   'lat': 41.410252,
#   'lon': -81.853897,
#   'country': 'United States',
#   'alt': 799},
#  {'name': 'Cleveland Municipal Airport',
#   'iata': 'QTN',
#   'icao': 'KRNV',
#   'lat': 33.761425,
#   'lon': -90.757881,
#   'country': 'United States',
#   'alt': 136},
#  {'name': 'Cloncurry Airport',
#   'iata': 'CNJ',
#   'icao': 'YCCY',
#   'lat': -20.668905,
#   'lon': 140.508514,
#   'country': 'Australia',
#   'alt': 616},
#  {'name': 'Cloudbreak Fortescue Dave Forrest Airport',
#   'iata': 'KFE',
#   'icao': 'YFDF',
#   'lat': -22.292,
#   'lon': 119.437225,
#   'country': 'Australia',
#   'alt': 1555},
#  {'name': 'Clovis Municipal Airport',
#   'iata': 'CVN',
#   'icao': 'KCVN',
#   'lat': 34.427223,
#   'lon': -103.078888,
#   'country': 'United States',
#   'alt': 4216},
#  {'name': 'Cluj-Napoca International Airport',
#   'iata': 'CLJ',
#   'icao': 'LRCL',
#   'lat': 46.785091,
#   'lon': 23.68611,
#   'country': 'Romania',
#   'alt': 1035},
#  {'name': 'Clyde River Airport',
#   'iata': 'YCY',
#   'icao': 'CYCY',
#   'lat': 70.486107,
#   'lon': -68.516602,
#   'country': 'Canada',
#   'alt': 87},
#  {'name': 'Coari Airport',
#   'iata': 'CIZ',
#   'icao': 'SWKO',
#   'lat': -4.1341,
#   'lon': -63.134789,
#   'country': 'Brazil',
#   'alt': 137},
#  {'name': 'Coatesville Chester County Area Airport',
#   'iata': 'CTH',
#   'icao': 'KMQS',
#   'lat': 39.979,
#   'lon': -75.865501,
#   'country': 'United States',
#   'alt': 660},
#  {'name': 'Cobar Airport',
#   'iata': 'CAZ',
#   'icao': 'YCBA',
#   'lat': -31.530001,
#   'lon': 145.789993,
#   'country': 'Australia',
#   'alt': 724},
#  {'name': 'Cobija Capitan Anibal Arab Airport',
#   'iata': 'CIJ',
#   'icao': 'SLCO',
#   'lat': -11.0404,
#   'lon': -68.782898,
#   'country': 'Bolivia',
#   'alt': 892},
#  {'name': 'Cochabamba Jorge Wilstermann International Airport',
#   'iata': 'CBB',
#   'icao': 'SLCB',
#   'lat': -17.421,
#   'lon': -66.177101,
#   'country': 'Bolivia',
#   'alt': 8360},
#  {'name': 'Cochin International Airport',
#   'iata': 'COK',
#   'icao': 'VOCI',
#   'lat': 10.15199,
#   'lon': 76.401901,
#   'country': 'India',
#   'alt': 30},
#  {'name': 'Coconut Island Airport',
#   'iata': 'CNC',
#   'icao': 'YCCT',
#   'lat': -10.05,
#   'lon': 143.070007,
#   'country': 'Australia',
#   'alt': 3},
#  {'name': 'Cocos Islands Airport',
#   'iata': 'CCK',
#   'icao': 'YPCC',
#   'lat': -12.188611,
#   'lon': 96.830559,
#   'country': 'Cocos (Keeling) Islands',
#   'alt': 10},
#  {'name': 'Cody Yellowstone Regional Airport',
#   'iata': 'COD',
#   'icao': 'KCOD',
#   'lat': 44.52,
#   'lon': -109.019997,
#   'country': 'United States',
#   'alt': 5102},
#  {'name': 'Coen Airport',
#   'iata': 'CUQ',
#   'icao': 'YCOE',
#   'lat': -13.763889,
#   'lon': 143.113327,
#   'country': 'Australia',
#   'alt': 532},
#  {'name': "Coeur d'Alene Airport",
#   'iata': 'COE',
#   'icao': 'KCOE',
#   'lat': 47.773605,
#   'lon': -116.824165,
#   'country': 'United States',
#   'alt': 2295},
#  {'name': 'Coffs Harbour Airport',
#   'iata': 'CFS',
#   'icao': 'YCFS',
#   'lat': -30.320499,
#   'lon': 153.116302,
#   'country': 'Australia',
#   'alt': 18},
#  {'name': 'Cognac Chateaubernard Air Base',
#   'iata': 'CNG',
#   'icao': 'LFBG',
#   'lat': 45.657669,
#   'lon': -0.314753,
#   'country': 'France',
#   'alt': 70},
#  {'name': 'Coimbatore International Airport',
#   'iata': 'CJB',
#   'icao': 'VOCB',
#   'lat': 11.03003,
#   'lon': 77.043381,
#   'country': 'India',
#   'alt': 1324},
#  {'name': 'Coimbra Airport',
#   'iata': 'CBP',
#   'icao': 'LPCO',
#   'lat': 40.1572,
#   'lon': -8.47,
#   'country': 'Portugal',
#   'alt': 587},
#  {'name': 'Colby Municipal Airport',
#   'iata': 'CBK',
#   'icao': 'KCBK',
#   'lat': 39.42614,
#   'lon': -101.050301,
#   'country': 'United States',
#   'alt': 3170},
#  {'name': 'Cold Bay Airport',
#   'iata': 'CDB',
#   'icao': 'PACD',
#   'lat': 55.206059,
#   'lon': -162.725006,
#   'country': 'United States',
#   'alt': 102},
#  {'name': 'Coldfoot Airport',
#   'iata': 'CXF',
#   'icao': 'PACX',
#   'lat': 67.252197,
#   'lon': -150.203995,
#   'country': 'United States',
#   'alt': 1042},
#  {'name': 'Colima Airport',
#   'iata': 'CLQ',
#   'icao': 'MMIA',
#   'lat': 19.27701,
#   'lon': -103.577003,
#   'country': 'Mexico',
#   'alt': 2467},
#  {'name': 'Coll Airport',
#   'iata': 'COL',
#   'icao': 'EGEL',
#   'lat': 56.601898,
#   'lon': -6.61778,
#   'country': 'United Kingdom',
#   'alt': 21},
#  {'name': 'Collarenebri Airport',
#   'iata': 'CRB',
#   'icao': 'YCBR',
#   'lat': -29.5217,
#   'lon': 148.582001,
#   'country': 'Australia',
#   'alt': 152},
#  {'name': 'College Park Airport',
#   'iata': 'CGS',
#   'icao': 'KCGS',
#   'lat': 38.980598,
#   'lon': -76.922302,
#   'country': 'United States',
#   'alt': 48},
#  {'name': 'College Station Easterwood Airport',
#   'iata': 'CLL',
#   'icao': 'KCLL',
#   'lat': 30.588579,
#   'lon': -96.3638,
#   'country': 'United States',
#   'alt': 320},
#  {'name': 'Collins Bay Airport',
#   'iata': 'YKC',
#   'icao': 'CYKC',
#   'lat': 58.236099,
#   'lon': -103.678001,
#   'country': 'Canada',
#   'alt': 1341},
#  {'name': 'Colmar Houssen Airport',
#   'iata': 'CMR',
#   'icao': 'LFGA',
#   'lat': 48.110352,
#   'lon': 7.359147,
#   'country': 'France',
#   'alt': 630},
#  {'name': 'Cologne Bonn Airport',
#   'iata': 'CGN',
#   'icao': 'EDDK',
#   'lat': 50.866001,
#   'lon': 7.143,
#   'country': 'Germany',
#   'alt': 302},
#  {'name': 'Colombo Bandaranaike International Airport',
#   'iata': 'CMB',
#   'icao': 'VCBI',
#   'lat': 7.181139,
#   'lon': 79.883789,
#   'country': 'Sri Lanka',
#   'alt': 32},
#  {'name': 'Colombo Ratmalana Airport',
#   'iata': 'RML',
#   'icao': 'VCCC',
#   'lat': 6.821994,
#   'lon': 79.8862,
#   'country': 'Sri Lanka',
#   'alt': 16},
#  {'name': 'Colon Enrique Adolfo Jimenez Airport',
#   'iata': 'ONX',
#   'icao': 'MPEJ',
#   'lat': 9.356639,
#   'lon': -79.867401,
#   'country': 'Panama',
#   'alt': 25},
#  {'name': 'Colonsay Airport',
#   'iata': 'CSA',
#   'icao': 'EGEY',
#   'lat': 56.057499,
#   'lon': -6.24306,
#   'country': 'United Kingdom',
#   'alt': 44},
#  {'name': 'Colorado Springs Airport',
#   'iata': 'COS',
#   'icao': 'KCOS',
#   'lat': 38.805801,
#   'lon': -104.699997,
#   'country': 'United States',
#   'alt': 6187},
#  {'name': 'Colorado Springs Meadow Lake Airport',
#   'iata': 'QTL',
#   'icao': 'KFLY',
#   'lat': 38.94595,
#   'lon': -104.571159,
#   'country': 'United States',
#   'alt': 6824},
#  {'name': 'Columbia Jim Hamilton Owens Airport',
#   'iata': 'CUB',
#   'icao': 'KCUB',
#   'lat': 33.970501,
#   'lon': -80.995201,
#   'country': 'United States',
#   'alt': 193},
#  {'name': 'Columbia Maury County Airport',
#   'iata': 'MRC',
#   'icao': 'KMRC',
#   'lat': 35.553375,
#   'lon': -87.177437,
#   'country': 'United States',
#   'alt': 676},
#  {'name': 'Columbia Metropolitan Airport',
#   'iata': 'CAE',
#   'icao': 'KCAE',
#   'lat': 33.938831,
#   'lon': -81.119499,
#   'country': 'United States',
#   'alt': 236},
#  {'name': 'Columbia Regional Airport',
#   'iata': 'COU',
#   'icao': 'KCOU',
#   'lat': 38.818089,
#   'lon': -92.219597,
#   'country': 'United States',
#   'alt': 889},
#  {'name': 'Columbus John Glenn International Airport',
#   'iata': 'CMH',
#   'icao': 'KCMH',
#   'lat': 39.997971,
#   'lon': -82.8918,
#   'country': 'United States',
#   'alt': 814},
#  {'name': 'Columbus Lowndes County Airport',
#   'iata': 'UBS',
#   'icao': 'KUBS',
#   'lat': 33.46452,
#   'lon': -88.380753,
#   'country': 'United States',
#   'alt': 185},
#  {'name': 'Columbus Metropolitan Airport',
#   'iata': 'CSG',
#   'icao': 'KCSG',
#   'lat': 32.516331,
#   'lon': -84.938797,
#   'country': 'United States',
#   'alt': 397},
#  {'name': 'Columbus Municipal Airport',
#   'iata': 'CLU',
#   'icao': 'KBAK',
#   'lat': 39.261902,
#   'lon': -85.896301,
#   'country': 'United States',
#   'alt': 656},
#  {'name': 'Columbus Municipal Airport',
#   'iata': 'OLU',
#   'icao': 'KOLU',
#   'lat': 41.447224,
#   'lon': -97.341667,
#   'country': 'United States',
#   'alt': 1444},
#  {'name': 'Columbus Ohio State University Airport',
#   'iata': 'OSU',
#   'icao': 'KOSU',
#   'lat': 40.079723,
#   'lon': -83.073059,
#   'country': 'United States',
#   'alt': 906},
#  {'name': 'Columbus Rickenbacker International Airport',
#   'iata': 'LCK',
#   'icao': 'KLCK',
#   'lat': 39.813782,
#   'lon': -82.927803,
#   'country': 'United States',
#   'alt': 744},
#  {'name': 'Comayagua Palmerola International Airport',
#   'iata': 'XPL',
#   'icao': 'MHPR',
#   'lat': 14.3824,
#   'lon': -87.621201,
#   'country': 'Honduras',
#   'alt': 2061},
#  {'name': 'Comiso Airport',
#   'iata': 'CIY',
#   'icao': 'LICB',
#   'lat': 36.990002,
#   'lon': 14.6,
#   'country': 'Italy',
#   'alt': 620},
#  {'name': 'Comodoro Rivadavia International Airport',
#   'iata': 'CRD',
#   'icao': 'SAVC',
#   'lat': -45.785301,
#   'lon': -67.4655,
#   'country': 'Argentina',
#   'alt': 190},
#  {'name': 'Comox Valley Airport',
#   'iata': 'YQQ',
#   'icao': 'CYQQ',
#   'lat': 49.710831,
#   'lon': -124.886002,
#   'country': 'Canada',
#   'alt': 84},
#  {'name': 'Compton Woodley Airport',
#   'iata': 'CPM',
#   'icao': 'KCPM',
#   'lat': 33.889999,
#   'lon': -118.244003,
#   'country': 'United States',
#   'alt': 97},
#  {'name': 'Con Dao Airport',
#   'iata': 'VCS',
#   'icao': 'VVCS',
#   'lat': 8.7325,
#   'lon': 106.628891,
#   'country': 'Vietnam',
#   'alt': 20},
#  {'name': 'Conakry International Airport',
#   'iata': 'CKY',
#   'icao': 'GUCY',
#   'lat': 9.576889,
#   'lon': -13.6119,
#   'country': 'Guinea',
#   'alt': 72},
#  {'name': 'Concepcion Carriel Sur International Airport',
#   'iata': 'CCP',
#   'icao': 'SCIE',
#   'lat': -36.772598,
#   'lon': -73.063103,
#   'country': 'Chile',
#   'alt': 26},
#  {'name': 'Concord Buchanan Field Airport',
#   'iata': 'CCR',
#   'icao': 'KCCR',
#   'lat': 37.988888,
#   'lon': -122.055557,
#   'country': 'United States',
#   'alt': 23},
#  {'name': 'Concord Municipal Airport',
#   'iata': 'CON',
#   'icao': 'KCON',
#   'lat': 43.202702,
#   'lon': -71.502296,
#   'country': 'United States',
#   'alt': 342},
#  {'name': 'Concord Regional Airport',
#   'iata': 'USA',
#   'icao': 'KJQF',
#   'lat': 35.385139,
#   'lon': -80.711189,
#   'country': 'United States',
#   'alt': 662},
#  {'name': 'Confresa Airport',
#   'iata': 'CFO',
#   'icao': 'SJHG',
#   'lat': -10.6344,
#   'lon': -51.563599,
#   'country': 'Brazil',
#   'alt': 781},
#  {'name': 'Congo Town South Andros Airport',
#   'iata': 'TZN',
#   'icao': 'MYAK',
#   'lat': 24.158367,
#   'lon': -77.588799,
#   'country': 'Bahamas',
#   'alt': 41},
#  {'name': 'Conroe Lone Star Executive Airport',
#   'iata': 'CXO',
#   'icao': 'KCXO',
#   'lat': 30.35236,
#   'lon': -95.414497,
#   'country': 'United States',
#   'alt': 245},
#  {'name': 'Constanta International Airport',
#   'iata': 'CND',
#   'icao': 'LRCK',
#   'lat': 44.362221,
#   'lon': 28.488331,
#   'country': 'Romania',
#   'alt': 353},
#  {'name': 'Constantine Mohamed Boudiaf International Airport',
#   'iata': 'CZL',
#   'icao': 'DABC',
#   'lat': 36.27602,
#   'lon': 6.620386,
#   'country': 'Algeria',
#   'alt': 2316},
#  {'name': 'Coober Pedy Airport',
#   'iata': 'CPD',
#   'icao': 'YCBP',
#   'lat': -29.039942,
#   'lon': 134.720154,
#   'country': 'Australia',
#   'alt': 738},
#  {'name': 'Cooktown Airport',
#   'iata': 'CTN',
#   'icao': 'YCKN',
#   'lat': -15.443333,
#   'lon': 145.183334,
#   'country': 'Australia',
#   'alt': 26},
#  {'name': 'Cooma Snowy Mountains Airport',
#   'iata': 'OOM',
#   'icao': 'YCOM',
#   'lat': -36.299999,
#   'lon': 148.970001,
#   'country': 'Australia',
#   'alt': 3088},
#  {'name': 'Coondewanna Airport',
#   'iata': 'CJF',
#   'icao': 'YCWA',
#   'lat': -22.965,
#   'lon': 118.809998,
#   'country': 'Australia',
#   'alt': 2327},
#  {'name': 'Copenhagen Airport',
#   'iata': 'CPH',
#   'icao': 'EKCH',
#   'lat': 55.616959,
#   'lon': 12.645637,
#   'country': 'Denmark',
#   'alt': 17},
#  {'name': 'Copenhagen Sea Airport',
#   'iata': 'QEC',
#   'icao': 'EKCC',
#   'lat': 55.691055,
#   'lon': 12.600377,
#   'country': 'Denmark',
#   'alt': 1},
#  {'name': 'Copiapo Desierto de Atacama Airport',
#   'iata': 'CPO',
#   'icao': 'SCAT',
#   'lat': -27.261248,
#   'lon': -70.779221,
#   'country': 'Chile',
#   'alt': 670},
#  {'name': 'Coral Harbour Airport',
#   'iata': 'YZS',
#   'icao': 'CYZS',
#   'lat': 64.193329,
#   'lon': -83.359398,
#   'country': 'Canada',
#   'alt': 210},
#  {'name': 'Cordoba Airport',
#   'iata': 'ODB',
#   'icao': 'LEBA',
#   'lat': 37.841999,
#   'lon': -4.84887,
#   'country': 'Spain',
#   'alt': 297},
#  {'name': 'Cordoba International Airport',
#   'iata': 'COR',
#   'icao': 'SACO',
#   'lat': -31.323601,
#   'lon': -64.207901,
#   'country': 'Argentina',
#   'alt': 1604},
#  {'name': 'Cordova Mudhole Smith Airport',
#   'iata': 'CDV',
#   'icao': 'PACV',
#   'lat': 60.491772,
#   'lon': -145.477005,
#   'country': 'United States',
#   'alt': 54},
#  {'name': 'Corfu International Airport',
#   'iata': 'CFU',
#   'icao': 'LGKR',
#   'lat': 39.60194,
#   'lon': 19.911659,
#   'country': 'Greece',
#   'alt': 6},
#  {'name': 'Cork Airport',
#   'iata': 'ORK',
#   'icao': 'EICK',
#   'lat': 51.841381,
#   'lon': -8.49111,
#   'country': 'Ireland',
#   'alt': 502},
#  {'name': 'Cornelio Procopio Airport',
#   'iata': 'CKO',
#   'icao': 'SSCP',
#   'lat': -23.1525,
#   'lon': -50.602501,
#   'country': 'Brazil',
#   'alt': 1854},
#  {'name': 'Coro Jose Leonardo Chirinos Airport',
#   'iata': 'CZE',
#   'icao': 'SVCR',
#   'lat': 11.41486,
#   'lon': -69.681602,
#   'country': 'Venezuela',
#   'alt': 52},
#  {'name': 'Corowa Airport',
#   'iata': 'CWW',
#   'icao': 'YCOR',
#   'lat': -35.994701,
#   'lon': 146.356995,
#   'country': 'Australia',
#   'alt': 469},
#  {'name': 'Corozal Airport',
#   'iata': 'CZH',
#   'icao': 'MZCZ',
#   'lat': 18.382221,
#   'lon': -88.410835,
#   'country': 'Belize',
#   'alt': 39},
#  {'name': 'Corozal Las Brujas Airport',
#   'iata': 'CZU',
#   'icao': 'SKCZ',
#   'lat': 9.333333,
#   'lon': -75.283302,
#   'country': 'Colombia',
#   'alt': 528},
#  {'name': 'Corpus Christi International Airport',
#   'iata': 'CRP',
#   'icao': 'KCRP',
#   'lat': 27.770361,
#   'lon': -97.501198,
#   'country': 'United States',
#   'alt': 44},
#  {'name': 'Correia Pinto Planalto Serrano Regional Airport',
#   'iata': 'EEA',
#   'icao': 'SNCP',
#   'lat': -27.634167,
#   'lon': -50.358334,
#   'country': 'Brazil',
#   'alt': 2887},
#  {'name': 'Corrientes International Airport',
#   'iata': 'CNQ',
#   'icao': 'SARC',
#   'lat': -27.445499,
#   'lon': -58.761799,
#   'country': 'Argentina',
#   'alt': 203},
#  {'name': 'Corsicana Municipal Airport',
#   'iata': 'CRS',
#   'icao': 'KCRS',
#   'lat': 32.027225,
#   'lon': -96.39785,
#   'country': 'United States',
#   'alt': 442},
#  {'name': 'Cortez Municipal Airport',
#   'iata': 'CEZ',
#   'icao': 'KCEZ',
#   'lat': 37.302776,
#   'lon': -108.62722,
#   'country': 'United States',
#   'alt': 5918},
#  {'name': 'Corumba International Airport',
#   'iata': 'CMG',
#   'icao': 'SBCR',
#   'lat': -19.0119,
#   'lon': -57.673,
#   'country': 'Brazil',
#   'alt': 461},
#  {'name': 'Corvallis Municipal Airport',
#   'iata': 'CVO',
#   'icao': 'KCVO',
#   'lat': 44.501186,
#   'lon': -123.285698,
#   'country': 'United States',
#   'alt': 243},
#  {'name': 'Corvo Airport',
#   'iata': 'CVU',
#   'icao': 'LPCR',
#   'lat': 39.671379,
#   'lon': -31.1166,
#   'country': 'Portugal',
#   'alt': 98},
#  {'name': 'Cotabato Awang Airport',
#   'iata': 'CBO',
#   'icao': 'RPWC',
#   'lat': 7.165242,
#   'lon': 124.209602,
#   'country': 'Philippines',
#   'alt': 189},
#  {'name': 'Cotonou Cadjehoun Airport',
#   'iata': 'COO',
#   'icao': 'DBBB',
#   'lat': 6.357228,
#   'lon': 2.384353,
#   'country': 'Benin',
#   'alt': 19},
#  {'name': 'Cotulla La Salle County Airport',
#   'iata': 'COT',
#   'icao': 'KCOT',
#   'lat': 28.45669,
#   'lon': -99.2183,
#   'country': 'United States',
#   'alt': 474},
#  {'name': 'Council Bluffs Municipal Airport',
#   'iata': 'CBF',
#   'icao': 'KCBF',
#   'lat': 41.259201,
#   'lon': -95.760597,
#   'country': 'United States',
#   'alt': 1253},
#  {'name': 'Courchevel Altiport',
#   'iata': 'CVF',
#   'icao': 'LFLJ',
#   'lat': 45.39666,
#   'lon': 6.633611,
#   'country': 'France',
#   'alt': 6580},
#  {'name': 'Coventry Airport',
#   'iata': 'CVT',
#   'icao': 'EGBE',
#   'lat': 52.36972,
#   'lon': -1.47972,
#   'country': 'United Kingdom',
#   'alt': 267},
#  {'name': "Cox's Bazar Airport",
#   'iata': 'CXB',
#   'icao': 'VGCB',
#   'lat': 21.45219,
#   'lon': 91.963882,
#   'country': 'Bangladesh',
#   'alt': 12},
#  {'name': 'Cozumel International Airport',
#   'iata': 'CZM',
#   'icao': 'MMCZ',
#   'lat': 20.5224,
#   'lon': -86.925598,
#   'country': 'Mexico',
#   'alt': 15},
#  {'name': 'Craig Moffat Airport',
#   'iata': 'CIG',
#   'icao': 'KCAG',
#   'lat': 40.495201,
#   'lon': -107.522003,
#   'country': 'United States',
#   'alt': 6193},
#  ...]

# %%
import flightradar24
fr = flightradar24.Api()
airlines = fr.get_airlines()
airlines['rows']
# Out:
# [{'Name': '21 Air', 'Code': '2I', 'ICAO': 'CSB'},
#  {'Name': '25only Aviation', 'Code': '4Q', 'ICAO': 'ONY'},
#  {'Name': '2Excel Aviation', 'Code': '', 'ICAO': 'BRO'},
#  {'Name': '40-Mile Air', 'Code': 'Q5', 'ICAO': 'MLA'},
#  {'Name': '748 Air Services', 'Code': 'FE', 'ICAO': 'IHO'},
#  {'Name': '9 Air', 'Code': 'AQ', 'ICAO': 'JYH'},
#  {'Name': 'Abakan Air', 'Code': 'S5', 'ICAO': 'NKP'},
#  {'Name': 'ABS Jets', 'Code': '', 'ICAO': 'ABP'},
#  {'Name': 'Abu Dhabi Aviation', 'Code': '', 'ICAO': 'BAR'},
#  {'Name': 'ABX Air', 'Code': 'GB', 'ICAO': 'ABX'},
#  {'Name': 'Acass Ireland', 'Code': '', 'ICAO': 'SON'},
#  {'Name': 'Advanced Air', 'Code': 'AN', 'ICAO': 'WSN'},
#  {'Name': 'Aegean Airlines', 'Code': 'A3', 'ICAO': 'AEE'},
#  {'Name': 'Aer Lingus', 'Code': 'EI', 'ICAO': 'EIN'},
#  {'Name': 'Aer Lingus UK', 'Code': 'EG', 'ICAO': 'EUK'},
#  {'Name': 'AerCaribe', 'Code': 'JK', 'ICAO': 'ACL'},
#  {'Name': 'Aero', 'Code': 'TD', 'ICAO': 'BLK'},
#  {'Name': 'Aero', 'Code': 'N2', 'ICAO': 'NIG'},
#  {'Name': 'Aero Asahi Corporation', 'Code': '', 'ICAO': 'AKF'},
#  {'Name': 'Aero Charter', 'Code': '', 'ICAO': 'GLT'},
#  {'Name': 'Aero Charter and Transport', 'Code': '', 'ICAO': 'CTA'},
#  {'Name': 'Aero FlightOps UK', 'Code': 'FO', 'ICAO': 'UKA'},
#  {'Name': 'Aero Guernsey', 'Code': '', 'ICAO': 'AEO'},
#  {'Name': 'Aero K', 'Code': 'RF', 'ICAO': 'EOK'},
#  {'Name': 'Aero Mongolia', 'Code': 'M0', 'ICAO': 'MNG'},
#  {'Name': 'Aero Nomad Airlines', 'Code': 'KA', 'ICAO': 'ANK'},
#  {'Name': 'Aero Sotravia', 'Code': '', 'ICAO': 'ASR'},
#  {'Name': 'Aero-Beta Flight Training', 'Code': '', 'ICAO': 'ABA'},
#  {'Name': 'Aero-Dienst', 'Code': '', 'ICAO': 'ADN'},
#  {'Name': 'Aero-Service', 'Code': '', 'ICAO': 'RSR'},
#  {'Name': 'Aero4M', 'Code': '', 'ICAO': 'AEH'},
#  {'Name': 'Aeroflot', 'Code': 'SU', 'ICAO': 'AFL'},
#  {'Name': 'Aeroitalia', 'Code': 'XZ', 'ICAO': 'AEZ'},
#  {'Name': 'Aerolineas Argentinas', 'Code': 'AR', 'ICAO': 'ARG'},
#  {'Name': 'Aerolineas Ejecutivas', 'Code': '', 'ICAO': 'LET'},
#  {'Name': 'Aerolineas Sosa', 'Code': 'P4', 'ICAO': 'NSO'},
#  {'Name': 'Aerolink Uganda', 'Code': 'A8', 'ICAO': 'XAU'},
#  {'Name': 'AeroLogic', 'Code': '3S', 'ICAO': 'BOX'},
#  {'Name': 'Aeromar', 'Code': 'VW', 'ICAO': 'TAO'},
#  {'Name': 'Aeromexico', 'Code': 'AM', 'ICAO': 'AMX'},
#  {'Name': 'Aeromexico Connect', 'Code': '5D', 'ICAO': 'SLI'},
#  {'Name': 'Aeronaves TSM', 'Code': '', 'ICAO': 'VTM'},
#  {'Name': 'Aeropartner', 'Code': '', 'ICAO': 'DFC'},
#  {'Name': 'Aeroregional', 'Code': '', 'ICAO': 'RER'},
#  {'Name': 'Aeroservicios de la Costa', 'Code': '', 'ICAO': 'TAA'},
#  {'Name': 'Aerostan', 'Code': '', 'ICAO': 'BSC'},
#  {'Name': 'Aerosucre', 'Code': '', 'ICAO': 'KRE'},
#  {'Name': 'Aerosul Linhas Aereas', 'Code': '', 'ICAO': 'ASO'},
#  {'Name': 'Aerotec', 'Code': '', 'ICAO': 'AEP'},
#  {'Name': 'Aerotours', 'Code': '', 'ICAO': 'ATU'},
#  {'Name': 'Aerotranscargo', 'Code': 'F5', 'ICAO': 'ATG'},
#  {'Name': 'AeroUnion', 'Code': '6R', 'ICAO': 'TNO'},
#  {'Name': 'Aerovias DAP', 'Code': 'V5', 'ICAO': 'DAP'},
#  {'Name': 'Aerovis Airlines', 'Code': '', 'ICAO': 'VIZ'},
#  {'Name': 'Aerro Direkt', 'Code': '4D', 'ICAO': 'DIR'},
#  {'Name': 'AF-Aviation', 'Code': '', 'ICAO': 'AFF'},
#  {'Name': 'Afric Aviation', 'Code': 'L8', 'ICAO': 'EKG'},
#  {'Name': 'Africa Airlines', 'Code': '', 'ICAO': 'AAT'},
#  {'Name': 'Africa Charter Airline', 'Code': '', 'ICAO': 'FSK'},
#  {'Name': 'Africa World Airlines', 'Code': 'AW', 'ICAO': 'AFW'},
#  {'Name': 'African Express Airways', 'Code': 'XU', 'ICAO': 'AXK'},
#  {'Name': 'Afrijet', 'Code': 'J7', 'ICAO': 'ABS'},
#  {'Name': 'Afriqiyah Airways', 'Code': '8U', 'ICAO': 'AAW'},
#  {'Name': 'Air 1st Aviation', 'Code': '', 'ICAO': 'RUF'},
#  {'Name': 'Air Albania', 'Code': 'ZB', 'ICAO': 'ABN'},
#  {'Name': 'Air Algerie', 'Code': 'AH', 'ICAO': 'DAH'},
#  {'Name': 'Air Alliance', 'Code': '', 'ICAO': 'AYY'},
#  {'Name': 'Air Alsie', 'Code': '6I', 'ICAO': 'MMD'},
#  {'Name': 'Air Anka', 'Code': 'TZ', 'ICAO': 'TAH'},
#  {'Name': 'Air Antilles', 'Code': '3S', 'ICAO': 'GUY'},
#  {'Name': 'Air Arabia', 'Code': 'G9', 'ICAO': 'ABY'},
#  {'Name': 'Air Arabia Abu Dhabi', 'Code': '3L', 'ICAO': 'ADY'},
#  {'Name': 'Air Arabia Egypt', 'Code': 'E5', 'ICAO': 'RBG'},
#  {'Name': 'Air Arabia Maroc', 'Code': '3O', 'ICAO': 'MAC'},
#  {'Name': 'Air Astana', 'Code': 'KC', 'ICAO': 'KZR'},
#  {'Name': 'Air Astra', 'Code': '2A', 'ICAO': 'AWA'},
#  {'Name': 'Air Atlanta Europe', 'Code': 'CT', 'ICAO': 'AAE'},
#  {'Name': 'Air Atlanta Icelandic', 'Code': 'CC', 'ICAO': 'ABD'},
#  {'Name': 'Air Austral', 'Code': 'UU', 'ICAO': 'REU'},
#  {'Name': 'Air Bagan', 'Code': 'W9', 'ICAO': 'JAB'},
#  {'Name': 'Air Baltic', 'Code': 'BT', 'ICAO': 'BTI'},
#  {'Name': 'Air Belgium', 'Code': 'KF', 'ICAO': 'ABB'},
#  {'Name': 'Air Bohemia', 'Code': '', 'ICAO': 'BOH'},
#  {'Name': 'Air Borealis', 'Code': '', 'ICAO': 'LBR'},
#  {'Name': 'Air Botswana', 'Code': 'BP', 'ICAO': 'BOT'},
#  {'Name': 'Air Bucharest', 'Code': '', 'ICAO': 'BUR'},
#  {'Name': 'Air Burkina', 'Code': '2J', 'ICAO': 'VBW'},
#  {'Name': 'Air Busan', 'Code': 'BX', 'ICAO': 'ABL'},
#  {'Name': 'Air Cairo', 'Code': 'SM', 'ICAO': 'MSC'},
#  {'Name': 'Air Caledonie', 'Code': 'TY', 'ICAO': 'TPC'},
#  {'Name': 'Air Canada', 'Code': 'AC', 'ICAO': 'ACA'},
#  {'Name': 'Air Canada Rouge', 'Code': 'RV', 'ICAO': 'ROU'},
#  {'Name': 'Air Caraibes', 'Code': 'TX', 'ICAO': 'FWI'},
#  {'Name': 'Air Care Alliance', 'Code': '', 'ICAO': 'CMF'},
#  {'Name': 'Air Cargo Carriers', 'Code': '2Q', 'ICAO': 'SNC'},
#  {'Name': 'Air Cargo Global', 'Code': 'CW', 'ICAO': 'CCC'},
#  {'Name': 'Air Central', 'Code': 'GI', 'ICAO': 'LHA'},
#  {'Name': 'Air Century', 'Code': 'Y2', 'ICAO': 'CEY'},
#  {'Name': 'Air Changan', 'Code': '9H', 'ICAO': 'CGN'},
#  {'Name': 'Air Charity Network', 'Code': '', 'ICAO': 'NGF'},
#  {'Name': 'Air Charter Scotland', 'Code': '', 'ICAO': 'EDC'},
#  {'Name': 'Air Charter Scotland Europe', 'Code': '', 'ICAO': 'SCO'},
#  {'Name': 'Air Chathams', 'Code': '3C', 'ICAO': 'CVA'},
#  {'Name': 'Air China', 'Code': 'CA', 'ICAO': 'CCA'},
#  {'Name': 'Air China Cargo', 'Code': '', 'ICAO': 'CAO'},
#  {'Name': 'Air China Inner Mongolia', 'Code': '', 'ICAO': 'CNM'},
#  {'Name': 'Air Choice One', 'Code': '3E', 'ICAO': 'ACO'},
#  {'Name': 'Air Class', 'Code': '', 'ICAO': 'QCL'},
#  {'Name': 'AirConnect', 'Code': 'KS', 'ICAO': 'KON'},
#  {'Name': 'Air Corporate', 'Code': '', 'ICAO': 'CPV'},
#  {'Name': 'Air Corsica', 'Code': 'XK', 'ICAO': 'CCM'},
#  {'Name': 'Air Costa Rica', 'Code': 'RI', 'ICAO': 'RII'},
#  {'Name': "Air Cote d'Ivoire", 'Code': 'HF', 'ICAO': 'VRE'},
#  {'Name': 'Air Creebec', 'Code': 'YN', 'ICAO': 'CRQ'},
#  {'Name': 'Air Deccan', 'Code': '', 'ICAO': 'DKN'},
#  {'Name': 'Air Djibouti', 'Code': 'DJ', 'ICAO': 'DJB'},
#  {'Name': 'Air Do', 'Code': 'HD', 'ICAO': 'ADO'},
#  {'Name': 'Air Dolomiti', 'Code': 'EN', 'ICAO': 'DLA'},
#  {'Name': 'Air Europa', 'Code': 'UX', 'ICAO': 'AEA'},
#  {'Name': 'Air Europa Express', 'Code': 'X5', 'ICAO': 'OVA'},
#  {'Name': 'Air Excel', 'Code': '', 'ICAO': 'XLL'},
#  {'Name': 'Air Falcon', 'Code': 'FS', 'ICAO': 'FPK'},
#  {'Name': 'Air Flamenco', 'Code': 'F4', 'ICAO': 'WAF'},
#  {'Name': 'Air France', 'Code': 'AF', 'ICAO': 'AFR'},
#  {'Name': 'Air France Hop', 'Code': 'A5', 'ICAO': 'HOP'},
#  {'Name': 'Air Georgia', 'Code': 'DC', 'ICAO': 'AGF'},
#  {'Name': 'Air Ghana', 'Code': '', 'ICAO': 'GHN'},
#  {'Name': 'Air Greenland', 'Code': 'GL', 'ICAO': 'GRL'},
#  {'Name': 'Air Guilin', 'Code': 'GT', 'ICAO': 'CGH'},
#  {'Name': 'Air Hamburg', 'Code': '', 'ICAO': 'AHO'},
#  {'Name': 'Air Hong Kong', 'Code': 'LD', 'ICAO': 'AHK'},
#  {'Name': 'Air Horizont', 'Code': 'HT', 'ICAO': 'HAT'},
#  {'Name': 'Air Incheon', 'Code': 'KJ', 'ICAO': 'AIH'},
#  {'Name': 'Air India', 'Code': 'AI', 'ICAO': 'AIC'},
#  {'Name': 'Air India Express', 'Code': 'IX', 'ICAO': 'AXB'},
#  {'Name': 'Air Inuit', 'Code': '3H', 'ICAO': 'AIE'},
#  {'Name': 'Air Japan', 'Code': 'NQ', 'ICAO': 'AJX'},
#  {'Name': 'Air KBZ', 'Code': 'K7', 'ICAO': 'KBZ'},
#  {'Name': 'Air Key West', 'Code': '', 'ICAO': 'KWX'},
#  {'Name': 'Air Kiribati', 'Code': 'IK', 'ICAO': 'AKL'},
#  {'Name': 'Air Koryo', 'Code': 'JS', 'ICAO': 'KOR'},
#  {'Name': 'Air Leisure', 'Code': 'AL', 'ICAO': 'ALD'},
#  {'Name': 'Air Liaison', 'Code': 'DU', 'ICAO': 'LSJ'},
#  {'Name': 'Air Libya', 'Code': '7I', 'ICAO': 'TLR'},
#  {'Name': 'Air Loyaute', 'Code': '', 'ICAO': 'RLY'},
#  {'Name': 'Air Macau', 'Code': 'NX', 'ICAO': 'AMU'},
#  {'Name': 'Air Madagascar', 'Code': 'MD', 'ICAO': 'MDG'},
#  {'Name': 'Air Malta', 'Code': 'KM', 'ICAO': 'AMC'},
#  {'Name': 'Air Manas', 'Code': 'ZM', 'ICAO': 'MBB'},
#  {'Name': 'Air Mauritius', 'Code': 'MK', 'ICAO': 'MAU'},
#  {'Name': 'Air Mediterranean', 'Code': 'MV', 'ICAO': 'MAR'},
#  {'Name': 'Air Moana', 'Code': 'NM', 'ICAO': 'NTR'},
#  {'Name': 'Air Moldova', 'Code': '9U', 'ICAO': 'MLD'},
#  {'Name': 'Air Montenegro', 'Code': '', 'ICAO': 'MNE'},
#  {'Name': 'Air Mountain', 'Code': '', 'ICAO': 'AMT'},
#  {'Name': 'Air New Zealand', 'Code': 'NZ', 'ICAO': 'ANZ'},
#  {'Name': 'Air Niugini', 'Code': 'PX', 'ICAO': 'ANG'},
#  {'Name': 'Air North', 'Code': '4N', 'ICAO': 'ANT'},
#  {'Name': 'Air Nostrum', 'Code': 'YW', 'ICAO': 'ANE'},
#  {'Name': 'Air Nunavut', 'Code': '', 'ICAO': 'BFF'},
#  {'Name': 'Air Panama', 'Code': '7P', 'ICAO': 'PST'},
#  {'Name': 'Air Peace', 'Code': 'P4', 'ICAO': 'APK'},
#  {'Name': 'Air Premia', 'Code': 'YP', 'ICAO': 'APZ'},
#  {'Name': 'Air Rarotonga', 'Code': 'GZ', 'ICAO': 'RAR'},
#  {'Name': 'Air Saint-Pierre', 'Code': 'PJ', 'ICAO': 'SPM'},
#  {'Name': 'Air Senegal', 'Code': 'HC', 'ICAO': 'SZN'},
#  {'Name': 'Air Seoul', 'Code': 'RS', 'ICAO': 'ASV'},
#  {'Name': 'Air Seychelles', 'Code': 'HM', 'ICAO': 'SEY'},
#  {'Name': 'Air Sphinx', 'Code': '', 'ICAO': 'ASD'},
#  {'Name': 'Air Spray', 'Code': '', 'ICAO': 'ASB'},
#  {'Name': 'Air Sunshine', 'Code': '', 'ICAO': 'RSI'},
#  {'Name': 'Air Tahiti', 'Code': 'VT', 'ICAO': 'VTA'},
#  {'Name': 'Air Tahiti Nui', 'Code': 'TN', 'ICAO': 'THT'},
#  {'Name': 'Air Tanzania', 'Code': 'TC', 'ICAO': 'ATC'},
#  {'Name': 'Air Taxi & Charter International', 'Code': '', 'ICAO': 'IBJ'},
#  {'Name': 'Air Thanlwin', 'Code': 'ST', 'ICAO': 'RTL'},
#  {'Name': 'Air Tindi', 'Code': '8T', 'ICAO': 'TIN'},
#  {'Name': 'Air Transat', 'Code': 'TS', 'ICAO': 'TSC'},
#  {'Name': 'Air Transport Europe', 'Code': '', 'ICAO': 'EAT'},
#  {'Name': 'Air Transport International', 'Code': '8C', 'ICAO': 'ATN'},
#  {'Name': 'Air Travel', 'Code': 'A6', 'ICAO': 'OTC'},
#  {'Name': 'Air Urga', 'Code': '3N', 'ICAO': 'URG'},
#  {'Name': 'Air Vanuatu', 'Code': 'NF', 'ICAO': 'AVN'},
#  {'Name': 'Air Volta', 'Code': '', 'ICAO': 'VLB'},
#  {'Name': 'Air Wisconsin', 'Code': 'ZW', 'ICAO': 'AWI'},
#  {'Name': 'Air X Charter', 'Code': 'AX', 'ICAO': 'AXY'},
#  {'Name': 'Air Zimbabwe', 'Code': 'UM', 'ICAO': 'AZW'},
#  {'Name': 'Air-Glaciers', 'Code': '', 'ICAO': 'AGV'},
#  {'Name': 'Air-Taxi Europe', 'Code': '', 'ICAO': 'TWG'},
#  {'Name': 'AirACT', 'Code': '9T', 'ICAO': 'RUN'},
#  {'Name': 'AirAsia', 'Code': 'AK', 'ICAO': 'AXM'},
#  {'Name': 'AirAsia India', 'Code': 'I5', 'ICAO': 'IAD'},
#  {'Name': 'AirAsia X', 'Code': 'D7', 'ICAO': 'XAX'},
#  {'Name': 'AirBlue', 'Code': 'PA', 'ICAO': 'ABQ'},
#  {'Name': 'AirBridgeCargo Airlines', 'Code': 'RU', 'ICAO': 'ABW'},
#  {'Name': 'Airbus', 'Code': '', 'ICAO': 'AIB'},
#  {'Name': 'Airbus Transport International', 'Code': '4Y', 'ICAO': 'BGA'},
#  {'Name': 'Aircalin', 'Code': 'SB', 'ICAO': 'ACI'},
#  {'Name': 'Aircompany Armenia', 'Code': 'RM', 'ICAO': 'NGT'},
#  {'Name': 'Aircompany RusJet', 'Code': '', 'ICAO': 'RSJ'},
#  {'Name': 'Aircraft Management Group', 'Code': '', 'ICAO': 'RVJ'},
#  {'Name': 'Aireon Canada', 'Code': '', 'ICAO': 'AEN'},
#  {'Name': 'Airest', 'Code': '', 'ICAO': 'AEG'},
#  {'Name': 'AirExplore', 'Code': 'ED', 'ICAO': 'AXE'},
#  {'Name': 'Airfast Indonesia', 'Code': '', 'ICAO': 'AFE'},
#  {'Name': 'AirGO Private Airline', 'Code': '', 'ICAO': 'XGO'},
#  {'Name': 'Airhub Airlines', 'Code': 'RE', 'ICAO': 'GJM'},
#  {'Name': 'Airkenya Express', 'Code': 'P2', 'ICAO': 'XAK'},
#  {'Name': 'Airlec Air Espace', 'Code': '', 'ICAO': 'ARL'},
#  {'Name': 'Airlift', 'Code': '', 'ICAO': 'ALI'},
#  {'Name': 'Airlift International', 'Code': '', 'ICAO': 'AIR'},
#  {'Name': 'Airlink', 'Code': '', 'ICAO': 'JAR'},
#  {'Name': 'Airlink', 'Code': '4Z', 'ICAO': 'LNK'},
#  {'Name': 'AirNet', 'Code': '', 'ICAO': 'USC'},
#  {'Name': 'Airnorth', 'Code': 'TL', 'ICAO': 'ANO'},
#  {'Name': 'Airpac Airlines', 'Code': '', 'ICAO': 'APC'},
#  {'Name': 'AirPink', 'Code': '', 'ICAO': 'PNK'},
#  {'Name': 'AirSERBIA', 'Code': 'JU', 'ICAO': 'ASL'},
#  {'Name': 'AirSF Flight Services', 'Code': '', 'ICAO': 'XSN'},
#  {'Name': 'AirShare', 'Code': '', 'ICAO': 'XSR'},
#  {'Name': 'AirSial', 'Code': 'PF', 'ICAO': 'SIF'},
#  {'Name': 'AirSmart', 'Code': '', 'ICAO': 'XSM'},
#  {'Name': 'AirSprint', 'Code': '', 'ICAO': 'ASP'},
#  {'Name': 'Airstream', 'Code': '', 'ICAO': 'AQS'},
#  {'Name': 'AirSWIFT', 'Code': 'T6', 'ICAO': 'ATX'},
#  {'Name': 'AirTanker', 'Code': '9L', 'ICAO': 'TOW'},
#  {'Name': 'Airtask', 'Code': '', 'ICAO': 'DCT'},
#  {'Name': 'AirTraffic', 'Code': '', 'ICAO': 'ATY'},
#  {'Name': 'Airwing', 'Code': '', 'ICAO': 'NWG'},
#  {'Name': 'Airwork', 'Code': '', 'ICAO': 'AWK'},
#  {'Name': 'AIS Airlines', 'Code': '', 'ICAO': 'PNX'},
#  {'Name': 'Ajwaa Airlines', 'Code': '', 'ICAO': 'AJY'},
#  {'Name': 'Akasa Air', 'Code': 'QP', 'ICAO': 'AKJ'},
#  {'Name': 'Al-Atheer Aviation', 'Code': '', 'ICAO': 'ATE'},
#  {'Name': 'Al-Naser Wings', 'Code': 'NG', 'ICAO': 'NAD'},
#  {'Name': 'Alante Air Charter', 'Code': '', 'ICAO': 'SVL'},
#  {'Name': 'Alaska Airlines', 'Code': 'AS', 'ICAO': 'ASA'},
#  {'Name': 'Alaska Central Express', 'Code': 'KO', 'ICAO': 'AER'},
#  {'Name': 'AlbaStar', 'Code': 'AP', 'ICAO': 'LAV'},
#  {'Name': 'Albatros Airlines', 'Code': 'G0', 'ICAO': 'GAL'},
#  {'Name': 'Albawings', 'Code': '2B', 'ICAO': 'AWT'},
#  {'Name': 'Albinati Aeronautics', 'Code': '', 'ICAO': 'LUC'},
#  {'Name': 'Albinati Aeronautics', 'Code': '', 'ICAO': 'ULC'},
#  {'Name': 'Alexandria Airlines', 'Code': 'DQ', 'ICAO': 'KHH'},
#  {'Name': 'Alfa Airlines', 'Code': '5E', 'ICAO': 'AAJ'},
#  {'Name': 'Algonquin Airlink', 'Code': '', 'ICAO': 'FSY'},
#  {'Name': 'Alidaunia', 'Code': 'D4', 'ICAO': 'LID'},
#  {'Name': 'AlisCargo Airlines', 'Code': 'CP', 'ICAO': 'LSI'},
#  {'Name': 'Aliserio', 'Code': '', 'ICAO': 'TJD'},
#  {'Name': 'ALK Airlines', 'Code': '', 'ICAO': 'VBB'},
#  {'Name': 'Alkan Air', 'Code': '', 'ICAO': 'ALN'},
#  {'Name': 'Alkan Air', 'Code': '', 'ICAO': 'AKN'},
#  {'Name': 'All Nippon Airways', 'Code': 'NH', 'ICAO': 'ANA'},
#  {'Name': 'Allegiant Air', 'Code': 'G4', 'ICAO': 'AAY'},
#  {'Name': 'Alliance Air', 'Code': '9I', 'ICAO': 'LLR'},
#  {'Name': 'Alliance Airlines', 'Code': 'QQ', 'ICAO': 'UTY'},
#  {'Name': 'Allied Air', 'Code': '4W', 'ICAO': 'AJK'},
#  {'Name': 'AlMasria Universal Airlines', 'Code': 'UJ', 'ICAO': 'LMU'},
#  {'Name': 'Aloha Air Cargo', 'Code': 'KH', 'ICAO': 'AAH'},
#  {'Name': 'AlpAvia', 'Code': '', 'ICAO': 'APP'},
#  {'Name': 'Alphaland Aviation', 'Code': '', 'ICAO': 'BIC'},
#  {'Name': 'Alpine Air Express', 'Code': '5A', 'ICAO': 'AIP'},
#  {'Name': 'Alpine Flightservice', 'Code': '', 'ICAO': 'FSE'},
#  {'Name': 'Alrosa', 'Code': '6R', 'ICAO': 'DRU'},
#  {'Name': 'ALS', 'Code': '', 'ICAO': 'ALW'},
#  {'Name': 'Altagna', 'Code': '', 'ICAO': 'AGH'},
#  {'Name': 'Amakusa Airlines', 'Code': 'MZ', 'ICAO': 'AHX'},
#  {'Name': 'Amapola Flyg', 'Code': 'HP', 'ICAO': 'APF'},
#  {'Name': 'Amas', 'Code': 'Z8', 'ICAO': 'AZN'},
#  {'Name': 'AMC Airlines', 'Code': '', 'ICAO': 'AMV'},
#  {'Name': 'AMC Aviation', 'Code': '', 'ICAO': 'AMQ'},
#  {'Name': 'Amelia International', 'Code': '8R', 'ICAO': 'AIA'},
#  {'Name': 'American Air Charter', 'Code': '', 'ICAO': 'GTW'},
#  {'Name': 'American Airlines', 'Code': 'AA', 'ICAO': 'AAL'},
#  {'Name': 'Ameriflight', 'Code': 'A8', 'ICAO': 'AMF'},
#  {'Name': 'Amerijet International', 'Code': 'M6', 'ICAO': 'AJT'},
#  {'Name': 'Ameristar', 'Code': '7Z', 'ICAO': 'AJI'},
#  {'Name': 'AMREF Flying Doctors', 'Code': '', 'ICAO': 'FDS'},
#  {'Name': 'AMS Airlines', 'Code': '', 'ICAO': 'GEO'},
#  {'Name': 'ANA Wings', 'Code': 'EH', 'ICAO': 'AKX'},
#  {'Name': 'Anap Jets', 'Code': '', 'ICAO': 'AJP'},
#  {'Name': 'Anda Air', 'Code': 'DM', 'ICAO': 'SSV'},
#  {'Name': 'Anderson Air', 'Code': '', 'ICAO': 'ADS'},
#  {'Name': 'Andes Lineas Aereas', 'Code': '', 'ICAO': 'ANS'},
#  {'Name': 'Angara Airlines', 'Code': '2G', 'ICAO': 'AGU'},
#  {'Name': 'Anguilla Air Services', 'Code': 'Q3', 'ICAO': 'AXL'},
#  {'Name': 'Animawings', 'Code': 'A2', 'ICAO': 'AWG'},
#  {'Name': 'Antonov Airlines', 'Code': '', 'ICAO': 'ADB'},
#  {'Name': 'APG Airlines', 'Code': 'GP', 'ICAO': 'RIV'},
#  {'Name': 'Arajet', 'Code': 'DM', 'ICAO': 'DWI'},
#  {'Name': 'Arc en Ciel', 'Code': '', 'ICAO': 'JMS'},
#  {'Name': 'Arcus Air', 'Code': '', 'ICAO': 'AZE'},
#  {'Name': 'Ariana Afghan Airlines', 'Code': 'FG', 'ICAO': 'AFG'},
#  {'Name': 'Arik Air', 'Code': 'W3', 'ICAO': 'ARA'},
#  {'Name': 'Arkhangelsk Airlines', 'Code': '', 'ICAO': 'OAO'},
#  {'Name': 'Arkia Israeli Airlines', 'Code': 'IZ', 'ICAO': 'AIZ'},
#  {'Name': 'Armenia Airways', 'Code': '6A', 'ICAO': 'AMW'},
#  {'Name': 'Aruba Airlines', 'Code': 'AG', 'ICAO': 'ARU'},
#  {'Name': 'ASAS Linhas Aereas', 'Code': '', 'ICAO': 'CEU'},
#  {'Name': 'ASG Business Aviation', 'Code': '', 'ICAO': 'ESW'},
#  {'Name': 'Asia Cargo Airlines', 'Code': 'GM', 'ICAO': 'TMG'},
#  {'Name': 'Asia Pacific Airlines', 'Code': 'P9', 'ICAO': 'MGE'},
#  {'Name': 'Asia Sky Lines', 'Code': '', 'ICAO': 'LIC'},
#  {'Name': 'Asian Express General Aviation Wuxi', 'Code': '', 'ICAO': 'WUA'},
#  {'Name': 'Asiana Airlines', 'Code': 'OZ', 'ICAO': 'AAR'},
#  {'Name': 'Asky Airlines', 'Code': 'KP', 'ICAO': 'SKK'},
#  {'Name': 'ASL Airlines', 'Code': '', 'ICAO': 'ABR'},
#  {'Name': 'ASL Airlines Belgium', 'Code': '3V', 'ICAO': 'TAY'},
#  {'Name': 'ASL Airlines France', 'Code': '5O', 'ICAO': 'FPO'},
#  {'Name': 'ASL Airlines Hungary', 'Code': '', 'ICAO': 'FAH'},
#  {'Name': 'ASL Airlines UK', 'Code': '', 'ICAO': 'ABV'},
#  {'Name': 'Asta Linhas Aereas', 'Code': '0A', 'ICAO': 'SUL'},
#  {'Name': 'Astonjet', 'Code': '', 'ICAO': 'ASJ'},
#  {'Name': 'Astral Aviation', 'Code': '8V', 'ICAO': 'ACP'},
#  {'Name': 'ATA Airlines', 'Code': 'I3', 'ICAO': 'TBZ'},
#  {'Name': 'ATI Jet', 'Code': '', 'ICAO': 'CYO'},
#  {'Name': 'Atlantic Airways', 'Code': 'RC', 'ICAO': 'FLI'},
#  {'Name': 'Atlas Air', 'Code': '5Y', 'ICAO': 'GTI'},
#  {'Name': 'Atlas Air Service', 'Code': '', 'ICAO': 'ATL'},
#  {'Name': 'ATR', 'Code': '', 'ICAO': 'EVX'},
#  {'Name': 'Atran', 'Code': 'V8', 'ICAO': 'VAS'},
#  {'Name': 'Auckland Rescue Helicopter', 'Code': '', 'ICAO': 'WPR'},
#  {'Name': 'Aura Airlines', 'Code': 'U5', 'ICAO': 'GWR'},
#  {'Name': 'Auric Air', 'Code': 'UI', 'ICAO': 'AUK'},
#  {'Name': 'Aurigny Air Services', 'Code': 'GR', 'ICAO': 'AUR'},
#  {'Name': 'Aurora', 'Code': 'HZ', 'ICAO': 'SHU'},
#  {'Name': 'Austrian Airlines', 'Code': 'OS', 'ICAO': 'AUA'},
#  {'Name': 'Av8Jet', 'Code': '', 'ICAO': 'AJO'},
#  {'Name': 'Avanti Air', 'Code': '', 'ICAO': 'ATV'},
#  {'Name': 'Avcenter', 'Code': '', 'ICAO': 'TTE'},
#  {'Name': 'Avcon Jet', 'Code': '', 'ICAO': 'AOJ'},
#  {'Name': 'Avcon Jet Malta', 'Code': '', 'ICAO': 'VCJ'},
#  {'Name': 'Avcon Jet San Marino', 'Code': '', 'ICAO': 'VAJ'},
#  {'Name': 'Avelo Airlines', 'Code': 'XP', 'ICAO': 'VXP'},
#  {'Name': 'Avia Traffic', 'Code': 'YK', 'ICAO': 'AVJ'},
#  {'Name': 'Aviacon Zitotrans', 'Code': 'ZR', 'ICAO': 'AZS'},
#  {'Name': 'Avianca', 'Code': 'AV', 'ICAO': 'AVA'},
#  {'Name': 'Avianca Cargo', 'Code': 'QT', 'ICAO': 'TPA'},
#  {'Name': 'Avianca Costa Rica', 'Code': 'LR', 'ICAO': 'LRC'},
#  {'Name': 'Avianca Ecuador', 'Code': '2K', 'ICAO': 'GLG'},
#  {'Name': 'Avianca El Salvador', 'Code': 'TA', 'ICAO': 'TAI'},
#  {'Name': 'Avianca Express', 'Code': 'EX', 'ICAO': 'AVR'},
#  {'Name': 'Avianca Guatemala', 'Code': 'GU', 'ICAO': 'GUG'},
#  {'Name': 'Aviastar', 'Code': '', 'ICAO': 'VIT'},
#  {'Name': 'Aviastar-TU', 'Code': '4B', 'ICAO': 'TUP'},
#  {'Name': 'Aviation Advisor', 'Code': '', 'ICAO': 'LKF'},
#  {'Name': 'Aviation Horizons', 'Code': 'ZS', 'ICAO': 'HZS'},
#  {'Name': 'Avion Express', 'Code': 'X9', 'ICAO': 'NVD'},
#  {'Name': 'Avion Express Malta', 'Code': 'X8', 'ICAO': 'MLH'},
#  {'Name': 'Avionord', 'Code': '', 'ICAO': 'VND'},
#  {'Name': 'Avior Airlines', 'Code': '9V', 'ICAO': 'ROI'},
#  {'Name': 'Aviostart', 'Code': '', 'ICAO': 'VSR'},
#  {'Name': 'Azerbaijan Airlines', 'Code': 'J2', 'ICAO': 'AHY'},
#  {'Name': 'Azimuth', 'Code': 'A4', 'ICAO': 'AZO'},
#  {'Name': 'Azman Air', 'Code': 'ZQ', 'ICAO': 'AZM'},
#  {'Name': 'Azores Airlines', 'Code': 'S4', 'ICAO': 'RZO'},
#  {'Name': 'Aztec Airways', 'Code': 'AJ', 'ICAO': 'AZY'},
#  {'Name': 'Azul Conecta', 'Code': '2F', 'ICAO': 'ACN'},
#  {'Name': 'Azul Linhas Aereas', 'Code': 'AD', 'ICAO': 'AZU'},
#  {'Name': 'Azur Air', 'Code': 'ZF', 'ICAO': 'AZV'},
#  {'Name': 'Azur Air Ukraine', 'Code': 'QU', 'ICAO': 'UTN'},
#  {'Name': 'BA CityFlyer', 'Code': 'CJ', 'ICAO': 'CFE'},
#  {'Name': 'BA Euroflyer', 'Code': '0A', 'ICAO': 'EFW'},
#  {'Name': 'Babcock MCS Espana', 'Code': '', 'ICAO': 'INR'},
#  {'Name': 'Babcock MCS France', 'Code': '', 'ICAO': 'PTH'},
#  {'Name': 'Babcock MCS Italia', 'Code': '', 'ICAO': 'ELH'},
#  {'Name': 'Babcock MCS Onshore', 'Code': '', 'ICAO': 'RHD'},
#  {'Name': 'Babcock MCS Portugal', 'Code': '', 'ICAO': 'BBO'},
#  {'Name': 'Babcock Scandinavian AirAmbulance', 'Code': '', 'ICAO': 'DFL'},
#  {'Name': 'Babcock Scandinavian AirAmbulance', 'Code': '', 'ICAO': 'BNO'},
#  {'Name': 'Baden Aircraft Operations', 'Code': '', 'ICAO': 'BAO'},
#  {'Name': 'Badr Airlines', 'Code': 'J4', 'ICAO': 'BDR'},
#  {'Name': 'BAe Systems', 'Code': '', 'ICAO': 'BAE'},
#  {'Name': 'BAe Systems Marine', 'Code': '', 'ICAO': 'VSB'},
#  {'Name': 'Bahamasair', 'Code': 'UP', 'ICAO': 'BHS'},
#  {'Name': 'Bairline', 'Code': '', 'ICAO': 'BRJ'},
#  {'Name': 'Bakhtar Afghan Airlines', 'Code': 'BM', 'ICAO': 'BFO'},
#  {'Name': 'Bamboo Airways', 'Code': 'QH', 'ICAO': 'BAV'},
#  {'Name': 'Bangkok Airways', 'Code': 'PG', 'ICAO': 'BKP'},
#  {'Name': 'BankAir', 'Code': '', 'ICAO': 'BKA'},
#  {'Name': 'Bar XH Air', 'Code': '', 'ICAO': 'BXH'},
#  {'Name': 'Baron Aviation Services', 'Code': '', 'ICAO': 'BVN'},
#  {'Name': 'Bassaka Air', 'Code': '5B', 'ICAO': 'BSX'},
#  {'Name': 'Batik Air', 'Code': 'ID', 'ICAO': 'BTK'},
#  {'Name': 'Batik Air Malaysia', 'Code': 'OD', 'ICAO': 'MXD'},
#  {'Name': 'Bearskin Airlines', 'Code': 'JV', 'ICAO': 'BLS'},
#  {'Name': 'Bees Airline', 'Code': '7B', 'ICAO': 'UBE'},
#  {'Name': 'Beijing Airlines', 'Code': '', 'ICAO': 'BJN'},
#  {'Name': 'Bel Air Aviation', 'Code': '', 'ICAO': 'BBX'},
#  {'Name': 'Belavia', 'Code': 'B2', 'ICAO': 'BRU'},
#  {'Name': 'Bemidji Airlines', 'Code': 'CH', 'ICAO': 'BMJ'},
#  {'Name': 'Bering Air', 'Code': '8E', 'ICAO': 'BRG'},
#  {'Name': 'Berjaya Air', 'Code': 'J8', 'ICAO': 'BVT'},
#  {'Name': 'Berniq Airways', 'Code': 'NB', 'ICAO': 'BNL'},
#  {'Name': 'Berry Aviation', 'Code': '', 'ICAO': 'BYA'},
#  {'Name': 'Bestfly Aruba', 'Code': '', 'ICAO': 'BFY'},
#  {'Name': 'Bestfly Cabo Verde', 'Code': '3B', 'ICAO': 'BCV'},
#  {'Name': 'BH Air', 'Code': '8H', 'ICAO': 'BGH'},
#  {'Name': 'Bhutan Airlines', 'Code': 'B3', 'ICAO': 'BTN'},
#  {'Name': 'Bighorn Airways', 'Code': '', 'ICAO': 'BHR'},
#  {'Name': 'Biman Bangladesh Airlines', 'Code': 'BG', 'ICAO': 'BBC'},
#  {'Name': 'BinAir', 'Code': '', 'ICAO': 'BID'},
#  {'Name': 'Binter Canarias', 'Code': 'NT', 'ICAO': 'IBB'},
#  {'Name': 'Bioflight', 'Code': '', 'ICAO': 'BIO'},
#  {'Name': 'Bismillah Airlines', 'Code': 'BH', 'ICAO': 'BML'},
#  {'Name': 'Blue Air', 'Code': '0B', 'ICAO': 'BLA'},
#  {'Name': 'Blue Bird Aviation', 'Code': '', 'ICAO': 'BLB'},
#  {'Name': 'Blue Dart Aviation', 'Code': 'BZ', 'ICAO': 'BDA'},
#  {'Name': 'Blue Islands', 'Code': 'SI', 'ICAO': 'BCI'},
#  {'Name': 'Blue Square Aviation', 'Code': '', 'ICAO': 'BSG'},
#  {'Name': 'Bluebird Airways', 'Code': 'BZ', 'ICAO': 'BBG'},
#  {'Name': 'Bluebird Aviation', 'Code': '', 'ICAO': 'BBZ'},
#  {'Name': 'Bluebird Nordic', 'Code': 'BO', 'ICAO': 'BBD'},
#  {'Name': 'Boeing', 'Code': '', 'ICAO': 'BOE'},
#  {'Name': 'Boliviana de Aviacion', 'Code': 'OB', 'ICAO': 'BOV'},
#  {'Name': 'Bombardier', 'Code': '', 'ICAO': 'BBA'},
#  {'Name': 'Bonza', 'Code': 'AB', 'ICAO': 'BNZ'},
#  {'Name': 'Bookajet', 'Code': '', 'ICAO': 'BOO'},
#  {'Name': 'Boutique Air', 'Code': '4B', 'ICAO': 'BTQ'},
#  {'Name': 'Boutique Aviation', 'Code': '', 'ICAO': 'BQA'},
#  {'Name': 'BRA', 'Code': 'TF', 'ICAO': 'BRX'},
#  {'Name': 'Braathens International Airways', 'Code': 'TT', 'ICAO': 'BIX'},
#  {'Name': 'Bravo Airways', 'Code': '', 'ICAO': 'BAY'},
#  {'Name': 'Breeze Airways', 'Code': 'MX', 'ICAO': 'MXY'},
#  {'Name': 'Brilliant Jet', 'Code': '', 'ICAO': 'TXJ'},
#  {'Name': 'Bristow Helicopters', 'Code': '', 'ICAO': 'BHL'},
#  {'Name': 'Bristow Nigeria', 'Code': '', 'ICAO': 'BHN'},
#  {'Name': 'Bristow Norway', 'Code': '', 'ICAO': 'NOR'},
#  {'Name': 'Bristow US', 'Code': '', 'ICAO': 'BTZ'},
#  {'Name': 'British Airways', 'Code': 'BA', 'ICAO': 'BAW'},
#  {'Name': 'British Airways Shuttle', 'Code': '', 'ICAO': 'SHT'},
#  {'Name': 'British International Helicopters', 'Code': '', 'ICAO': 'BRT'},
#  {'Name': 'Bromma Air Maintenance', 'Code': '', 'ICAO': 'CFL'},
#  {'Name': 'Brussels Airlines', 'Code': 'SN', 'ICAO': 'BEL'},
#  {'Name': 'Budapest Aircraft Service', 'Code': 'RP', 'ICAO': 'BPS'},
#  {'Name': 'Buddha Air', 'Code': 'U4', 'ICAO': 'BHA'},
#  {'Name': 'Budget Lines', 'Code': 'BD', 'ICAO': 'BGN'},
#  {'Name': 'Buffalo Airways', 'Code': 'J0', 'ICAO': 'BFL'},
#  {'Name': 'Bul Air', 'Code': 'LB', 'ICAO': 'BVL'},
#  {'Name': 'Bulgaria - Government', 'Code': '', 'ICAO': 'BGF'},
#  {'Name': 'Bulgaria Air', 'Code': 'FB', 'ICAO': 'LZB'},
#  {'Name': 'Buraq Air', 'Code': 'UZ', 'ICAO': 'BRQ'},
#  {'Name': 'Business Aviation Asia', 'Code': 'UN', 'ICAO': 'UNA'},
#  {'Name': 'Business Wings', 'Code': '', 'ICAO': 'JMP'},
#  {'Name': 'Buzz', 'Code': 'RR', 'ICAO': 'RYS'},
#  {'Name': 'BySky', 'Code': '', 'ICAO': 'BYS'},
#  {'Name': 'C&M Airways', 'Code': '', 'ICAO': 'RWG'},
#  {'Name': 'CAA', 'Code': 'BU', 'ICAO': 'REB'},
#  {'Name': 'Cabo Verde Airlines', 'Code': 'VR', 'ICAO': 'TCV'},
#  {'Name': 'Caicos Express Airways', 'Code': '9Q', 'ICAO': 'CXE'},
#  {'Name': 'Calafia Airlines', 'Code': 'A7', 'ICAO': 'CFV'},
#  {'Name': 'Calm Air', 'Code': 'MO', 'ICAO': 'CAV'},
#  {'Name': 'Calstar', 'Code': '', 'ICAO': 'CMD'},
#  {'Name': 'Camair-Co', 'Code': 'QC', 'ICAO': 'CRC'},
#  {'Name': 'Cambodia Airways', 'Code': 'KR', 'ICAO': 'KME'},
#  {'Name': 'Cambodia Angkor Air', 'Code': 'K6', 'ICAO': 'KHV'},
#  {'Name': 'Cambodia Bayon Airlines', 'Code': 'BD', 'ICAO': 'BYC'},
#  {'Name': 'Cameroon Airlines', 'Code': 'UY', 'ICAO': 'UYC'},
#  {'Name': 'Camex Airlines', 'Code': 'Z7', 'ICAO': 'CMS'},
#  {'Name': 'Canada - Department of Transport', 'Code': '', 'ICAO': 'TGO'},
#  {'Name': 'Canadian Airways Congo', 'Code': '', 'ICAO': 'TWC'},
#  {'Name': 'Canadian North', 'Code': '5T', 'ICAO': 'AKT'},
#  {'Name': 'Canarias Airlines', 'Code': '', 'ICAO': 'RSC'},
#  {'Name': 'CanaryFly', 'Code': 'PM', 'ICAO': 'CNF'},
#  {'Name': 'Canavia', 'Code': '', 'ICAO': 'CNA'},
#  {'Name': 'Canjet Airlines', 'Code': 'C6', 'ICAO': 'CJA'},
#  {'Name': 'Canlink Aviation', 'Code': '', 'ICAO': 'MFC'},
#  {'Name': 'CanWest Air', 'Code': '', 'ICAO': 'CWA'},
#  {'Name': 'Cape Air', 'Code': '9K', 'ICAO': 'KAP'},
#  {'Name': 'Capital Air Ambulance', 'Code': '', 'ICAO': 'EGL'},
#  {'Name': 'Capital Airlines', 'Code': 'JD', 'ICAO': 'CBJ'},
#  {'Name': 'Capital City Air Carriers', 'Code': '', 'ICAO': 'CCQ'},
#  {'Name': 'Cardiff Aviation Malta', 'Code': '', 'ICAO': 'SGO'},
#  {'Name': 'Cardig Air', 'Code': '', 'ICAO': 'CAD'},
#  {'Name': 'CareFlight', 'Code': '', 'ICAO': 'CFH'},
#  {'Name': 'Cargo Air', 'Code': '', 'ICAO': 'CGF'},
#  {'Name': 'Cargo Three', 'Code': 'C3', 'ICAO': 'CTW'},
#  {'Name': 'Cargojet Airways', 'Code': 'W8', 'ICAO': 'CJT'},
#  {'Name': 'CargoLogic Germany', 'Code': '6L', 'ICAO': 'GCL'},
#  {'Name': 'CargoLogicAir', 'Code': 'P3', 'ICAO': 'CLU'},
#  {'Name': 'Cargolux', 'Code': 'CV', 'ICAO': 'CLX'},
#  {'Name': 'Cargolux Italia', 'Code': 'C8', 'ICAO': 'ICV'},
#  {'Name': 'Caribbean Airlines', 'Code': 'BW', 'ICAO': 'BWA'},
#  {'Name': 'Carpatair', 'Code': 'V3', 'ICAO': 'KRP'},
#  {'Name': 'Carson Air', 'Code': '', 'ICAO': 'CRN'},
#  {'Name': 'Caspian Airlines', 'Code': 'RV', 'ICAO': 'CPN'},
#  {'Name': 'Castle Aviation', 'Code': '', 'ICAO': 'CSJ'},
#  {'Name': 'CAT Aviation', 'Code': '', 'ICAO': 'CAZ'},
#  {'Name': 'Cathay Pacific', 'Code': 'CX', 'ICAO': 'CPA'},
#  {'Name': 'Catreus', 'Code': '', 'ICAO': 'VCG'},
#  {'Name': 'Cavok Air', 'Code': '', 'ICAO': 'CVK'},
#  {'Name': 'Cayman Airways', 'Code': 'KX', 'ICAO': 'CAY'},
#  {'Name': 'Cebgo', 'Code': 'DG', 'ICAO': 'SRQ'},
#  {'Name': 'Cebu Pacific', 'Code': '5J', 'ICAO': 'CEB'},
#  {'Name': 'Ceiba Intercontinental', 'Code': 'C2', 'ICAO': 'CEL'},
#  {'Name': 'CemAir', 'Code': '5Z', 'ICAO': 'KEM'},
#  {'Name': 'Central Air Southwest', 'Code': '', 'ICAO': 'CTL'},
#  {'Name': 'Central Airlines', 'Code': 'I9', 'ICAO': 'HLF'},
#  {'Name': 'Central Mountain Air', 'Code': '9M', 'ICAO': 'GLR'},
#  {'Name': 'Centreline', 'Code': '', 'ICAO': 'CLF'},
#  {'Name': 'Chabahar Airlines', 'Code': '', 'ICAO': 'IRU'},
#  {'Name': 'Chair Airlines', 'Code': 'GM', 'ICAO': 'GSW'},
#  {'Name': 'Chalair Aviation', 'Code': 'CE', 'ICAO': 'CLG'},
#  {'Name': 'Challenge Air Cargo', 'Code': 'X6', 'ICAO': 'CHZ'},
#  {'Name': 'Challenge Airlines', 'Code': 'X7', 'ICAO': 'CHG'},
#  {'Name': 'Challenge Airlines IL', 'Code': '5C', 'ICAO': 'ICL'},
#  {'Name': 'Cham Wings Airlines', 'Code': '6Q', 'ICAO': 'SAW'},
#  {'Name': 'Charter Jets', 'Code': '', 'ICAO': 'LTC'},
#  {'Name': 'Chartright Air', 'Code': '', 'ICAO': 'HRT'},
#  {'Name': 'CHC Helicopter', 'Code': '', 'ICAO': 'HMB'},
#  {'Name': 'CHC Helicopters Netherlands', 'Code': '', 'ICAO': 'HNL'},
#  {'Name': 'CHC Helicopters Nigeria', 'Code': '', 'ICAO': 'ATQ'},
#  {'Name': 'CHC Helikopter Service', 'Code': '', 'ICAO': 'HKS'},
#  {'Name': 'CHC International', 'Code': '', 'ICAO': 'GCY'},
#  {'Name': 'Chengdu Airlines', 'Code': 'EU', 'ICAO': 'UEA'},
#  {'Name': 'Chervon Corporation', 'Code': '', 'ICAO': 'GLH'},
#  {'Name': 'Chicago Jet Group', 'Code': '', 'ICAO': 'WDY'},
#  {'Name': 'China Airlines', 'Code': 'CI', 'ICAO': 'CAL'},
#  {'Name': 'China Cargo Airlines', 'Code': 'CK', 'ICAO': 'CKK'},
#  {'Name': 'China Eastern Airlines', 'Code': 'MU', 'ICAO': 'CES'},
#  {'Name': 'China Express Airlines', 'Code': 'G5', 'ICAO': 'HXA'},
#  {'Name': 'China Postal Airlines', 'Code': 'CF', 'ICAO': 'CYZ'},
#  {'Name': 'China Southern Airlines', 'Code': 'CZ', 'ICAO': 'CSN'},
#  {'Name': 'China Southern Cargo', 'Code': '', 'ICAO': 'CSG'},
#  {'Name': 'China United Airlines', 'Code': 'KN', 'ICAO': 'CUA'},
#  {'Name': 'Chongqing Airlines', 'Code': 'OQ', 'ICAO': 'CQN'},
#  {'Name': 'Chrono Aviation', 'Code': 'MB', 'ICAO': 'NDL'},
#  {'Name': 'Chrono Jet', 'Code': 'MB', 'ICAO': 'MBK'},
#  {'Name': 'Cinnamon Air', 'Code': 'C7', 'ICAO': 'CIN'},
#  {'Name': 'CITIC Offshore Helicopter', 'Code': '', 'ICAO': 'CHC'},
#  {'Name': 'Citilink', 'Code': 'QG', 'ICAO': 'CTV'},
#  {'Name': 'Citrus', 'Code': 'XT', 'ICAO': 'CTU'},
#  {'Name': 'Cityjet', 'Code': 'WX', 'ICAO': 'BCY'},
#  {'Name': 'Civil Air Patrol', 'Code': '', 'ICAO': 'CAP'},
#  {'Name': 'Class Aviation', 'Code': '', 'ICAO': 'DUC'},
#  {'Name': 'Clipper Jet', 'Code': '', 'ICAO': 'ORO'},
#  {'Name': 'CM Airlines', 'Code': 'CC', 'ICAO': 'OMT'},
#  {'Name': 'CMA CGM AirCargo', 'Code': '2C', 'ICAO': 'CMA'},
#  {'Name': 'Coastal Aviation', 'Code': 'CQ', 'ICAO': 'CSV'},
#  {'Name': 'Cobalt Air', 'Code': 'CO', 'ICAO': 'FCB'},
#  {'Name': 'Cobham Aviation', 'Code': 'NC', 'ICAO': 'JTE'},
#  {'Name': 'Cobham Aviation Services Australia', 'Code': '', 'ICAO': 'NJS'},
#  {'Name': 'Cobham Flight Inspection', 'Code': '', 'ICAO': 'CLB'},
#  {'Name': 'Colorful GuiZhou Airlines', 'Code': 'GY', 'ICAO': 'CGZ'},
#  {'Name': 'Comlux Aruba', 'Code': 'CS', 'ICAO': 'CXB'},
#  {'Name': 'Comlux Aviation', 'Code': '', 'ICAO': 'CLA'},
#  {'Name': 'Comlux Aviation Malta', 'Code': '', 'ICAO': 'MLM'},
#  {'Name': 'CommutAir', 'Code': 'C5', 'ICAO': 'UCA'},
#  {'Name': 'Compagnia Aeronautica Italiana', 'Code': '', 'ICAO': 'CPI'},
#  {'Name': 'Compass Cargo Airlines', 'Code': 'HQ', 'ICAO': 'ADZ'},
#  {'Name': 'Conair', 'Code': '', 'ICAO': 'FGD'},
#  {'Name': 'Condor', 'Code': 'DE', 'ICAO': 'CFG'},
#  {'Name': 'Congo Airways', 'Code': '8Z', 'ICAO': 'CGA'},
#  {'Name': 'Connect Airlines', 'Code': 'MW', 'ICAO': 'WZM'},
#  {'Name': 'Connect Linhas Aereas', 'Code': '6C', 'ICAO': 'CNT'},
#  {'Name': 'Conquest Air', 'Code': 'C4', 'ICAO': 'QAI'},
#  {'Name': 'Constanta Airline', 'Code': '', 'ICAO': 'UZA'},
#  {'Name': 'Contour Aviation', 'Code': 'LF', 'ICAO': 'VTE'},
#  {'Name': 'Conviasa', 'Code': 'V0', 'ICAO': 'VCV'},
#  {'Name': 'Copa Airlines', 'Code': 'CM', 'ICAO': 'CMP'},
#  {'Name': 'Copenhagen Airtaxi', 'Code': '', 'ICAO': 'CAT'},
#  {'Name': 'Corendon Airlines', 'Code': 'XC', 'ICAO': 'CAI'},
#  {'Name': 'Corendon Airlines Europe', 'Code': 'XR', 'ICAO': 'CXI'},
#  {'Name': 'Corendon Dutch Airlines', 'Code': 'CD', 'ICAO': 'CND'},
#  {'Name': 'Corporate Air', 'Code': '', 'ICAO': 'CPT'},
#  {'Name': 'Corporate Air', 'Code': '', 'ICAO': 'MLN'},
#  {'Name': 'Corsair', 'Code': 'SS', 'ICAO': 'CRL'},
#  {'Name': 'Costa Rica Green Airways', 'Code': 'GW', 'ICAO': 'GRA'},
#  {'Name': 'Coulson Aviation', 'Code': '', 'ICAO': 'CUL'},
#  {'Name': 'Cristalux', 'Code': 'Z7', 'ICAO': 'AUZ'},
#  {'Name': 'Croatia Airlines', 'Code': 'OU', 'ICAO': 'CTN'},
#  {'Name': 'Cronos Airlines', 'Code': 'C8', 'ICAO': 'CRA'},
#  {'Name': 'Cronos Airlines Benin', 'Code': 'C9', 'ICAO': 'CKL'},
#  {'Name': 'CSA Air', 'Code': '', 'ICAO': 'IRO'},
#  {'Name': 'CSI Aviation', 'Code': '', 'ICAO': 'CSI'},
#  {'Name': 'Cubana', 'Code': 'CU', 'ICAO': 'CUB'},
#  {'Name': 'Cygnus Air', 'Code': '', 'ICAO': 'RGN'},
#  {'Name': 'Cyprus Airways', 'Code': 'CY', 'ICAO': 'CYP'},
#  {'Name': 'Czech Airlines', 'Code': 'OK', 'ICAO': 'CSA'},
#  {'Name': 'Daallo Airlines', 'Code': 'D3', 'ICAO': 'DAO'},
#  {'Name': 'Dalian Airlines', 'Code': '', 'ICAO': 'CCD'},
#  {'Name': 'Dan Air', 'Code': 'DN', 'ICAO': 'JOC'},
#  {'Name': 'Dana Air', 'Code': '9J', 'ICAO': 'DAN'},
#  {'Name': 'Dassault Falcon Service', 'Code': '', 'ICAO': 'DSO'},
#  {'Name': 'DAT', 'Code': 'DX', 'ICAO': 'DTR'},
#  {'Name': 'DAT LT', 'Code': 'R6', 'ICAO': 'DNU'},
#  {'Name': 'DC Aviation', 'Code': '', 'ICAO': 'DCS'},
#  {'Name': 'DEA Aviation', 'Code': '', 'ICAO': 'WKT'},
#  {'Name': 'Deer Jet', 'Code': '', 'ICAO': 'DER'},
#  {'Name': 'Deer Jet Beijing', 'Code': '', 'ICAO': 'BDJ'},
#  {'Name': 'Delta Air Lines', 'Code': 'DL', 'ICAO': 'DAL'},
#  {'Name': 'Delta Private Jets', 'Code': '', 'ICAO': 'DPJ'},
#  {'Name': 'Dena Airways', 'Code': 'D9', 'ICAO': 'DAI'},
#  {'Name': 'Deraya', 'Code': '', 'ICAO': 'DRY'},
#  {'Name': 'Desert Jet', 'Code': '', 'ICAO': 'DJR'},
#  {'Name': 'Dexter Air Taxi', 'Code': '', 'ICAO': 'DXT'},
#  {'Name': 'DHL', 'Code': 'D0', 'ICAO': 'DHK'},
#  {'Name': 'DHL Aero Expreso', 'Code': 'D5', 'ICAO': 'DAE'},
#  {'Name': 'DHL Air Austria', 'Code': 'Q7', 'ICAO': 'DHA'},
#  {'Name': 'DHL Aviation EEMEA', 'Code': 'ES', 'ICAO': 'DHX'},
#  {'Name': 'Diamond Sky', 'Code': '', 'ICAO': 'DMS'},
#  {'Name': 'Divi Divi Air', 'Code': '3R', 'ICAO': 'DVR'},
#  {'Name': 'Dniproavia', 'Code': '', 'ICAO': 'UDN'},
#  {'Name': 'Donghai Airlines', 'Code': 'DZ', 'ICAO': 'EPA'},
#  {'Name': 'Dornier Aviation Nigeria Aiep', 'Code': 'DO', 'ICAO': 'DAV'},
#  {'Name': 'Douniah Airlines', 'Code': 'DH', 'ICAO': 'DTS'},
#  {'Name': 'DragonFly Executive', 'Code': '', 'ICAO': 'CBM'},
#  {'Name': 'Dreamline Aviation', 'Code': '', 'ICAO': 'DLX'},
#  {'Name': 'DRF Luftrettung', 'Code': '1I', 'ICAO': 'AMB'},
#  {'Name': 'Druk Air', 'Code': 'KB', 'ICAO': 'DRK'},
#  {'Name': 'Dubai Air Wing', 'Code': '', 'ICAO': 'DUB'},
#  {'Name': 'E+S Air', 'Code': '', 'ICAO': 'CAH'},
#  {'Name': 'E-Aviation', 'Code': '', 'ICAO': 'EFD'},
#  {'Name': 'E-Cargo Airlines', 'Code': 'RF', 'ICAO': 'ERF'},
#  {'Name': 'EADS CASA', 'Code': '', 'ICAO': 'AED'},
#  {'Name': 'Eagle Air', 'Code': '', 'ICAO': 'EGU'},
#  {'Name': 'Eagle Air Iceland', 'Code': '', 'ICAO': 'FEI'},
#  {'Name': 'Eagle Atlantic Airlines', 'Code': '', 'ICAO': 'EAB'},
#  {'Name': 'Eagle Creek Aviation', 'Code': '', 'ICAO': 'EGC'},
#  {'Name': 'EagleMed', 'Code': '', 'ICAO': 'EMD'},
#  {'Name': 'East Coast Jets', 'Code': '', 'ICAO': 'ECJ'},
#  {'Name': 'East-West Express', 'Code': '', 'ICAO': 'EWU'},
#  {'Name': 'Eastar Jet', 'Code': 'ZE', 'ICAO': 'ESR'},
#  {'Name': 'Eastern Airlines', 'Code': '2D', 'ICAO': 'EAL'},
#  {'Name': 'Eastern Airways', 'Code': 'T3', 'ICAO': 'EZE'},
#  {'Name': 'Eastern Australia Airlines', 'Code': '', 'ICAO': 'EAQ'},
#  {'Name': 'Easy Charter', 'Code': 'RD', 'ICAO': 'LOL'},
#  {'Name': 'EasyFly', 'Code': 'VE', 'ICAO': 'EFY'},
#  {'Name': 'easyJet', 'Code': 'U2', 'ICAO': 'EZY'},
#  {'Name': 'easyJet Europe', 'Code': 'EC', 'ICAO': 'EJU'},
#  {'Name': 'easyJet Switzerland', 'Code': 'DS', 'ICAO': 'EZS'},
#  {'Name': 'EATIS', 'Code': '', 'ICAO': 'SRK'},
#  {'Name': 'Eclair Aviation', 'Code': '', 'ICAO': 'ECC'},
#  {'Name': 'ECO Airlines', 'Code': '', 'ICAO': 'EKO'},
#  {'Name': 'EcoJet', 'Code': '8J', 'ICAO': 'ECO'},
#  {'Name': 'Edelweiss Air', 'Code': 'WK', 'ICAO': 'EDW'},
#  {'Name': 'EGT Jet', 'Code': '', 'ICAO': 'EGT'},
#  {'Name': 'EgyptAir', 'Code': 'MS', 'ICAO': 'MSR'},
#  {'Name': 'EgyptAir Cargo', 'Code': '', 'ICAO': 'MSX'},
#  {'Name': 'EJM Europe', 'Code': '', 'ICAO': 'JME'},
#  {'Name': 'El Al', 'Code': 'LY', 'ICAO': 'ELY'},
#  {'Name': 'Electra Airways', 'Code': '', 'ICAO': 'EAF'},
#  {'Name': 'Elifriulia', 'Code': '', 'ICAO': 'EFG'},
#  {'Name': 'Elilombarda', 'Code': '', 'ICAO': 'EOA'},
#  {'Name': 'Eliossola', 'Code': '', 'ICAO': 'EOS'},
#  {'Name': 'Elitaliana', 'Code': '', 'ICAO': 'ELA'},
#  {'Name': 'Elitavia', 'Code': '', 'ICAO': 'EAV'},
#  {'Name': 'Elitavia Malta', 'Code': 'MA', 'ICAO': 'EAU'},
#  {'Name': 'Elite Air', 'Code': '', 'ICAO': 'ELZ'},
#  {'Name': 'Elite Airways', 'Code': '7Q', 'ICAO': 'MNU'},
#  {'Name': 'Elitellina', 'Code': '', 'ICAO': 'FGS'},
#  {'Name': 'Embraer', 'Code': '', 'ICAO': 'EMB'},
#  {'Name': 'Emerald Airlines', 'Code': 'EA', 'ICAO': 'EAI'},
#  {'Name': 'Emerald Airlines UK', 'Code': '', 'ICAO': 'EAG'},
#  {'Name': 'Emetebe.com.ec', 'Code': '', 'ICAO': 'EMT'},
#  {'Name': 'Emirates', 'Code': 'EK', 'ICAO': 'UAE'},
#  {'Name': 'Emirates Flight Training Academy', 'Code': '', 'ICAO': 'EFC'},
#  {'Name': 'Emperor Aviation', 'Code': '', 'ICAO': 'EMM'},
#  {'Name': 'Empire Airlines', 'Code': 'EM', 'ICAO': 'CFS'},
#  {'Name': 'Empire Aviation', 'Code': '', 'ICAO': 'MJE'},
#  {'Name': 'Empyreal Jet', 'Code': '', 'ICAO': 'RLJ'},
#  {'Name': 'ENAC Ecole Aviation Civile', 'Code': '', 'ICAO': 'NAK'},
#  {'Name': 'Encore Air Cargo', 'Code': '', 'ICAO': 'DKT'},
#  {'Name': 'Endeavor Air', 'Code': '9E', 'ICAO': 'EDV'},
#  {'Name': 'Enter Air', 'Code': 'E4', 'ICAO': 'ENT'},
#  {'Name': 'Envoy Air', 'Code': 'MQ', 'ICAO': 'ENY'},
#  {'Name': 'Epsilon Aviation', 'Code': '', 'ICAO': 'GRV'},
#  {'Name': 'Equair', 'Code': 'HN', 'ICAO': 'EQX'},
#  {'Name': 'Estafeta', 'Code': 'E7', 'ICAO': 'ESF'},
#  {'Name': 'Estelar', 'Code': 'ES', 'ICAO': 'ETR'},
#  {'Name': 'ETF Airways', 'Code': 'LI', 'ICAO': 'EZZ'},
#  {'Name': 'Ethiopian Airlines', 'Code': 'ET', 'ICAO': 'ETH'},
#  {'Name': 'Etihad Airways', 'Code': 'EY', 'ICAO': 'ETD'},
#  {'Name': 'Euro Link', 'Code': '', 'ICAO': 'EUL'},
#  {'Name': 'Euro-Asia Air', 'Code': '5B', 'ICAO': 'EAK'},
#  {'Name': 'EuroAtlantic Airways', 'Code': 'YU', 'ICAO': 'MMZ'},
#  {'Name': 'Eurocopter Deutschland', 'Code': '', 'ICAO': 'RDF'},
#  {'Name': 'European Air Charter', 'Code': 'H6', 'ICAO': 'BUC'},
#  {'Name': 'European Air Transport', 'Code': 'QY', 'ICAO': 'BCS'},
#  {'Name': 'European Cargo', 'Code': '', 'ICAO': 'URO'},
#  {'Name': 'European Flight Academy', 'Code': '', 'ICAO': 'PTO'},
#  {'Name': 'European Flight Service', 'Code': '', 'ICAO': 'EUW'},
#  {'Name': 'European Flyers', 'Code': '', 'ICAO': 'FYS'},
#  {'Name': 'European SAO', 'Code': '', 'ICAO': 'EKT'},
#  {'Name': 'Eurowings', 'Code': 'EW', 'ICAO': 'EWG'},
#  {'Name': 'Eurowings Austria', 'Code': 'E2', 'ICAO': 'EWE'},
#  {'Name': 'Eurowings Discover', 'Code': '4Y', 'ICAO': 'OCN'},
#  {'Name': 'Eurowings Europe', 'Code': 'E6', 'ICAO': 'EWL'},
#  {'Name': 'EVA Air', 'Code': 'BR', 'ICAO': 'EVA'},
#  {'Name': 'Everts Air Alaska', 'Code': '5V', 'ICAO': 'VTS'},
#  {'Name': 'EWA Air', 'Code': 'ZD', 'ICAO': 'EWR'},
#  {'Name': 'Excellent Air', 'Code': '', 'ICAO': 'ECA'},
#  {'Name': 'Execuflight', 'Code': '', 'ICAO': 'EFT'},
#  {'Name': 'Execujet Middle East', 'Code': '', 'ICAO': 'EJO'},
#  {'Name': 'Execujet Scandinavia', 'Code': '', 'ICAO': 'VMP'},
#  {'Name': 'Executive Airlink', 'Code': '', 'ICAO': 'ENK'},
#  {'Name': 'Executive Jet Charter', 'Code': '', 'ICAO': 'EXJ'},
#  {'Name': 'Executive Jet Management', 'Code': '', 'ICAO': 'EJM'},
#  {'Name': 'Exploits Valley Air Services', 'Code': '8K', 'ICAO': 'EVS'},
#  {'Name': 'Express Air Cargo', 'Code': '7A', 'ICAO': 'XRC'},
#  {'Name': 'Express Freighters Australia', 'Code': 'QE', 'ICAO': 'EFA'},
#  {'Name': 'ExpressJet Airlines', 'Code': 'XE', 'ICAO': 'BTA'},
#  {'Name': 'Exxaero', 'Code': '', 'ICAO': 'XRO'},
#  {'Name': 'EZ Air', 'Code': '7Z', 'ICAO': 'EZR'},
#  {'Name': 'Eznis Airways', 'Code': 'MG', 'ICAO': 'EZA'},
#  {'Name': 'FAI rent-a-jet', 'Code': '', 'ICAO': 'IFA'},
#  {'Name': 'Far Eastern Air Transport', 'Code': 'FE', 'ICAO': 'FEA'},
#  {'Name': 'Fast Air', 'Code': '', 'ICAO': 'PBR'},
#  {'Name': 'Fastjet Zimbabwe', 'Code': 'FN', 'ICAO': 'FJW'},
#  {'Name': 'FedEx', 'Code': 'FX', 'ICAO': 'FDX'},
#  {'Name': 'Fenix Air Charter', 'Code': '', 'ICAO': 'FNX'},
#  {'Name': 'Feuerwehr-Flugdienst Niedersachsen', 'Code': '', 'ICAO': 'FFD'},
#  {'Name': 'Fiji Airways', 'Code': 'FJ', 'ICAO': 'FJI'},
#  {'Name': 'Fiji Link', 'Code': '', 'ICAO': 'FJA'},
#  {'Name': 'Finistair', 'Code': '', 'ICAO': 'FTR'},
#  {'Name': 'Finnair', 'Code': 'AY', 'ICAO': 'FIN'},
#  {'Name': 'FinnHEMS', 'Code': '', 'ICAO': 'FIH'},
#  {'Name': 'Firefly', 'Code': 'FY', 'ICAO': 'FFM'},
#  {'Name': 'First Air', 'Code': '7F', 'ICAO': 'FAB'},
#  {'Name': 'First Nation Airways', 'Code': '', 'ICAO': 'FRN'},
#  {'Name': 'FitsAir', 'Code': '8D', 'ICAO': 'EXV'},
#  {'Name': 'Flair Airlines', 'Code': 'F8', 'ICAO': 'FLE'},
#  {'Name': 'Fleet Air International', 'Code': '', 'ICAO': 'FRF'},
#  {'Name': 'Flexflight', 'Code': 'W2', 'ICAO': 'FXT'},
#  {'Name': 'Flexjet', 'Code': '', 'ICAO': 'LXJ'},
#  {'Name': 'Flexjet Europe', 'Code': '', 'ICAO': 'FLJ'},
#  {'Name': 'Flexjet Operations Malta', 'Code': '', 'ICAO': 'FJO'},
#  {'Name': 'Flight Calibration Services', 'Code': '', 'ICAO': 'FCK'},
#  {'Name': 'Flight Calibration Services', 'Code': '', 'ICAO': 'VOR'},
#  {'Name': 'Flight options', 'Code': '', 'ICAO': 'OPT'},
#  {'Name': 'Flight Training Europe', 'Code': '', 'ICAO': 'AYR'},
#  {'Name': 'FlightExec', 'Code': '', 'ICAO': 'FEX'},
#  {'Name': 'Flightline', 'Code': '', 'ICAO': 'FTL'},
#  {'Name': 'Flightlink', 'Code': 'YS', 'ICAO': 'FLZ'},
#  {'Name': 'Flightpath Charter Airways', 'Code': '', 'ICAO': 'KNT'},
#  {'Name': 'Florida Air Cargo', 'Code': '', 'ICAO': 'FAS'},
#  {'Name': 'Fltplan', 'Code': '', 'ICAO': 'DCM'},
#  {'Name': 'Flugfelag Islands', 'Code': 'NY', 'ICAO': 'FXI'},
#  {'Name': 'Fly 7', 'Code': '', 'ICAO': 'FSF'},
#  {'Name': 'Fly Across', 'Code': '', 'ICAO': 'ACW'},
#  {'Name': 'Fly Air41', 'Code': '', 'ICAO': 'BER'},
#  {'Name': 'Fly AllWays', 'Code': '8W', 'ICAO': 'EDR'},
#  {'Name': 'Fly Angola', 'Code': 'EQ', 'ICAO': 'FLA'},
#  {'Name': 'Fly Armenia Airways', 'Code': 'VF', 'ICAO': 'FBB'},
#  {'Name': 'Fly Art', 'Code': '', 'ICAO': 'FLB'},
#  {'Name': 'Fly Baghdad', 'Code': 'IF', 'ICAO': 'FBA'},
#  {'Name': 'Fly Gangwon', 'Code': '4V', 'ICAO': 'FGW'},
#  {'Name': 'Fly Jamaica', 'Code': 'OJ', 'ICAO': 'FJM'},
#  {'Name': 'Fly Jinnah', 'Code': '9P', 'ICAO': 'FJL'},
#  {'Name': 'Fly Jordan', 'Code': 'F0', 'ICAO': 'FJR'},
#  {'Name': 'Fly Oya', 'Code': 'YI', 'ICAO': 'OYA'},
#  {'Name': 'Fly Pro', 'Code': 'FP', 'ICAO': 'PVV'},
#  {'Name': 'Fly SAX', 'Code': '', 'ICAO': 'EXZ'},
#  {'Name': 'Fly Sky Airlines', 'Code': '', 'ICAO': 'FSQ'},
#  {'Name': 'Fly Sky Airlines', 'Code': '', 'ICAO': 'FSU'},
#  {'Name': 'Fly Tyrol', 'Code': '', 'ICAO': 'FTY'},
#  {'Name': 'Fly2Sky', 'Code': 'F6', 'ICAO': 'VAW'},
#  {'Name': 'Fly540', 'Code': '5H', 'ICAO': 'FFV'},
#  {'Name': 'Flyadeal', 'Code': 'F3', 'ICAO': 'FAD'},
#  {'Name': 'FlyArna', 'Code': 'G6', 'ICAO': 'ACY'},
#  {'Name': 'Flybe', 'Code': 'BE', 'ICAO': 'BEE'},
#  {'Name': 'FlyBig', 'Code': 'S9', 'ICAO': 'FLG'},
#  {'Name': 'Flybondi', 'Code': 'FO', 'ICAO': 'FBZ'},
#  {'Name': 'FlyBosnia', 'Code': '6W', 'ICAO': 'FBS'},
#  {'Name': 'FlyDamas', 'Code': '4J', 'ICAO': 'FDK'},
#  {'Name': 'FlyDubai', 'Code': 'FZ', 'ICAO': 'FDB'},
#  {'Name': 'FlyEgypt', 'Code': 'FT', 'ICAO': 'FEG'},
#  {'Name': 'flyExclusive', 'Code': '', 'ICAO': 'JRE'},
#  {'Name': 'FlyGTA Airlines', 'Code': 'SX', 'ICAO': 'TOR'},
#  {'Name': 'Flying Business Aviation', 'Code': '', 'ICAO': 'FBX'},
#  {'Name': 'Flying Service', 'Code': '', 'ICAO': 'FYG'},
#  {'Name': 'FlyMe', 'Code': 'VP', 'ICAO': 'VQI'},
#  {'Name': 'FlyMontserrat', 'Code': '5M', 'ICAO': 'MNT'},
#  {'Name': 'Flynas', 'Code': 'XY', 'ICAO': 'KNE'},
#  {'Name': 'FlyOne', 'Code': '5F', 'ICAO': 'FIA'},
#  {'Name': 'FlyOne Armenia', 'Code': '3F', 'ICAO': 'FIE'},
#  {'Name': 'FlyOne Romania', 'Code': 'OE', 'ICAO': 'FOE'},
#  {'Name': 'FlyPelican', 'Code': 'FP', 'ICAO': 'FRE'},
#  {'Name': 'Flyr', 'Code': 'FS', 'ICAO': 'FOX'},
#  {'Name': 'FlySafair', 'Code': 'FA', 'ICAO': 'SFR'},
#  {'Name': 'FlySchool', 'Code': '', 'ICAO': 'FSM'},
#  {'Name': 'FR Aviation', 'Code': '', 'ICAO': 'FRA'},
#  {'Name': 'Freebird Airlines', 'Code': 'FH', 'ICAO': 'FHY'},
#  {'Name': 'Freebird Airlines Europe', 'Code': 'MI', 'ICAO': 'FHM'},
#  {'Name': 'Freedom Airline Express', 'Code': '4F', 'ICAO': 'FDT'},
#  {'Name': 'Freight Runners Express', 'Code': '', 'ICAO': 'FRG'},
#  {'Name': 'French Bee', 'Code': 'BF', 'ICAO': 'FBU'},
#  {'Name': 'Frontier', 'Code': 'F9', 'ICAO': 'FFT'},
#  {'Name': 'Fuji Dream Airlines', 'Code': 'JH', 'ICAO': 'FDA'},
#  {'Name': 'Fuzhou Airlines', 'Code': 'FU', 'ICAO': 'FZA'},
#  {'Name': 'GainJet', 'Code': '', 'ICAO': 'GNJ'},
#  {'Name': 'Galistair Infinite Aviation', 'Code': 'GT', 'ICAO': 'GTR'},
#  {'Name': 'Gama Aviation', 'Code': '', 'ICAO': 'GMA'},
#  {'Name': 'Gama Aviation Cayman', 'Code': '', 'ICAO': 'GKY'},
#  {'Name': 'Gama Aviation UAE', 'Code': '', 'ICAO': 'GSH'},
#  {'Name': 'Garuda Indonesia', 'Code': 'GA', 'ICAO': 'GIA'},
#  {'Name': 'Gazpromavia', 'Code': '4G', 'ICAO': 'GZP'},
#  {'Name': 'General Atomic AeroTech Systems', 'Code': '', 'ICAO': 'DOR'},
#  {'Name': 'Genex', 'Code': '', 'ICAO': 'GNX'},
#  {'Name': 'Genghis Khan Airlines', 'Code': '9D', 'ICAO': 'NMG'},
#  {'Name': 'Geo Sky Airline', 'Code': 'D4', 'ICAO': 'GEL'},
#  {'Name': 'Georgian Airlines', 'Code': 'GH', 'ICAO': 'IGT'},
#  {'Name': 'Georgian Airways', 'Code': 'A9', 'ICAO': 'TGZ'},
#  {'Name': 'German Airways', 'Code': 'ZQ', 'ICAO': 'GER'},
#  {'Name': 'Germany - Air Ambulance', 'Code': '', 'ICAO': 'CHX'},
#  {'Name': 'Gesellschaft Fur Flugzieldarstellung', 'Code': '', 'ICAO': 'GFD'},
#  {'Name': 'Gestair', 'Code': '', 'ICAO': 'GES'},
#  {'Name': 'Gestair Aviation Malta', 'Code': '', 'ICAO': 'GSM'},
#  {'Name': 'GetJet Airlines', 'Code': 'GW', 'ICAO': 'GJT'},
#  {'Name': 'Getjet Airlines Latvia', 'Code': '', 'ICAO': 'DML'},
#  {'Name': 'Ghadames Air Transport', 'Code': 'NJ', 'ICAO': 'GMS'},
#  {'Name': 'Global Air Charters', 'Code': '', 'ICAO': 'GJE'},
#  {'Name': 'Global Air Transport', 'Code': '5S', 'ICAO': 'GAK'},
#  {'Name': 'Global Airways', 'Code': '', 'ICAO': 'GBL'},
#  {'Name': 'Global Aviation', 'Code': '', 'ICAO': 'MSS'},
#  {'Name': 'Global Jet Luxembourg', 'Code': '', 'ICAO': 'SVW'},
#  {'Name': 'Global Supply Systems', 'Code': '', 'ICAO': 'GSS'},
#  {'Name': 'Global X', 'Code': 'G6', 'ICAO': 'GXA'},
#  {'Name': 'GlobeAir', 'Code': '', 'ICAO': 'GAC'},
#  {'Name': 'Go First', 'Code': 'G8', 'ICAO': 'GOW'},
#  {'Name': 'GoJet ', 'Code': 'G7', 'ICAO': 'GJS'},
#  {'Name': 'GOL Linhas Aereas', 'Code': 'G3', 'ICAO': 'GLO'},
#  {'Name': 'Goldeck Flug', 'Code': '', 'ICAO': 'GDK'},
#  {'Name': 'Gouvernement du Quebec', 'Code': '', 'ICAO': 'QUE'},
#  {'Name': 'GP Aviation', 'Code': 'IV', 'ICAO': 'GPX'},
#  {'Name': 'Grafair', 'Code': '', 'ICAO': 'GFM'},
#  {'Name': 'Grand Canyon Airlines', 'Code': 'YR', 'ICAO': 'CVU'},
#  {'Name': 'Grand China Air', 'Code': 'CN', 'ICAO': 'GDC'},
#  {'Name': 'Grant Aviation', 'Code': 'GV', 'ICAO': 'GUN'},
#  {'Name': 'Greater Bay Airlines', 'Code': 'HB', 'ICAO': 'HGB'},
#  {'Name': 'Green Africa Airways', 'Code': 'Q9', 'ICAO': 'GWG'},
#  {'Name': 'Greybird Aviation', 'Code': '', 'ICAO': 'GAG'},
#  {'Name': 'GTA Air', 'Code': '', 'ICAO': 'GTX'},
#  {'Name': 'Gulf Air', 'Code': 'GF', 'ICAO': 'GFA'},
#  {'Name': 'Gulf and Caribbean Cargo', 'Code': 'IF', 'ICAO': 'TSU'},
#  {'Name': 'Gulf Wings', 'Code': '', 'ICAO': 'GWC'},
#  {'Name': 'GullivAir', 'Code': 'G2', 'ICAO': 'GBG'},
#  {'Name': 'Guna Airlines', 'Code': '', 'ICAO': 'GUA'},
#  {'Name': 'GX Airlines', 'Code': 'GX', 'ICAO': 'CBG'},
#  {'Name': 'Hahn Air', 'Code': 'HR', 'ICAO': 'HHN'},
#  {'Name': 'Hai Au Aviation', 'Code': '', 'ICAO': 'HAI'},
#  {'Name': 'Hainan Airlines', 'Code': 'HU', 'ICAO': 'CHH'},
#  {'Name': 'Hala Air', 'Code': 'HG', 'ICAO': 'HTP'},
#  {'Name': 'Hangar 8', 'Code': '', 'ICAO': 'HGR'},
#  {'Name': 'Hans Airways', 'Code': '', 'ICAO': 'GKS'},
#  {'Name': 'Harmony Jets', 'Code': '', 'ICAO': 'HMJ'},
#  {'Name': 'Hawaiian Airlines', 'Code': 'HA', 'ICAO': 'HAL'},
#  {'Name': 'Hebei Airlines', 'Code': 'NS', 'ICAO': 'HBH'},
#  {'Name': 'Heli Air Monaco', 'Code': 'YO', 'ICAO': 'MCM'},
#  {'Name': 'Heli Air Services', 'Code': '', 'ICAO': 'HLR'},
#  {'Name': 'Heli Holland', 'Code': '', 'ICAO': 'HHE'},
#  {'Name': 'Heli Securite', 'Code': '', 'ICAO': 'HLI'},
#  {'Name': 'Heli Service International', 'Code': '', 'ICAO': 'HSO'},
#  {'Name': 'Héli-Union', 'Code': '', 'ICAO': 'HLU'},
#  {'Name': 'Helicol', 'Code': '', 'ICAO': 'HEL'},
#  {'Name': 'Helijet International', 'Code': '', 'ICAO': 'JBA'},
#  {'Name': 'Helistar', 'Code': '', 'ICAO': 'HTS'},
#  {'Name': 'Helistar', 'Code': '', 'ICAO': 'HSR'},
#  {'Name': 'Helitrans', 'Code': '', 'ICAO': 'HDR'},
#  {'Name': 'HELITY Copter Airlines', 'Code': '', 'ICAO': 'HTY'},
#  {'Name': 'Hello Jets', 'Code': 'H3', 'ICAO': 'HLJ'},
#  {'Name': 'Helvetic Airways', 'Code': '2L', 'ICAO': 'OAW'},
#  {'Name': 'Hera Flight', 'Code': '', 'ICAO': 'HER'},
#  {'Name': 'Hermes Airlines', 'Code': 'H3', 'ICAO': 'HRM'},
#  {'Name': 'Heron Aviation', 'Code': '', 'ICAO': 'HRN'},
#  {'Name': 'Heston Airlines', 'Code': 'HN', 'ICAO': 'HST'},
#  {'Name': 'Hi Air', 'Code': '4H', 'ICAO': 'HGG'},
#  {'Name': 'Hi Fly', 'Code': '5K', 'ICAO': 'HFY'},
#  {'Name': 'Hi Fly Malta', 'Code': '3L', 'ICAO': 'HFM'},
#  {'Name': 'Hibernian Airlines', 'Code': 'HG', 'ICAO': 'HBN'},
#  {'Name': 'Himalaya Airlines', 'Code': 'H9', 'ICAO': 'HIM'},
#  {'Name': 'Hinterland Aviation', 'Code': 'OI', 'ICAO': 'HND'},
#  {'Name': 'HiSky', 'Code': 'H7', 'ICAO': 'HYM'},
#  {'Name': 'HiSky Europe', 'Code': 'H4', 'ICAO': 'HYS'},
#  {'Name': 'Hokkaido Air System', 'Code': '', 'ICAO': 'NTH'},
#  {'Name': 'Hong Kong Air Cargo', 'Code': 'RH', 'ICAO': 'HKC'},
#  {'Name': 'Hong Kong Airlines', 'Code': 'HX', 'ICAO': 'CRK'},
#  {'Name': 'Hong Kong Express', 'Code': 'UO', 'ICAO': 'HKE'},
#  {'Name': 'Hop-A-Jet', 'Code': '', 'ICAO': 'HPJ'},
#  {'Name': 'Horizon Air', 'Code': 'QX', 'ICAO': 'QXE'},
#  {'Name': 'HTM Helicopter Travel Munich', 'Code': '', 'ICAO': 'HTM'},
#  {'Name': 'Hummingbird Aviation', 'Code': '', 'ICAO': 'ETI'},
#  {'Name': 'Hunnu Air', 'Code': 'MR', 'ICAO': 'MML'},
#  {'Name': 'Hydro Quebec', 'Code': '0Q', 'ICAO': 'HYD'},
#  {'Name': 'Hyperion Aviation', 'Code': '', 'ICAO': 'HYP'},
#  {'Name': 'I-Fly', 'Code': 'F7', 'ICAO': 'RSY'},
#  {'Name': 'iAero Airways', 'Code': 'WQ', 'ICAO': 'SWQ'},
#  {'Name': 'IBC Airways', 'Code': 'II', 'ICAO': 'CSQ'},
#  {'Name': 'Iberia', 'Code': 'IB', 'ICAO': 'IBE'},
#  {'Name': 'Iberia Express', 'Code': 'I2', 'ICAO': 'IBS'},
#  {'Name': 'Iberojet', 'Code': 'E9', 'ICAO': 'EVE'},
#  {'Name': 'Ibex Airlines', 'Code': 'FW', 'ICAO': 'IBX'},
#  {'Name': 'Ibom Air', 'Code': 'QI', 'ICAO': 'IAN'},
#  {'Name': 'Icar Air', 'Code': '', 'ICAO': 'RAC'},
#  {'Name': 'Icaro', 'Code': 'X8', 'ICAO': 'ICD'},
#  {'Name': 'Icelandair', 'Code': 'FI', 'ICAO': 'ICE'},
#  {'Name': 'ICS-Aero', 'Code': '', 'ICAO': 'ICF'},
#  {'Name': 'IFL Group', 'Code': '', 'ICAO': 'IFL'},
#  {'Name': 'Image Air Charter', 'Code': '', 'ICAO': 'BMG'},
#  {'Name': 'ImperialJet', 'Code': '', 'ICAO': 'JTI'},
#  {'Name': 'IndiaOne Air', 'Code': 'I7', 'ICAO': 'IOA'},
#  {'Name': 'IndiGo', 'Code': '6E', 'ICAO': 'IGO'},
#  {'Name': 'Indonesia AirAsia', 'Code': 'QZ', 'ICAO': 'AWQ'},
#  {'Name': 'iNTAIRLINE', 'Code': '', 'ICAO': 'ITI'},
#  {'Name': 'Intel Air Shuttle', 'Code': '', 'ICAO': 'HGT'},
#  {'Name': 'InterCaribbean Airways', 'Code': 'JY', 'ICAO': 'IWY'},
#  {'Name': 'InterJet West', 'Code': 'K8', 'ICAO': 'IJW'},
#  {'Name': 'International Committee of the Red Cross',
#   'Code': '',
#   'ICAO': 'RED'},
#  {'Name': 'International Jet Management', 'Code': '', 'ICAO': 'IJM'},
#  {'Name': 'InterSky', 'Code': '3L', 'ICAO': 'ISK'},
#  {'Name': 'IrAero', 'Code': 'IO', 'ICAO': 'IAE'},
#  {'Name': 'Iran Air', 'Code': 'IR', 'ICAO': 'IRA'},
#  {'Name': 'Iran Airtour', 'Code': 'B9', 'ICAO': 'IRB'},
#  {'Name': 'Iran Aseman Airlines', 'Code': 'EP', 'ICAO': 'IRC'},
#  {'Name': 'Iraq Gate Company', 'Code': '', 'ICAO': 'IGC'},
#  {'Name': 'Iraqi Airways', 'Code': 'IA', 'ICAO': 'IAW'},
#  {'Name': 'IRS Airlines', 'Code': '', 'ICAO': 'LVB'},
#  {'Name': 'Israir Airlines', 'Code': '6H', 'ICAO': 'ISR'},
#  {'Name': 'ITA Airways', 'Code': 'AZ', 'ICAO': 'ITY'},
#  {'Name': 'Italfly', 'Code': '', 'ICAO': 'ITL'},
#  {'Name': 'iXAir', 'Code': '', 'ICAO': 'IXR'},
#  {'Name': 'Izair', 'Code': '4I', 'ICAO': 'IZM'},
#  {'Name': 'Izhavia', 'Code': 'I8', 'ICAO': 'IZA'},
#  {'Name': 'JA Air Charter', 'Code': '', 'ICAO': 'LTD'},
#  {'Name': 'JAL Express', 'Code': 'JC', 'ICAO': 'JEX'},
#  {'Name': 'Jambojet', 'Code': 'JM', 'ICAO': 'JMA'},
#  {'Name': 'Japan Air Commuter', 'Code': '3X', 'ICAO': 'JAC'},
#  {'Name': 'Japan Airlines', 'Code': 'JL', 'ICAO': 'JAL'},
#  {'Name': 'Japan Transocean Air', 'Code': 'NU', 'ICAO': 'JTA'},
#  {'Name': 'Jasmin Airways', 'Code': 'JO', 'ICAO': 'JAW'},
#  {'Name': 'Jazeera Airways', 'Code': 'J9', 'ICAO': 'JZR'},
#  {'Name': 'Jazz Aviation', 'Code': 'QK', 'ICAO': 'JZA'},
#  {'Name': 'JC Airlines', 'Code': 'QD', 'ICAO': 'JCC'},
#  {'Name': 'JC Bamford Excavators', 'Code': '', 'ICAO': 'JCB'},
#  {'Name': 'Jeju Air', 'Code': '7C', 'ICAO': 'JJA'},
#  {'Name': 'Jet Airways', 'Code': '9W', 'ICAO': 'JAI'},
#  {'Name': 'Jet Asia Airways', 'Code': 'JF', 'ICAO': 'JAA'},
#  {'Name': 'Jet Aviation Business Jets', 'Code': 'PP', 'ICAO': 'PJS'},
#  {'Name': 'Jet Aviation Flight Services', 'Code': '', 'ICAO': 'JAS'},
#  {'Name': 'Jet Charter', 'Code': 'N2', 'ICAO': 'JCT'},
#  {'Name': 'Jet Edge', 'Code': '', 'ICAO': 'EDG'},
#  {'Name': 'Jet Executive', 'Code': '', 'ICAO': 'JEI'},
#  {'Name': 'Jet Express', 'Code': '', 'ICAO': 'RFE'},
#  {'Name': 'Jet Fly Airline', 'Code': '', 'ICAO': 'JFL'},
#  {'Name': 'Jet It', 'Code': '', 'ICAO': 'JIT'},
#  {'Name': 'Jet Linx Aviation', 'Code': 'JL', 'ICAO': 'JTL'},
#  {'Name': 'Jet Logistics', 'Code': '', 'ICAO': 'JLG'},
#  {'Name': 'Jet Story', 'Code': '', 'ICAO': 'JDI'},
#  {'Name': 'Jet Test International', 'Code': '', 'ICAO': 'JTN'},
#  {'Name': 'Jet2', 'Code': 'LS', 'ICAO': 'EXS'},
#  {'Name': 'Jetair Caribbean', 'Code': '4J', 'ICAO': 'JRC'},
#  {'Name': 'Jetalliance East', 'Code': '', 'ICAO': 'PLS'},
#  {'Name': 'Jetbee Czech', 'Code': '', 'ICAO': 'JBC'},
#  {'Name': 'JetBlue Airways', 'Code': 'B6', 'ICAO': 'JBU'},
#  {'Name': 'Jetcall', 'Code': '', 'ICAO': 'JCL'},
#  {'Name': 'Jetclub', 'Code': '0J', 'ICAO': 'JCS'},
#  {'Name': 'Jetconnect', 'Code': '', 'ICAO': 'QNZ'},
#  {'Name': 'JetFlite', 'Code': '', 'ICAO': 'JEF'},
#  {'Name': 'Jetfly Aviation', 'Code': '', 'ICAO': 'JFA'},
#  {'Name': 'Jetkontor', 'Code': '', 'ICAO': 'JKH'},
#  {'Name': 'jetlines', 'Code': 'AU', 'ICAO': 'CJL'},
#  {'Name': 'JetLite', 'Code': 'S2', 'ICAO': 'JLL'},
#  {'Name': 'JetNetherlands', 'Code': '', 'ICAO': 'JNL'},
#  {'Name': 'JetRight', 'Code': '', 'ICAO': 'JRT'},
#  {'Name': 'JetSMART', 'Code': 'JA', 'ICAO': 'JAT'},
#  {'Name': 'JetSMART Argentina', 'Code': 'WJ', 'ICAO': 'JES'},
#  {'Name': 'JetSMART Peru', 'Code': 'JZ', 'ICAO': 'JAP'},
#  {'Name': 'Jetstar', 'Code': 'JQ', 'ICAO': 'JST'},
#  {'Name': 'Jetstar Asia', 'Code': '3K', 'ICAO': 'JSA'},
#  {'Name': 'Jetstar Japan', 'Code': 'GK', 'ICAO': 'JJP'},
#  {'Name': 'JetStream', 'Code': '', 'ICAO': 'JSH'},
#  {'Name': 'JetStream Charter', 'Code': '', 'ICAO': 'VTB'},
#  {'Name': 'Jetsuite Air', 'Code': '', 'ICAO': 'RSP'},
#  {'Name': 'Jettime', 'Code': '', 'ICAO': 'JTD'},
#  {'Name': 'Jetways Airlines', 'Code': 'WU', 'ICAO': 'JWX'},
#  {'Name': 'Jhonlin Air Transport', 'Code': '', 'ICAO': 'JLB'},
#  {'Name': 'Jiangsu Jingdong Cargo Airlines', 'Code': 'JG', 'ICAO': 'JDL'},
#  {'Name': 'Jiangxi Air', 'Code': 'RY', 'ICAO': 'CJX'},
#  {'Name': 'Jiangxi Express Commuter Aviation', 'Code': '', 'ICAO': 'KXA'},
#  {'Name': 'Jin Air', 'Code': 'LJ', 'ICAO': 'JNA'},
#  {'Name': 'Jinxiang Airlines', 'Code': '', 'ICAO': 'JXX'},
#  {'Name': 'Jivair', 'Code': '', 'ICAO': 'JIV'},
#  {'Name': 'Jonair', 'Code': '', 'ICAO': 'JON'},
#  {'Name': 'Jonika', 'Code': '', 'ICAO': 'JNK'},
#  {'Name': 'Jordan Aviation', 'Code': 'R5', 'ICAO': 'JAV'},
#  {'Name': 'Jordan International Air Cargo', 'Code': '', 'ICAO': 'JCI'},
#  {'Name': 'JoyAir', 'Code': 'JR', 'ICAO': 'JOY'},
#  {'Name': 'JSX', 'Code': 'XE', 'ICAO': 'JSX'},
#  {'Name': 'Jubba Airways', 'Code': '3J', 'ICAO': 'JBW'},
#  {'Name': 'Jump Air', 'Code': '', 'ICAO': 'JUP'},
#  {'Name': 'Juneyao Air', 'Code': 'HO', 'ICAO': 'DKH'},
#  {'Name': 'Jung Sky', 'Code': '', 'ICAO': 'JSY'},
#  {'Name': 'K-Mile Air', 'Code': '8K', 'ICAO': 'KMI'},
#  {'Name': 'K5-Aviation Germany', 'Code': '', 'ICAO': 'KAY'},
#  {'Name': 'KaiserAir', 'Code': '', 'ICAO': 'KAI'},
#  {'Name': 'Kalitta Air', 'Code': 'K4', 'ICAO': 'CKS'},
#  {'Name': 'Kalitta Charters', 'Code': 'K9', 'ICAO': 'KFS'},
#  {'Name': 'Kalitta Charters II', 'Code': 'K5', 'ICAO': 'KII'},
#  {'Name': 'Kam Air', 'Code': 'RQ', 'ICAO': 'KMF'},
#  {'Name': 'Kamaka Air', 'Code': '', 'ICAO': 'KMK'},
#  ...]

# %%
import flightradar24
airline = 'KLM' # Turkish Airlines
fr = flightradar24.Api()
flights = fr.get_flights(airline)
flights
# Out:
# {'full_count': 10221,
#  'version': 4,
#  '2f6ecc3b': ['484416',
#   51.8817,
#   0.8813,
#   70,
#   35000,
#   548,
#   '',
#   'F-EGLK3',
#   'B772',
#   'PH-BQM',
#   1678185453,
#   'GIG',
#   'AMS',
#   'KL706',
#   0,
#   0,
#   'KLM706',
#   0,
#   'KLM'],
#  '2f6ee970': ['48436B',
#   50.0972,
#   -7.2801,
#   67,
#   37000,
#   527,
#   '',
#   'F-EGHE1',
#   'B772',
#   'PH-BQD',
#   1678185454,
#   'GYE',
#   'AMS',
#   'KL753',
#   0,
#   64,
#   'KLM753',
#   0,
#   'KLM'],
#  '2f6eeef7': ['485B44',
#   52.9096,
#   1.5914,
#   101,
#   26825,
#   518,
#   '',
#   'F-EGNM5',
#   'B78X',
#   'PH-BKD',
#   1678185455,
#   'LAX',
#   'AMS',
#   'KL602',
#   0,
#   -1792,
#   'KLM602',
#   0,
#   'KLM'],
#  '2f6f1e59': ['485000',
#   34.2117,
#   -33.0236,
#   36,
#   34004,
#   553,
#   '',
#   'F-SAT7',
#   'B77W',
#   'PH-BVK',
#   1678185452,
#   'LIM',
#   'AMS',
#   'KL744',
#   0,
#   0,
#   'KLM744',
#   0,
#   'KLM'],
#  '2f6f22b4': ['485343',
#   45.7805,
#   -20.6581,
#   62,
#   39000,
#   552,
#   '',
#   'F-SAT2',
#   'B789',
#   'PH-BHI',
#   1678185456,
#   'LIR',
#   'AMS',
#   'KL717',
#   0,
#   0,
#   'KLM717',
#   0,
#   'KLM'],
#  '2f6f2886': ['485345',
#   52.7914,
#   2.4826,
#   105,
#   24975,
#   492,
#   '',
#   'F-EHWO1',
#   'B789',
#   'PH-BHM',
#   1678185453,
#   'MSP',
#   'AMS',
#   'KL656',
#   0,
#   64,
#   'KLM656',
#   0,
#   'KLM'],
#  '2f6f2df7': ['4851B1',
#   53.4284,
#   -5.9556,
#   79,
#   39000,
#   542,
#   '',
#   'F-EICM1',
#   'B789',
#   'PH-BHF',
#   1678185454,
#   'ATL',
#   'AMS',
#   'KL622',
#   0,
#   -64,
#   'KLM168',
#   0,
#   'KLM'],
#  '2f6f39dd': ['4851AF',
#   49.0902,
#   -45.2491,
#   73,
#   38975,
#   490,
#   '',
#   'F-EST',
#   'B789',
#   'PH-BHD',
#   1678185452,
#   'MEX',
#   'AMS',
#   'KL686',
#   0,
#   0,
#   'KLM258',
#   0,
#   'KLM'],
#  '2f6f4a03': ['4841C4',
#   53.8317,
#   -22.5577,
#   82,
#   41000,
#   496,
#   '',
#   'F-SAT2',
#   'B744',
#   'PH-CKB',
#   1678185452,
#   'ORD',
#   'AMS',
#   'MP6516',
#   0,
#   0,
#   'MPH6516',
#   0,
#   'KLM'],
#  '2f6f844b': ['484CBB',
#   14.1623,
#   117.2466,
#   95,
#   41000,
#   495,
#   '',
#   'T-RPLL29',
#   'B77W',
#   'PH-BVG',
#   1678185443,
#   'BKK',
#   'MNL',
#   'KL803',
#   0,
#   0,
#   'KLM803',
#   0,
#   'KLM'],
#  '2f6f862d': ['485A35',
#   44.7442,
#   25.2238,
#   101,
#   18375,
#   352,
#   '',
#   'F-LROP4',
#   'B738',
#   'PH-BCL',
#   1678185455,
#   'AMS',
#   'OTP',
#   'KL1373',
#   0,
#   -1792,
#   'KLM44K',
#   0,
#   'KLM'],
#  '2f6f9429': ['484CB4',
#   38.7731,
#   -9.1346,
#   78,
#   0,
#   19,
#   '',
#   'F-LPCS3',
#   'B738',
#   'PH-BCA',
#   1678185455,
#   'AMS',
#   'LIS',
#   'KL1693',
#   1,
#   0,
#   'KLM71F',
#   0,
#   'KLM'],
#  '2f6fa3a3': ['484164',
#   41.8047,
#   12.2653,
#   250,
#   0,
#   20,
#   '',
#   'F-LIRA4',
#   'B738',
#   'PH-BXL',
#   1678185454,
#   'AMS',
#   'FCO',
#   'KL1601',
#   1,
#   0,
#   'KLM81K',
#   0,
#   'KLM'],
#  '2f6fa4cc': ['484F73',
#   41.9552,
#   19.1484,
#   145,
#   37000,
#   496,
#   '',
#   'F-LDSB1',
#   'A333',
#   'PH-AKD',
#   1678185452,
#   'AMS',
#   'JRO',
#   'KL573',
#   0,
#   0,
#   'KLM573',
#   0,
#   'KLM'],
#  '2f6fa766': ['48436F',
#   52.0789,
#   -12.4629,
#   268,
#   34000,
#   418,
#   '',
#   'F-EINN4',
#   'B772',
#   'PH-BQH',
#   1678185455,
#   'AMS',
#   'BOG',
#   'KL749',
#   0,
#   0,
#   'KLM749',
#   0,
#   'KLM'],
#  '2f6fa781': ['485A34',
#   41.8202,
#   -2.2739,
#   209,
#   30075,
#   436,
#   '',
#   'F-LEZG3',
#   'B738',
#   'PH-BCK',
#   1678185455,
#   'AMS',
#   'MAD',
#   'KL1701',
#   0,
#   -2432,
#   'KLM73D',
#   0,
#   'KLM'],
#  '2f6fad3c': ['484132',
#   50.7243,
#   8.3442,
#   330,
#   40000,
#   413,
#   '',
#   'F-EDVM1',
#   'B738',
#   'PH-BXC',
#   1678185454,
#   'FCO',
#   'AMS',
#   'KL1598',
#   0,
#   0,
#   'KLM58X',
#   0,
#   'KLM'],
#  '2f6fae12': ['484411',
#   55.9525,
#   -7.951,
#   286,
#   36000,
#   426,
#   '',
#   'F-EGPF5',
#   'A332',
#   'PH-AOC',
#   1678185455,
#   'AMS',
#   'IAH',
#   'KL661',
#   0,
#   0,
#   'KLM661',
#   0,
#   'KLM'],
#  '2f6fae14': ['4844C6',
#   58.9211,
#   20.4042,
#   59,
#   39000,
#   492,
#   '',
#   'F-EVVA1',
#   'B738',
#   'PH-BXV',
#   1678185453,
#   'AMS',
#   'HEL',
#   'KL1167',
#   0,
#   0,
#   'KLM1167',
#   0,
#   'KLM'],
#  '2f6faec6': ['484F06',
#   52.183,
#   20.9055,
#   114,
#   1325,
#   134,
#   '',
#   'F-EPBC1',
#   'B737',
#   'PH-BGM',
#   1678185454,
#   'AMS',
#   'WAW',
#   'KL1363',
#   0,
#   -640,
#   'KLM53L',
#   0,
#   'KLM'],
#  '2f6fb00b': ['484370',
#   50.0303,
#   -6.789,
#   252,
#   30000,
#   425,
#   '',
#   'F-EIWF2',
#   'B772',
#   'PH-BQI',
#   1678185453,
#   'AMS',
#   'GRU',
#   'KL791',
#   0,
#   0,
#   'KLM791',
#   0,
#   'KLM'],
#  '2f6fb0a2': ['485876',
#   44.9029,
#   -0.6091,
#   225,
#   2225,
#   173,
#   '',
#   'T-LFBD1',
#   'E75L',
#   'PH-EXZ',
#   1678185452,
#   'AMS',
#   'BOD',
#   'KL1315',
#   0,
#   -1024,
#   'KLM33R',
#   0,
#   'KLM'],
#  '2f6fb107': ['485086',
#   52.3011,
#   4.7574,
#   239,
#   0,
#   2,
#   '',
#   'F-EHAM1',
#   'E190',
#   'PH-EXD',
#   1678185430,
#   'GLA',
#   'AMS',
#   'KL1472',
#   1,
#   0,
#   'KLM1472',
#   0,
#   'KLM'],
#  '2f6fb116': ['484443',
#   53.449,
#   -7.1652,
#   256,
#   36000,
#   432,
#   '',
#   'F-EIKN3',
#   'A332',
#   'PH-AOD',
#   1678185452,
#   'AMS',
#   'BGI',
#   'KL781',
#   0,
#   0,
#   'KLM781',
#   0,
#   'KLM'],
#  '2f6fb1d2': ['48418C',
#   43.5115,
#   2.8014,
#   179,
#   36975,
#   482,
#   '',
#   'F-LFMK3',
#   'B739',
#   'PH-BXR',
#   1678185455,
#   'AMS',
#   'BCN',
#   'KL1669',
#   0,
#   -256,
#   'KLM65H',
#   0,
#   'KLM'],
#  '2f6fb211': ['484F7F',
#   59.963,
#   10.9147,
#   38,
#   5100,
#   182,
#   '',
#   'F-ENRY3',
#   'E190',
#   'PH-EZW',
#   1678185453,
#   'AMS',
#   'OSL',
#   'KL1143',
#   0,
#   -448,
#   'KLM29U',
#   0,
#   'KLM'],
#  '2f6fb3c1': ['484FDE',
#   47.9404,
#   18.0922,
#   107,
#   23975,
#   446,
#   '',
#   'F-LHSM3',
#   'B738',
#   'PH-BCD',
#   1678185454,
#   'AMS',
#   'BUD',
#   'KL1975',
#   0,
#   -1024,
#   'KLM67R',
#   0,
#   'KLM'],
#  '2f6fb47c': ['486258',
#   45.233,
#   10.3891,
#   181,
#   34800,
#   424,
#   '',
#   'F-LIPU1',
#   'E295',
#   'PH-NXB',
#   1678185455,
#   'AMS',
#   'FLR',
#   'KL1641',
#   0,
#   -640,
#   'KLM83J',
#   0,
#   'KLM'],
#  '2f6fb4b9': ['484368',
#   51.9227,
#   -4.979,
#   274,
#   34000,
#   409,
#   '',
#   'F-EGFH2',
#   'B772',
#   'PH-BQA',
#   1678185454,
#   'AMS',
#   'UIO',
#   'KL751',
#   0,
#   0,
#   'KLM751',
#   0,
#   'KLM'],
#  '2f6fb4c6': ['485E2D',
#   52.0161,
#   -6.7858,
#   273,
#   38000,
#   427,
#   '',
#   'F-EIBN2',
#   'B78X',
#   'PH-BKG',
#   1678185454,
#   'AMS',
#   'CUN',
#   'KL689',
#   0,
#   0,
#   'KLM689',
#   0,
#   'KLM'],
#  '2f6fb4cf': ['485E30',
#   58.9297,
#   -0.8369,
#   323,
#   33975,
#   462,
#   '',
#   'F-EGPA2',
#   'B78X',
#   'PH-BKK',
#   1678185454,
#   'AMS',
#   'SFO',
#   'KL605',
#   0,
#   128,
#   'KLM109',
#   0,
#   'KLM'],
#  '2f6fb5d0': ['484C51',
#   52.3012,
#   4.7582,
#   329,
#   0,
#   5,
#   '',
#   'F-EHAM1',
#   'E190',
#   'PH-EZM',
#   1678185437,
#   'EDI',
#   'AMS',
#   'KL1278',
#   1,
#   0,
#   'KLM1278',
#   0,
#   'KLM'],
#  '2f6fb602': ['4863DB',
#   52.6546,
#   5.7969,
#   224,
#   14800,
#   312,
#   '',
#   'F-EHWO1',
#   'E295',
#   'PH-NXC',
#   1678185454,
#   'GOT',
#   'AMS',
#   'KL1154',
#   0,
#   -2496,
#   'KLM24L',
#   0,
#   'KLM'],
#  '2f6fb729': ['485B43',
#   53.6966,
#   -5.1662,
#   276,
#   36000,
#   434,
#   '',
#   'F-EGQB1',
#   'B78X',
#   'PH-BKC',
#   1678185453,
#   'AMS',
#   'ATL',
#   'KL623',
#   0,
#   0,
#   'KLM623',
#   0,
#   'KLM'],
#  '2f6fb80a': ['484CBA',
#   47.3064,
#   14.0255,
#   144,
#   35000,
#   520,
#   '',
#   'F-LJLJ7',
#   'B77W',
#   'PH-BVF',
#   1678185455,
#   'AMS',
#   'ZNZ',
#   'KL515',
#   0,
#   0,
#   'KLM515',
#   0,
#   'KLM'],
#  '2f6fb980': ['484F72',
#   51.7721,
#   -2.9123,
#   276,
#   36000,
#   404,
#   '',
#   'F-EGLK2',
#   'A333',
#   'PH-AKB',
#   1678185455,
#   'AMS',
#   'MIA',
#   'KL627',
#   0,
#   0,
#   'KLM627',
#   0,
#   'KLM'],
#  '2f6fbbde': ['48455D',
#   51.4649,
#   -0.4525,
#   270,
#   0,
#   57,
#   '',
#   'F-EGLL2',
#   'B737',
#   'PH-BGF',
#   1678185449,
#   'AMS',
#   'LHR',
#   'KL1009',
#   1,
#   0,
#   'KLM1009',
#   0,
#   'KLM'],
#  '2f6fbce2': ['484FDF',
#   52.3061,
#   4.7704,
#   329,
#   0,
#   13,
#   '',
#   'F-EHAM1',
#   'B738',
#   'PH-BCE',
#   1678185379,
#   'NWI',
#   'AMS',
#   '',
#   1,
#   0,
#   'KLM9868',
#   0,
#   'KLM'],
#  '2f6fbdb8': ['484B90',
#   47.2415,
#   2.3986,
#   189,
#   41000,
#   452,
#   '',
#   'F-LFQG2',
#   'B737',
#   'PH-BGI',
#   1678185453,
#   'AMS',
#   'TLS',
#   'KL1303',
#   0,
#   0,
#   'KLM39W',
#   0,
#   'KLM'],
#  '2f6fbe56': ['485206',
#   52.7232,
#   2.8984,
#   106,
#   21475,
#   490,
#   '',
#   'F-EGSH3',
#   'E190',
#   'PH-EXE',
#   1678185454,
#   'ABZ',
#   'AMS',
#   'KL1442',
#   0,
#   -2368,
#   'KLM60B',
#   0,
#   'KLM'],
#  '2f6fbf3e': ['4843F3',
#   51.3785,
#   -0.24,
#   238,
#   32000,
#   410,
#   '',
#   'F-EGBE2',
#   'B772',
#   'PH-BQP',
#   1678185455,
#   'AMS',
#   'GIG',
#   'KL705',
#   0,
#   0,
#   'KLM705',
#   0,
#   'KLM'],
#  '2f6fc0fd': ['484161',
#   52.4438,
#   3.3286,
#   78,
#   15800,
#   382,
#   '',
#   'F-EHWO3',
#   'B738',
#   'PH-BXH',
#   1678185454,
#   'LHR',
#   'AMS',
#   'KL1008',
#   0,
#   -1536,
#   'KLM1008',
#   0,
#   'KLM'],
#  '2f6fc15d': ['485871',
#   52.2349,
#   4.6212,
#   47,
#   7700,
#   289,
#   '',
#   'F-EHRD5',
#   'E190',
#   'PH-EXV',
#   1678185455,
#   'LUX',
#   'AMS',
#   'KL1740',
#   0,
#   -448,
#   'KLM22E',
#   0,
#   'KLM'],
#  '2f6fc1ff': ['484F7C',
#   52.3076,
#   4.7746,
#   182,
#   0,
#   8,
#   '',
#   'F-EHAM1',
#   'E190',
#   'PH-EZT',
#   1678185455,
#   'HAJ',
#   'AMS',
#   'KL1904',
#   1,
#   0,
#   'KLM28M',
#   0,
#   'KLM'],
#  '2f6fc393': ['484163',
#   53.3694,
#   -2.2867,
#   222,
#   0,
#   0,
#   '',
#   'T-EGCC767',
#   'B738',
#   'PH-BXK',
#   1678185448,
#   'MAN',
#   'AMS',
#   'KL1074',
#   1,
#   0,
#   'KLM60A',
#   0,
#   'KLM'],
#  '2f6fc394': ['4851B3',
#   51.596,
#   1.1457,
#   248,
#   30000,
#   408,
#   '',
#   'F-EGDJ1',
#   'B77W',
#   'PH-BVP',
#   1678185453,
#   'AMS',
#   'PBM',
#   'KL713',
#   0,
#   0,
#   'KLM713',
#   0,
#   'KLM'],
#  '2f6fc3f6': ['484555',
#   42.8123,
#   -2.228,
#   30,
#   38000,
#   444,
#   '',
#   'F-LEAS1',
#   'B738',
#   'PH-BXW',
#   1678185454,
#   'MAD',
#   'AMS',
#   'KL1700',
#   0,
#   0,
#   'KLM20H',
#   0,
#   'KLM'],
#  '2f6fc3fa': ['48455F',
#   51.097,
#   7.3965,
#   132,
#   31000,
#   544,
#   '',
#   'F-EDDV3',
#   'B77W',
#   'PH-BVB',
#   1678185453,
#   'AMS',
#   'JNB',
#   'KL591',
#   0,
#   0,
#   'KLM591',
#   0,
#   'KLM'],
#  '2f6fc401': ['484BD1',
#   52.3804,
#   5.2045,
#   240,
#   3625,
#   249,
#   '',
#   'F-EHKD2',
#   'E190',
#   'PH-EZF',
#   1678185453,
#   'BRE',
#   'AMS',
#   'KL1754',
#   0,
#   -768,
#   'KLM52G',
#   0,
#   'KLM'],
#  '2f6fc66f': ['484369',
#   51.0702,
#   4.1365,
#   203,
#   23725,
#   407,
#   '',
#   'F-EHAM1',
#   'B772',
#   'PH-BQB',
#   1678185453,
#   'AMS',
#   'CPT',
#   'KL597',
#   0,
#   1024,
#   'KLM119',
#   0,
#   'KLM'],
#  '2f6fc73b': ['484B30',
#   52.0439,
#   8.5352,
#   96,
#   33000,
#   492,
#   '',
#   'F-EDVM1',
#   'E190',
#   'PH-EZC',
#   1678185454,
#   'AMS',
#   'WRO',
#   'KL1271',
#   0,
#   0,
#   'KLM31B',
#   0,
#   'KLM'],
#  '2f6fc86d': ['486491',
#   58.3075,
#   15.4443,
#   223,
#   37225,
#   418,
#   '',
#   'F-ESOW6',
#   'E295',
#   'PH-NXH',
#   1678185453,
#   'ARN',
#   'AMS',
#   'KL1108',
#   0,
#   576,
#   'KLM92V',
#   0,
#   'KLM'],
#  '2f6fc89e': ['484CC2',
#   50.6406,
#   7.6382,
#   146,
#   35000,
#   486,
#   '',
#   'F-LFST3',
#   'E190',
#   'PH-EZR',
#   1678185453,
#   'AMS',
#   'BLQ',
#   'KL1583',
#   0,
#   64,
#   'KLM11G',
#   0,
#   'KLM'],
#  '2f6fca01': ['4855D1',
#   48.6124,
#   6.6571,
#   329,
#   29425,
#   431,
#   '',
#   'F-LFSQ2',
#   'E75L',
#   'PH-EXO',
#   1678185455,
#   'BSL',
#   'AMS',
#   'KL1986',
#   0,
#   1664,
#   'KLM82K',
#   0,
#   'KLM'],
#  '2f6fca95': ['484371',
#   52.0057,
#   5.7058,
#   124,
#   19550,
#   438,
#   '',
#   'F-EDWR1',
#   'B772',
#   'PH-BQK',
#   1678185451,
#   'AMS',
#   'BLR',
#   'KL879',
#   0,
#   1088,
#   'KLM879',
#   0,
#   'KLM'],
#  '2f6fcb55': ['48548C',
#   53.1474,
#   0.0876,
#   106,
#   30675,
#   520,
#   '',
#   'F-EGBE2',
#   'E75L',
#   'PH-EXK',
#   1678185455,
#   'LBA',
#   'AMS',
#   'KL1546',
#   0,
#   832,
#   'KLM90B',
#   0,
#   'KLM'],
#  '2f6fcd8e': ['484F18',
#   45.6745,
#   9.6783,
#   75,
#   15525,
#   391,
#   '',
#   'F-LIMC2',
#   'B738',
#   'PH-BCB',
#   1678185452,
#   'LIN',
#   'AMS',
#   'KL1620',
#   0,
#   2304,
#   'KLM96K',
#   0,
#   'KLM'],
#  '2f6fce14': ['48436D',
#   0.574,
#   104.543,
#   126,
#   23525,
#   474,
#   '',
#   'F-WSSS1',
#   'B772',
#   'PH-BQF',
#   1678185455,
#   'SIN',
#   'DPS',
#   'KL835',
#   0,
#   1664,
#   'KLM835',
#   0,
#   'KLM'],
#  '2f6fd2b5': ['485874',
#   50.0772,
#   19.8038,
#   348,
#   0,
#   15,
#   '',
#   'F-EPKK2',
#   'E75L',
#   'PH-EXX',
#   1678185454,
#   'KRK',
#   'AMS',
#   'KL1994',
#   1,
#   0,
#   'KLM1994',
#   0,
#   'KLM'],
#  '2f6fd41a': ['48418A',
#   52.3084,
#   4.7728,
#   27,
#   0,
#   0,
#   '',
#   'T-EHAM115',
#   'B739',
#   'PH-BXO',
#   1678185450,
#   'AMS',
#   '',
#   '',
#   1,
#   0,
#   '',
#   0,
#   'KLM'],
#  'stats': {'total': {'ads-b': 9107,
#    'mlat': 291,
#    'faa': 62,
#    'flarm': 68,
#    'estimated': 403,
#    'satellite': 224,
#    'uat': 0,
#    'other': 0},
#   'visible': {'ads-b': 56,
#    'mlat': 0,
#    'faa': 0,
#    'flarm': 0,
#    'estimated': 1,
#    'satellite': 3,
#    'uat': 0,
#    'other': 0}}}

# %%
import flightradar24
flight_id = 'TK1' # Turkish Airlines' Istanbul - New York flight
fr = flightradar24.Api()
flight = fr.get_flight(flight_id)
flight
# Out:
# {'result': {'request': {'callback': None,
#    'device': None,
#    'fetchBy': 'flight',
#    'filterBy': None,
#    'format': 'json',
#    'limit': 25,
#    'olderThenFlightId': None,
#    'page': 1,
#    'pk': None,
#    'query': 'TK1',
#    'timestamp': None,
#    'token': None},
#   'response': {'item': {'current': 16, 'total': None, 'limit': 25},
#    'page': {'current': 1, 'more': False, 'total': None},
#    'timestamp': 1678185500,
#    'data': [{'identification': {'id': None,
#       'row': 5336196223,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '77W', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -14400,
#         'abbr': 'EDT',
#         'abbrName': 'Eastern Daylight Time',
#         'isDst': True},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678882800, 'arrival': 1678922700},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1678181092, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5335820205,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '333', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -14400,
#         'abbr': 'EDT',
#         'abbrName': 'Eastern Daylight Time',
#         'isDst': True},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678796400, 'arrival': 1678836300},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1678074317, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5335487517,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '333', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -14400,
#         'abbr': 'EDT',
#         'abbrName': 'Eastern Daylight Time',
#         'isDst': True},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678710000, 'arrival': 1678749900},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1677994172, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5335021890,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '77W', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -14400,
#         'abbr': 'EDT',
#         'abbrName': 'Eastern Daylight Time',
#         'isDst': True},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678623600, 'arrival': 1678663500},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1677862914, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5334830229,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '77W', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678537200, 'arrival': 1678577100},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1677822104, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5334472066,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '77W', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678450800, 'arrival': 1678490700},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1677732392, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5334101474,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Scheduled',
#       'icon': None,
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'scheduled',
#         'type': 'departure',
#         'color': 'gray',
#         'diverted': None},
#        'eventTime': {'utc': None, 'local': None}}},
#      'aircraft': {'model': {'code': '77W', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678364400, 'arrival': 1678404300},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': None, 'updated': 1677644659, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5333570775,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': None,
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Estimated dep 15:20',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'estimated',
#         'type': 'departure',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1678278000, 'local': 1678288800}}},
#      'aircraft': {'model': {'code': '77W', 'text': None},
#       'hex': None,
#       'registration': None,
#       'serialNo': None,
#       'age': None,
#       'restricted': None,
#       'availability': {'serialNo': None, 'age': None}},
#      'owner': None,
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678278000, 'arrival': 1678317900},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': 1678278000, 'arrival': None},
#       'other': {'eta': None, 'updated': 1678169161, 'duration': None}}},
#     {'identification': {'id': None,
#       'row': 5333359745,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Estimated dep 15:45',
#       'icon': 'yellow',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'estimated',
#         'type': 'departure',
#         'color': 'yellow',
#         'diverted': None},
#        'eventTime': {'utc': 1678193100, 'local': 1678203900}}},
#      'aircraft': {'model': {'code': 'A333', 'text': 'Airbus A330-303'},
#       'registration': 'TC-JOG',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA9E7',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678191600, 'arrival': 1678231500},
#       'real': {'departure': None, 'arrival': None},
#       'estimated': {'departure': 1678193100, 'arrival': None},
#       'other': {'eta': None, 'updated': 1678166988, 'duration': None}}},
#     {'identification': {'id': '2f6cf616',
#       'row': 5335922166,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 18:40',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1678146020, 'local': 1678128020}}},
#      'aircraft': {'model': {'code': 'A333', 'text': 'Airbus A330-343'},
#       'registration': 'TC-JNP',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA9D0',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678105200, 'arrival': 1678145100},
#       'real': {'departure': 1678108897, 'arrival': 1678146020},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1678146020, 'updated': 1678146020, 'duration': 37140}}},
#     {'identification': {'id': '2f69f80c',
#       'row': 5335562079,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 17:52',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1678056760, 'local': 1678038760}}},
#      'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-3F2(ER)'},
#       'registration': 'TC-LJF',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BB146',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1678018800, 'arrival': 1678058700},
#       'real': {'departure': 1678021746, 'arrival': 1678056760},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1678056760, 'updated': 1678056761, 'duration': 35040}}},
#     {'identification': {'id': '2f672f5b',
#       'row': 5332240531,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 17:53',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1677970388, 'local': 1677952388}}},
#      'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-3F2(ER)'},
#       'registration': 'TC-JJO',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA94F',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1677932400, 'arrival': 1677972300},
#       'real': {'departure': 1677934468, 'arrival': 1677970388},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1677970388, 'updated': 1677971730, 'duration': 35940}}},
#     {'identification': {'id': '2f6430b3',
#       'row': 5331898163,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 17:37',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1677883031, 'local': 1677865031}}},
#      'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-3F2(ER)'},
#       'registration': 'TC-JJL',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA94C',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1677846000, 'arrival': 1677885900},
#       'real': {'departure': 1677847951, 'arrival': 1677883031},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1677883031, 'updated': 1677883032, 'duration': 35100}}},
#     {'identification': {'id': '2f610ccb',
#       'row': 5331527361,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 17:26',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1677795965, 'local': 1677777965}}},
#      'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-3F2(ER)'},
#       'registration': 'TC-JJV',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA956',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1677759600, 'arrival': 1677799500},
#       'real': {'departure': 1677760939, 'arrival': 1677795965},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1677795965, 'updated': 1677796625, 'duration': 35040}}},
#     {'identification': {'id': '2f5dd4c5',
#       'row': 5331259681,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 17:25',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1677709555, 'local': 1677691555}}},
#      'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-3F2(ER)'},
#       'registration': 'TC-JJP',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA950',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1677673200, 'arrival': 1677713100},
#       'real': {'departure': 1677675940, 'arrival': 1677709555},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1677709555, 'updated': 1677711293, 'duration': 33600}}},
#     {'identification': {'id': '2f5ad536',
#       'row': 5330900010,
#       'number': {'default': 'TK1', 'alternative': None},
#       'callsign': 'THY1',
#       'codeshare': None},
#      'status': {'live': False,
#       'text': 'Landed 18:04',
#       'icon': 'green',
#       'estimated': None,
#       'ambiguous': False,
#       'generic': {'status': {'text': 'landed',
#         'type': 'arrival',
#         'color': 'green',
#         'diverted': None},
#        'eventTime': {'utc': 1677625478, 'local': 1677607478}}},
#      'aircraft': {'model': {'code': 'A333', 'text': 'Airbus A330-303'},
#       'registration': 'TC-JOE',
#       'country': {'id': 228,
#        'name': 'Turkey',
#        'alpha2': 'TR',
#        'alpha3': 'TUR'},
#       'hex': '4BA9E5',
#       'restricted': False,
#       'serialNo': None,
#       'age': {'availability': True},
#       'availability': {'serialNo': True, 'age': True}},
#      'owner': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'}},
#      'airline': {'name': 'Turkish Airlines',
#       'code': {'iata': 'TK', 'icao': 'THY'},
#       'short': 'Turkish Airlines'},
#      'airport': {'origin': {'name': 'Istanbul Airport',
#        'code': {'iata': 'IST', 'icao': 'LTFM'},
#        'position': {'latitude': 41.267052,
#         'longitude': 28.729757,
#         'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#         'region': {'city': 'Istanbul'}},
#        'timezone': {'name': 'Europe/Istanbul',
#         'offset': 10800,
#         'abbr': '+03',
#         'abbrName': None,
#         'isDst': False},
#        'visible': True},
#       'destination': {'name': 'New York John F. Kennedy International Airport',
#        'code': {'iata': 'JFK', 'icao': 'KJFK'},
#        'position': {'latitude': 40.639751,
#         'longitude': -73.7789,
#         'country': {'name': 'United States', 'code': 'US', 'id': 236},
#         'region': {'city': 'New York'}},
#        'timezone': {'name': 'America/New_York',
#         'offset': -18000,
#         'abbr': 'EST',
#         'abbrName': 'Eastern Standard Time',
#         'isDst': False},
#        'visible': True},
#       'real': None},
#      'time': {'scheduled': {'departure': 1677586800, 'arrival': 1677626700},
#       'real': {'departure': 1677588907, 'arrival': 1677625478},
#       'estimated': {'departure': None, 'arrival': None},
#       'other': {'eta': 1677625478,
#        'updated': 1677625478,
#        'duration': 36600}}}],
#    'aircraftInfo': None,
#    'aircraftImages': [{'registration': 'TC-JOG',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/91135_1674676692_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10861371',
#         'copyright': 'Alp AKBOSTANCI',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/49190_1674415817_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10858603',
#         'copyright': 'Ömür Sadikoglu',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/72738_1674393328_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10858232',
#         'copyright': 'Enri_Spotter',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/88767_1669408438_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10791905',
#         'copyright': 'Daniel Klein',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/50356_1664652312_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10737203',
#         'copyright': 'Ömür Sadikoglu',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/6/91135_1674676692.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10861371',
#         'copyright': 'Alp AKBOSTANCI',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/49190_1674415817.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10858603',
#         'copyright': 'Ömür Sadikoglu',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/72738_1674393328.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10858232',
#         'copyright': 'Enri_Spotter',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/88767_1669408438.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10791905',
#         'copyright': 'Daniel Klein',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/50356_1664652312.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10737203',
#         'copyright': 'Ömür Sadikoglu',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/91135_1674676692.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10861371',
#         'copyright': 'Alp AKBOSTANCI',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/49190_1674415817.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10858603',
#         'copyright': 'Ömür Sadikoglu',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/72738_1674393328.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10858232',
#         'copyright': 'Enri_Spotter',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/88767_1669408438.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10791905',
#         'copyright': 'Daniel Klein',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/50356_1664652312.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10737203',
#         'copyright': 'Ömür Sadikoglu',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-JNP',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/1588044_1676219947_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10878200',
#         'copyright': 'Sierra Aviation Photography',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/2391674_1676138293_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10877188',
#         'copyright': 'Sebastian Sowa',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/91850_1669655242_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10794880',
#         'copyright': 'Lorenz Kafenda',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/25191_1669316781_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10791191',
#         'copyright': 'OliverHendrich',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/18811_1671215126_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10816416',
#         'copyright': 'Aldo Martinelli',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/6/1588044_1676219947.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10878200',
#         'copyright': 'Sierra Aviation Photography',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/2391674_1676138293.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10877188',
#         'copyright': 'Sebastian Sowa',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/91850_1669655242.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10794880',
#         'copyright': 'Lorenz Kafenda',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/25191_1669316781.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10791191',
#         'copyright': 'OliverHendrich',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/18811_1671215126.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10816416',
#         'copyright': 'Aldo Martinelli',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/1588044_1676219947.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10878200',
#         'copyright': 'Sierra Aviation Photography',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/2391674_1676138293.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10877188',
#         'copyright': 'Sebastian Sowa',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/91850_1669655242.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10794880',
#         'copyright': 'Lorenz Kafenda',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/25191_1669316781.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10791191',
#         'copyright': 'OliverHendrich',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/18811_1671215126.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10816416',
#         'copyright': 'Aldo Martinelli',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-LJF',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/78519_1670142605_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10801495',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/58604_1665876881_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10750356',
#         'copyright': 'Chárbel Sandoval ',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/44744_1662725879_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10714255',
#         'copyright': 'Mehmed Bekir Cakmak',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/66295_1649404527_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10549199',
#         'copyright': 'John Fitzpatrick',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/60267_1640067238_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10423968',
#         'copyright': 'MashiroAsuna',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/6/78519_1670142605.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10801495',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/58604_1665876881.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10750356',
#         'copyright': 'Chárbel Sandoval ',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/44744_1662725879.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10714255',
#         'copyright': 'Mehmed Bekir Cakmak',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/66295_1649404527.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10549199',
#         'copyright': 'John Fitzpatrick',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/60267_1640067238.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10423968',
#         'copyright': 'MashiroAsuna',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/78519_1670142605.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10801495',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/58604_1665876881.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10750356',
#         'copyright': 'Chárbel Sandoval ',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/44744_1662725879.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10714255',
#         'copyright': 'Mehmed Bekir Cakmak',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/66295_1649404527.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10549199',
#         'copyright': 'John Fitzpatrick',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/60267_1640067238.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10423968',
#         'copyright': 'MashiroAsuna',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-JJO',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/5/32665_1667132663_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10763614',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/79036_1665065563_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10741571',
#         'copyright': 'Lewis Edward Latham',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/74525_1671048938_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10814261',
#         'copyright': 'Taha Berat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/97367_1664878815_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10739461',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/71454_1659693522_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10674217',
#         'copyright': 'Chow Kin Hei - AHKGAP',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/5/32665_1667132663.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10763614',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/79036_1665065563.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10741571',
#         'copyright': 'Lewis Edward Latham',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/74525_1671048938.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10814261',
#         'copyright': 'Taha Berat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/97367_1664878815.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10739461',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/71454_1659693522.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10674217',
#         'copyright': 'Chow Kin Hei - AHKGAP',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/5/32665_1667132663.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10763614',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/79036_1665065563.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10741571',
#         'copyright': 'Lewis Edward Latham',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/74525_1671048938.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10814261',
#         'copyright': 'Taha Berat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/97367_1664878815.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10739461',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/71454_1659693522.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10674217',
#         'copyright': 'Chow Kin Hei - AHKGAP',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-JJL',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/5/12271_1667763731_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10772556',
#         'copyright': 'Taha Berat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/58575_1671625518_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10821852',
#         'copyright': 'Joshua Müller',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/66515_1658854614_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10662859',
#         'copyright': 'Angelos Panou',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/29798_1668746169_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10784736',
#         'copyright': 'Akangaviation',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/51160_1656164288_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10630419',
#         'copyright': 'Shon Fridman',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/5/12271_1667763731.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10772556',
#         'copyright': 'Taha Berat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/58575_1671625518.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10821852',
#         'copyright': 'Joshua Müller',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/66515_1658854614.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10662859',
#         'copyright': 'Angelos Panou',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/29798_1668746169.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10784736',
#         'copyright': 'Akangaviation',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/51160_1656164288.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10630419',
#         'copyright': 'Shon Fridman',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/5/12271_1667763731.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10772556',
#         'copyright': 'Taha Berat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/58575_1671625518.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10821852',
#         'copyright': 'Joshua Müller',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/66515_1658854614.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10662859',
#         'copyright': 'Angelos Panou',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/29798_1668746169.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10784736',
#         'copyright': 'Akangaviation',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/51160_1656164288.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10630419',
#         'copyright': 'Shon Fridman',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-JJV',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/5/509830_1676560564_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10881716',
#         'copyright': 'Chuan Lu',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/628586_1675507924_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10870680',
#         'copyright': 'Andrew Hunt',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/59693_1672567676_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10833993',
#         'copyright': 'Vicknesh PS',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/92214_1664253051_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10733148',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/33465_1663470407_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10724471',
#         'copyright': 'Baek Jeonghyun',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/5/509830_1676560564.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10881716',
#         'copyright': 'Chuan Lu',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/628586_1675507924.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10870680',
#         'copyright': 'Andrew Hunt',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/59693_1672567676.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10833993',
#         'copyright': 'Vicknesh PS',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/92214_1664253051.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10733148',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/33465_1663470407.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10724471',
#         'copyright': 'Baek Jeonghyun',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/5/509830_1676560564.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10881716',
#         'copyright': 'Chuan Lu',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/628586_1675507924.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10870680',
#         'copyright': 'Andrew Hunt',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/59693_1672567676.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10833993',
#         'copyright': 'Vicknesh PS',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/92214_1664253051.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10733148',
#         'copyright': 'Oksana',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/33465_1663470407.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10724471',
#         'copyright': 'Baek Jeonghyun',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-JJP',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/77565_1669540289_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10793155',
#         'copyright': 'Harry Shan',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/58725_1672855623_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10838816',
#         'copyright': 'Onat Eronat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/45046_1669909718_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10798169',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/40379_1674051478_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10854179',
#         'copyright': 'doguegev',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/70792_1662406641_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10710770',
#         'copyright': 'Deniz Zeytinoglu',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/6/77565_1669540289.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10793155',
#         'copyright': 'Harry Shan',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/58725_1672855623.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10838816',
#         'copyright': 'Onat Eronat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/45046_1669909718.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10798169',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/40379_1674051478.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10854179',
#         'copyright': 'doguegev',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/70792_1662406641.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10710770',
#         'copyright': 'Deniz Zeytinoglu',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/77565_1669540289.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10793155',
#         'copyright': 'Harry Shan',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/58725_1672855623.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10838816',
#         'copyright': 'Onat Eronat',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/45046_1669909718.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10798169',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/40379_1674051478.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10854179',
#         'copyright': 'doguegev',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/70792_1662406641.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10710770',
#         'copyright': 'Deniz Zeytinoglu',
#         'source': 'Jetphotos.com'}]}},
#     {'registration': 'TC-JOE',
#      'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/5/1000185_1675975159_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10875393',
#         'copyright': 'Remi Dallot',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/53502_1670957156_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10813134',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/74254_1668120426_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10776752',
#         'copyright': 'Alessandro Iglesias',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/6/79095_1670379718_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10805519',
#         'copyright': 'Uranus',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/200/5/55928_1664802739_tb.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10738772',
#         'copyright': 'JJ Wang',
#         'source': 'Jetphotos.com'}],
#       'medium': [{'src': 'https://cdn.jetphotos.com/400/5/1000185_1675975159.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10875393',
#         'copyright': 'Remi Dallot',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/53502_1670957156.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10813134',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/74254_1668120426.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10776752',
#         'copyright': 'Alessandro Iglesias',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/6/79095_1670379718.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10805519',
#         'copyright': 'Uranus',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/400/5/55928_1664802739.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10738772',
#         'copyright': 'JJ Wang',
#         'source': 'Jetphotos.com'}],
#       'large': [{'src': 'https://cdn.jetphotos.com/640cb/5/1000185_1675975159.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10875393',
#         'copyright': 'Remi Dallot',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/53502_1670957156.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10813134',
#         'copyright': 'K Can Ozdemir',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/74254_1668120426.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10776752',
#         'copyright': 'Alessandro Iglesias',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/6/79095_1670379718.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10805519',
#         'copyright': 'Uranus',
#         'source': 'Jetphotos.com'},
#        {'src': 'https://cdn.jetphotos.com/640cb/5/55928_1664802739.jpg?v=0',
#         'link': 'https://www.jetphotos.com/photo/10738772',
#         'copyright': 'JJ Wang',
#         'source': 'Jetphotos.com'}]}}]}},
#  '_api': {'copyright': 'Copyright (c) 2014-2023 Flightradar24 AB. All rights reserved.',
#   'legalNotice': 'The contents of this file and all derived data are the property of Flightradar24 AB for use exclusively by its products and applications. Using, modifying or redistributing the data without the prior written permission of Flightradar24 AB is not allowed and may result in prosecutions.'}}

# %%
pip install FlightRadarAPI
# Out:
# Requirement already satisfied: FlightRadarAPI in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (1.2.3)
# Requirement already satisfied: Deprecated in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from FlightRadarAPI) (1.2.13)
# Requirement already satisfied: Brotli in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from FlightRadarAPI) (1.0.9)
# Requirement already satisfied: requests in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from FlightRadarAPI) (2.28.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from Deprecated->FlightRadarAPI) (1.12.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->FlightRadarAPI) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->FlightRadarAPI) (2021.10.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->FlightRadarAPI) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/opt/anaconda3/lib/python3.9/site-packages (from requests->FlightRadarAPI) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from FlightRadar24.api import FlightRadar24API
fr_api = FlightRadar24API()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 from FlightRadar24.api import FlightRadar24API
#       2 fr_api = FlightRadar24API()
#
# ModuleNotFoundError: No module named 'FlightRadar24'

# %%
import FlightRadarAPI
from threading import Thread, Lock
from time import sleep
import math

try:
    # Attempt to load config data
    from config import MIN_ALTITUDE

except (ModuleNotFoundError, NameError, ImportError):
    # If there's no config data
    MIN_ALTITUDE = 0  # feet

RETRIES = 3
RATE_LIMIT_DELAY = 1
MAX_FLIGHT_LOOKUP = 5
MAX_ALTITUDE = 10000  # feet
EARTH_RADIUS_KM = 6371
BLANK_FIELDS = ["", "N/A", "NONE"]

try:
    # Attempt to load config data
    from config import ZONE_HOME, LOCATION_HOME

    ZONE_DEFAULT = ZONE_HOME
    LOCATION_DEFAULT = LOCATION_HOME

except (ModuleNotFoundError, NameError, ImportError):
    # If there's no config data
    ZONE_DEFAULT = {"tl_y": 62.61, "tl_x": -13.07, "br_y": 49.71, "br_x": 3.46}
    LOCATION_DEFAULT = [51.509865, -0.118092, EARTH_RADIUS_KM]


def distance_from_flight_to_home(flight, home=LOCATION_DEFAULT):
    def polar_to_cartesian(lat, long, alt):
        DEG2RAD = math.pi / 180
        return [
            alt * math.cos(DEG2RAD * lat) * math.sin(DEG2RAD * long),
            alt * math.sin(DEG2RAD * lat),
            alt * math.cos(DEG2RAD * lat) * math.cos(DEG2RAD * long),
        ]

    def feet_to_meters_plus_earth(altitude_ft):
        altitude_km = 0.0003048 * altitude_ft
        return altitude_km + EARTH_RADIUS_KM

    try:
        (x0, y0, z0) = polar_to_cartesian(
            flight.latitude,
            flight.longitude,
            feet_to_meters_plus_earth(flight.altitude),
        )

        (x1, y1, z1) = polar_to_cartesian(*home)

        dist = math.sqrt((x1 - x0) ** 2 + (y1 - y0) ** 2 + (z1 - z0) ** 2)

        return dist

    except AttributeError:
        # on error say it's far away
        return 1e6


class Overhead:
    def __init__(self):
        self._api = FlightRadar24API()
        self._lock = Lock()
        self._data = []
        self._new_data = False
        self._processing = False

    def grab_data(self):
        Thread(target=self._grab_data).start()

    def _grab_data(self):
        # Mark data as old
        with self._lock:
            self._new_data = False
            self._processing = True

        data = []

        # Grab flight details
        bounds = self._api.get_bounds(ZONE_DEFAULT)
        flights = self._api.get_flights(bounds=bounds)

        # Sort flights by closest first
        flights = [
            f
            for f in flights
            if f.altitude < MAX_ALTITUDE and f.altitude > MIN_ALTITUDE
        ]
        flights = sorted(flights, key=lambda f: distance_from_flight_to_home(f))

        for flight in flights[:MAX_FLIGHT_LOOKUP]:
            retries = RETRIES

            while retries:
                # Rate limit protection
                sleep(RATE_LIMIT_DELAY)

                # Grab and store details
                try:
                    details = self._api.get_flight_details(flight.id)

                    # Get plane type
                    try:
                        plane = details["aircraft"]["model"]["text"]
                    except (KeyError, TypeError):
                        plane = ""

                    # Tidy up what we pass along
                    plane = plane if not (plane.upper() in BLANK_FIELDS) else ""

                    origin = (
                        flight.origin_airport_iata
                        if not (flight.origin_airport_iata.upper() in BLANK_FIELDS)
                        else ""
                    )

                    destination = (
                        flight.destination_airport_iata
                        if not (flight.destination_airport_iata.upper() in BLANK_FIELDS)
                        else ""
                    )

                    callsign = (
                        flight.callsign
                        if not (flight.callsign.upper() in BLANK_FIELDS)
                        else ""
                    )

                    data.append(
                        {
                            "plane": plane,
                            "origin": origin,
                            "destination": destination,
                            "vertical_speed": flight.vertical_speed,
                            "altitude": flight.altitude,
                            "callsign": callsign,
                        }
                    )
                    break

                except (KeyError, AttributeError):
                    retries -= 1

        with self._lock:
            self._new_data = True
            self._processing = False
            self._data = data

    @property
    def new_data(self):
        with self._lock:
            return self._new_data

    @property
    def processing(self):
        with self._lock:
            return self._processing

    @property
    def data(self):
        with self._lock:
            self._new_data = False
            return self._data

    @property
    def data_is_empty(self):
        return len(self._data) == 0


# Main function
if __name__ == "__main__":

    o = Overhead()
    o.grab_data()
    while not o.new_data:
        print("processing...")
        sleep(1)

    print(o.data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 import FlightRadarAPI
#       2 from threading import Thread, Lock
#       3 from time import sleep
#
# ModuleNotFoundError: No module named 'FlightRadarAPI'
